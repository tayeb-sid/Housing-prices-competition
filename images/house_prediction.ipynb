# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_selection import mutual_info_regression, mutual_info_classif
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.decomposition import PCA
from scipy.stats import randint, uniform
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, RandomizedSearchCV, PredefinedSplit, GridSearchCV
from sklearn.linear_model import Ridge, LinearRegression
from sklearn.svm import SVR
import xgboost as xgb
from sklearn.metrics import mean_squared_error

# %%
##############################################################################
# 1) Define global resources so we can reuse the same objects for train & test
##############################################################################

# --- Ordinal mapping for your ordinal columns ---
ordinal_mapping = {
    "GarageQual":    {"Ex": 5, "Gd": 4, "TA": 3, "Fa": 2, "Po": 1, "NA": 0},
    "Fence":         {"GdPrv": 4, "MnPrv": 3, "GdWo": 2, "MnWw": 1, "NA": 0},
    "GarageFinish":  {"Fin": 3, "RFn": 2, "Unf": 1, "NA": 0},
    "KitchenQual":   {"Ex": 4, "Gd": 3, "TA": 2, "Fa": 1, "Po": 0},
    "GarageCond":    {"Ex": 5, "Gd": 4, "TA": 3, "Fa": 2, "Po": 1, "NA": 0},
    "HeatingQC":     {"Ex": 4, "Gd": 3, "TA": 2, "Fa": 1, "Po": 0},
    "ExterQual":     {"Ex": 4, "Gd": 3, "TA": 2, "Fa": 1, "Po": 0},
    "BsmtCond":      {"Ex": 5, "Gd": 4, "TA": 3, "Fa": 2, "Po": 1, "NA": 0},
    "LandSlope":     {"Gtl": 2, "Mod": 1, "Sev": 0},
    "ExterCond":     {"Ex": 4, "Gd": 3, "TA": 2, "Fa": 1, "Po": 0},
    "BsmtExposure":  {"Gd": 4, "Av": 3, "Mn": 2, "No": 1, "NA": 0},
    "PavedDrive":    {"Y": 2, "P": 1, "N": 0},
    "BsmtQual":      {"Ex": 5, "Gd": 4, "TA": 3, "Fa": 2, "Po": 1, "NA": 0},
    "LotShape":      {"Reg": 3, "IR1": 2, "IR2": 1, "IR3": 0},
    "BsmtFinType2":  {"GLQ": 6, "ALQ": 5, "BLQ": 4, "Rec": 3, "LwQ": 2, "Unf": 1, "NA": 0},
    "BsmtFinType1":  {"GLQ": 6, "ALQ": 5, "BLQ": 4, "Rec": 3, "LwQ": 2, "Unf": 1, "NA": 0},
    "FireplaceQu":   {"Ex": 5, "Gd": 4, "TA": 3, "Fa": 2, "Po": 1, "NA": 0},
    "Utilities":     {"AllPub": 3, "NoSewr": 2, "NoSeWa": 1, "ELO": 0},
    "Functional":    {"Typ": 7, "Min1": 6, "Min2": 5, "Mod": 4, "Maj1": 3,
                      "Maj2": 2, "Sev": 1, "Sal": 0},
    "PoolQC":        {"Ex": 5, "Gd": 4, "TA": 3, "Fa": 2, "Po": 1, "NA": 0},
}
# Extract the list of ordinal columns from that mapping
ordinal_cols = list(ordinal_mapping.keys())

# --- Nominal features (for One-Hot Encoding) ---
nominal_features = [
    "MSZoning", "Street", "Alley", "LandContour", "LotConfig", "Neighborhood",
    "Condition1", "Condition2", "BldgType", "HouseStyle", "RoofStyle", "RoofMatl",
    "Exterior1st", "Exterior2nd", "MasVnrType", "Foundation", "Heating",
    "CentralAir", "Electrical", "GarageType", "MiscFeature", "SaleType",
    "SaleCondition"
]

# Create ONE global OrdinalEncoder and ONE global OneHotEncoder.
# We'll fit them on train, then reuse them to transform test.
ordinal_encoder = OrdinalEncoder(
    categories=[list(ordinal_mapping[col].keys()) for col in ordinal_cols],
    handle_unknown="use_encoded_value",
    unknown_value=-1
)
one_hot_encoder = OneHotEncoder(handle_unknown='ignore', sparse_output=False)

##############################################################################
# 2) Main preprocessing function
##############################################################################
# def preprocess_data(df, is_train=True):
#     """
#     Preprocess a housing DataFrame.
#     If is_train=True, drops outliers and fits the encoders.
#     If is_train=False, only transforms using the fitted encoders (NO outlier removal).

#     Returns:
#       (X, y) if is_train=True
#       X if is_train=False
#     """

#     # Make a copy so we don't overwrite the original data
#     df = df.copy()

#     # If this is training data, grab the target 'SalePrice'
#     # and remove it from the DataFrame.
#     if is_train:
#         y = df['SalePrice']
#         df.drop('SalePrice', axis=1, inplace=True)
#     else:
#         y = None  # no target in test set

#     # 1) Convert certain columns to numeric if they exist
#     cols_to_numeric = [
#         "LotFrontage", "MasVnrArea", "BsmtFinSF1", "BsmtFinSF2", "BsmtUnfSF",
#         "TotalBsmtSF", "BsmtFullBath", "GarageCars", "BsmtHalfBath", "GarageYrBlt"
#     ]
#     for col in cols_to_numeric:
#         if col in df.columns:
#             df[col] = pd.to_numeric(df[col], errors="coerce")

#     # 2) Fill numeric columns with 0, categorical with "NA"
#     numeric_cols = df.select_dtypes(include=['number']).columns
#     df[numeric_cols] = df[numeric_cols].fillna(0)

#     # Identify any columns of object/string dtype
#     cat_cols = df.select_dtypes(include=['object']).columns
#     for cat_col in cat_cols:
#         df[cat_col] = df[cat_col].fillna("NA")

#     # 3) Feature engineering examples (abbreviated from your original code)
#     #    Only do these if the columns exist in df.
#     if set(["FullBath","HalfBath","BsmtFullBath","BsmtHalfBath"]).issubset(df.columns):
#         df["TotalBath"] = (
#             df["FullBath"] +
#             0.5 * df["HalfBath"] +
#             df["BsmtFullBath"] +
#             0.5 * df["BsmtHalfBath"]
#         )
#     else:
#         # If any are missing, you can either create them or skip
#         df["TotalBath"] = 0

#     if "GarageYrBlt" in df.columns:
#         df["Has_garage"] = df["GarageYrBlt"].notnull().astype(int)

#     if set(["YrSold","YearBuilt"]).issubset(df.columns):
#         df["House_Age"] = df["YrSold"] - df["YearBuilt"]

#     if set(["YearBuilt","YearRemodAdd"]).issubset(df.columns):
#         df["Is_Remodeled"] = (df["YearBuilt"] != df["YearRemodAdd"]).astype(int)

#     # ... etc. for other features from your original code ...
#     # e.g., if you want "House_Age2", "GrLivArea" / "LotArea" ratio, etc.

#     # 4) Outlier removal: only do this on TRAIN.
#     #    Make sure to drop rows from y as well to keep them aligned.
#     if is_train:
#         # (a) LotFrontage > 200
#         if "LotFrontage" in df.columns:
#             idx = df[df["LotFrontage"] > 200].index
#             df.drop(idx, inplace=True)
#             y.drop(idx, inplace=True)

#         # (b) LotArea > 100000
#         if "LotArea" in df.columns:
#             idx = df[df["LotArea"] > 100000].index
#             df.drop(idx, inplace=True)
#             y.drop(idx, inplace=True)

#         # (c) BsmtFinSF1 > 4000
#         if "BsmtFinSF1" in df.columns:
#             idx = df[df["BsmtFinSF1"] > 4000].index
#             df.drop(idx, inplace=True)
#             y.drop(idx, inplace=True)

#         # (d) TotalBsmtSF > 6000
#         if "TotalBsmtSF" in df.columns:
#             idx = df[df["TotalBsmtSF"] > 6000].index
#             df.drop(idx, inplace=True)
#             y.drop(idx, inplace=True)

#         # (e) 1stFlrSF > 4000
#         if "1stFlrSF" in df.columns:
#             idx = df[df["1stFlrSF"] > 4000].index
#             df.drop(idx, inplace=True)
#             y.drop(idx, inplace=True)

#         # (f) GrLivArea > 4000 & y < 300000
#         if "GrLivArea" in df.columns:
#             idx = df[(df["GrLivArea"] > 4000) & (y < 300000)].index
#             df.drop(idx, inplace=True)
#             y.drop(idx, inplace=True)

#         # (g) LowQualFinSF > 550
#         if "LowQualFinSF" in df.columns:
#             idx = df[df["LowQualFinSF"] > 550].index
#             df.drop(idx, inplace=True)
#             y.drop(idx, inplace=True)

#     # 5) Ordinal Encoding for the columns in ordinal_mapping
#     #    We'll only encode columns that actually exist in df.
#     existing_ordinal = [col for col in ordinal_cols if col in df.columns]

#     # Clean up whitespace if any
#     for col in existing_ordinal:
#         df[col] = df[col].astype(str).str.strip()

#     # If train: fit_transform
#     # If test:  transform only
#     if len(existing_ordinal) > 0:
#         if is_train:
#             df[existing_ordinal] = ordinal_encoder.fit_transform(df[existing_ordinal])
#         else:
#             df[existing_ordinal] = ordinal_encoder.transform(df[existing_ordinal])
#         # Replace unknown encodings (-1) with 0
#         df.replace(-1, 0, inplace=True)

#     # 6) One-Hot Encoding for nominal features
#     existing_nominal = [col for col in nominal_features if col in df.columns]

#     if len(existing_nominal) > 0:
#         if is_train:
#             # Fit on train
#             encoded = one_hot_encoder.fit_transform(df[existing_nominal])
#         else:
#             # Transform test
#             encoded = one_hot_encoder.transform(df[existing_nominal])

#         # Convert to DataFrame
#         encoded_df = pd.DataFrame(
#             encoded,
#             columns=one_hot_encoder.get_feature_names_out(existing_nominal),
#             index=df.index
#         )
#         # Drop original nominal cols, then join
#         df.drop(columns=existing_nominal, inplace=True)
#         df = df.join(encoded_df)

#     # Return final results
#     if is_train:
#         return df, y
#     else:
#         return df

def preprocess_data(df, is_train=True):
    """
    Preprocess a housing DataFrame.
    If is_train=True, drops outliers and fits the encoders.
    If is_train=False, only transforms using the fitted encoders (NO outlier removal).

    Returns:
      (X, y) if is_train=True
      X if is_train=False
    """

    # Make a copy so we don't overwrite the original data
    df = df.copy()

    # If this is training data, grab the target 'SalePrice'
    # and remove it from the DataFrame.
    if is_train:
        y = df['SalePrice']
        df.drop('SalePrice', axis=1, inplace=True)
    else:
        y = None  # no target in test set

    # 1) Convert certain columns to numeric if they exist
    cols_to_numeric = [
        "LotFrontage", "MasVnrArea", "BsmtFinSF1", "BsmtFinSF2", "BsmtUnfSF",
        "TotalBsmtSF", "BsmtFullBath", "GarageCars", "BsmtHalfBath", "GarageYrBlt"
    ]
    for col in cols_to_numeric:
        if col in df.columns:
            df[col] = pd.to_numeric(df[col], errors="coerce")

    # 2) Fill numeric columns with 0, categorical with "NA"
    numeric_cols = df.select_dtypes(include=['number']).columns
    df[numeric_cols] = df[numeric_cols].fillna(0)

    # Identify any columns of object/string dtype
    cat_cols = df.select_dtypes(include=['object']).columns
    for cat_col in cat_cols:
        df[cat_col] = df[cat_col].fillna("NA")

    # 3) Feature engineering examples
    # Existing Feature Engineering
    if set(["FullBath","HalfBath","BsmtFullBath","BsmtHalfBath"]).issubset(df.columns):
        df["TotalBath"] = (
            df["FullBath"] +
            0.5 * df["HalfBath"] +
            df["BsmtFullBath"] +
            0.5 * df["BsmtHalfBath"]
        )
    else:
        df["TotalBath"] = 0

    if "GarageYrBlt" in df.columns:
        df["Has_garage"] = df["GarageYrBlt"].notnull().astype(int)

    if set(["YrSold","YearBuilt"]).issubset(df.columns):
        df["House_Age"] = df["YrSold"] - df["YearBuilt"]

    if set(["YearBuilt","YearRemodAdd"]).issubset(df.columns):
        df["Is_Remodeled"] = (df["YearBuilt"] != df["YearRemodAdd"]).astype(int)

    # New Feature Engineering (your provided list)
    if set(["Street", "Alley", "MasVnrType", "GarageType", "MiscFeature",
            "BsmtQual", "FireplaceQu", "PoolQC", "Fence", "CentralAir"]).issubset(df.columns):
        # Count missing values in the selected columns and add penalties if certain conditions are met
        df["Lack_of_feature_index"] = df[["Street", "Alley", "MasVnrType", "GarageType", "MiscFeature",
                                           "BsmtQual", "FireplaceQu", "PoolQC", "Fence"]].isnull().sum(axis=1) + \
                                       (df["MasVnrType"] == 'None') + (df["CentralAir"] == 'No')
    else:
        df["Lack_of_feature_index"] = 0

    for col in ["PoolQC", "MiscFeature", "Fence"]:
        if col not in df.columns:
            df[col] = pd.NA

    df["MiscFeatureExtended"] = (
        df["PoolQC"].notnull().astype(int) +
        df["MiscFeature"].notnull().astype(int) +
        df["Fence"].notnull().astype(int)
    ).astype(int)

    if "Alley" in df.columns:
        df["Has_Alley"] = df["Alley"].notnull().astype(int)
    else:
        df["Has_Alley"] = 0

    if set(["GrLivArea", "LotArea"]).issubset(df.columns):
        df["Lot_occupation"] = df["GrLivArea"] / df["LotArea"]
    else:
        df["Lot_occupation"] = 0

    if set(["TotalBsmtSF", "1stFlrSF", "2ndFlrSF"]).issubset(df.columns):
        df["Number_of_floors"] = (
            (df["TotalBsmtSF"] != 0).astype(int) +
            (df["1stFlrSF"] != 0).astype(int) +
            (df["2ndFlrSF"] != 0).astype(int)
        )
    else:
        df["Number_of_floors"] = 0

    if set(["GrLivArea", "TotalBsmtSF"]).issubset(df.columns):
        df['Total_Close_Live_Area'] = df['GrLivArea'] + df['TotalBsmtSF']
    else:
        df['Total_Close_Live_Area'] = 0

    if set(["WoodDeckSF", "OpenPorchSF", "EnclosedPorch", "3SsnPorch", "ScreenPorch"]).issubset(df.columns):
        df['Outside_live_area'] = (
            df['WoodDeckSF'] +
            df['OpenPorchSF'] +
            df['EnclosedPorch'] +
            df['3SsnPorch'] +
            df['ScreenPorch']
        )
    else:
        df['Outside_live_area'] = 0

    df['Total_usable_area'] = df.get('Total_Close_Live_Area', 0) + df.get('Outside_live_area', 0)

    if "OverallQual" in df.columns and "Total_usable_area" in df.columns:
        df['Area_Quality_Indicator'] = df['Total_usable_area'] * df['OverallQual']
    else:
        df['Area_Quality_Indicator'] = 0

    if set(["OverallQual", "OverallCond", "Total_usable_area"]).issubset(df.columns):
        df['Area_Qual_Cond_Indicator'] = df['Total_usable_area'] * df['OverallQual'] * df['OverallCond']
    else:
        df['Area_Qual_Cond_Indicator'] = 0

    if "BsmtQual" in df.columns:
        df['HasBsmt'] = df['BsmtQual'].notnull().astype(int)
    else:
        df['HasBsmt'] = 0

    if set(["OverallQual", "OverallCond"]).issubset(df.columns):
        df['Quality_conditition'] = df['OverallQual'] * df['OverallCond']
        df['Quality_conditition_2'] = df['OverallQual'] + df['OverallCond']
    else:
        df['Quality_conditition'] = 0
        df['Quality_conditition_2'] = 0

    if set(["YrSold", "YearRemodAdd"]).issubset(df.columns):
        df['House_Age2'] = df['YrSold'] - df['YearRemodAdd']
    else:
        df['House_Age2'] = 0

    # 4) Outlier removal: only do this on TRAIN.
    if is_train:
        # (a) LotFrontage > 200
        if "LotFrontage" in df.columns:
            idx = df[df["LotFrontage"] > 200].index
            df.drop(idx, inplace=True)
            y.drop(idx, inplace=True)

        # (b) LotArea > 100000
        if "LotArea" in df.columns:
            idx = df[df["LotArea"] > 100000].index
            df.drop(idx, inplace=True)
            y.drop(idx, inplace=True)

        # (c) BsmtFinSF1 > 4000
        if "BsmtFinSF1" in df.columns:
            idx = df[df["BsmtFinSF1"] > 4000].index
            df.drop(idx, inplace=True)
            y.drop(idx, inplace=True)

        # (d) TotalBsmtSF > 6000
        if "TotalBsmtSF" in df.columns:
            idx = df[df["TotalBsmtSF"] > 6000].index
            df.drop(idx, inplace=True)
            y.drop(idx, inplace=True)

        # (e) 1stFlrSF > 4000
        if "1stFlrSF" in df.columns:
            idx = df[df["1stFlrSF"] > 4000].index
            df.drop(idx, inplace=True)
            y.drop(idx, inplace=True)

        # (f) GrLivArea > 4000 & y < 300000
        if "GrLivArea" in df.columns:
            idx = df[(df["GrLivArea"] > 4000) & (y < 300000)].index
            df.drop(idx, inplace=True)
            y.drop(idx, inplace=True)

        # (g) LowQualFinSF > 550
        if "LowQualFinSF" in df.columns:
            idx = df[df["LowQualFinSF"] > 550].index
            df.drop(idx, inplace=True)
            y.drop(idx, inplace=True)

    # 5) Ordinal Encoding for the columns in ordinal_mapping
    existing_ordinal = [col for col in ordinal_cols if col in df.columns]

    # Clean up whitespace if any
    for col in existing_ordinal:
        df[col] = df[col].astype(str).str.strip()

    if len(existing_ordinal) > 0:
        if is_train:
            df[existing_ordinal] = ordinal_encoder.fit_transform(df[existing_ordinal])
        else:
            df[existing_ordinal] = ordinal_encoder.transform(df[existing_ordinal])
        # Replace unknown encodings (-1) with 0
        df.replace(-1, 0, inplace=True)

    # 6) One-Hot Encoding for nominal features
    existing_nominal = [col for col in nominal_features if col in df.columns]

    if len(existing_nominal) > 0:
        if is_train:
            # Fit on train
            encoded = one_hot_encoder.fit_transform(df[existing_nominal])
        else:
            # Transform test
            encoded = one_hot_encoder.transform(df[existing_nominal])

        # Convert to DataFrame
        encoded_df = pd.DataFrame(
            encoded,
            columns=one_hot_encoder.get_feature_names_out(existing_nominal),
            index=df.index
        )
        # Drop original nominal cols, then join
        df.drop(columns=existing_nominal, inplace=True)
        df = df.join(encoded_df)

    # Return final results
    if is_train:
        return df, y
    else:
        return df

# %%
df_train = pd.read_csv("train.csv")
X_train, y_train = preprocess_data(df_train, is_train=True)

# %%
df_test = pd.read_csv("test.csv")
test_ids = df_test['Id'].copy()
X_test = preprocess_data(df_test, is_train=False)

# %%
print(f"New train shape: {X_train.shape}, test shape: {X_test.shape}")
# Out:
# New train shape: (1452, 244), test shape: (1459, 244)

# %% [markdown]
# ## Random Forest

# %%
param_dist = {
    'n_estimators': randint(100, 3000),        # Number of trees
}
# Example parameter distribution:
# param_dist = {
#     'n_estimators': randint(100, 2000),        # Number of trees
#     'max_depth': randint(1, 20),             # Maximum tree depth
#     'min_samples_split': randint(2, 20),     # Minimum samples required to split an internal node
#     'min_samples_leaf': randint(1, 10),      # Minimum samples required at a leaf node
#     'max_features': ['sqrt', 'log2', None], # Number of features to consider at each split
#     'criterion': ['squared_error'] # For regression
# }
#
#param_dist_reduced = {
#    'n_estimators': randint(100, 500),        # Use fewer trees
#    'max_depth': randint(3, 15),              # Limit tree depth to reduce complexity
#    'min_samples_split': randint(10, 50),     # Increase minimum samples for splitting nodes
#    'min_samples_leaf': randint(5, 20),       # Increase minimum samples for leaves
#    'max_features': ['sqrt', 0.5, None],      # Test 'sqrt', 50% of features, or no limit
#    'criterion': ['squared_error']            # Stick with one criterion for consistency
#}

# %%
# Initialize the RandomForestRegressor
rf = RandomForestRegressor(bootstrap=True,oob_score=True, random_state=42)

# %%
# cv_dummy = [(np.arange(len(X_train)), np.arange(len(X_train)))]
random_search = RandomizedSearchCV(
    estimator=rf,
    param_distributions=param_dist,
    n_iter=15,
    scoring='neg_root_mean_squared_error',
    random_state=42,
    n_jobs=1,
    verbose=5,
    return_train_score=True,
    cv=3
)

# %%
random_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 15 candidates, totalling 45 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-30664167c996> in <cell line: 0>()
# ----> 1 random_search.fit(X_train, y_train)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, **params)
#    1022                 return results
#    1023
# -> 1024             self._run_search(evaluate_candidates)
#    1025
#    1026             # multimetric is determined here because in the case of a callable
#
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1949     def _run_search(self, evaluate_candidates):
#    1950         """Search n_iter candidates from param_distributions"""
# -> 1951         evaluate_candidates(
#    1952             ParameterSampler(
#    1953                 self.param_distributions, self.n_iter, random_state=self.random_state
#
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     968                     )
#     969
# --> 970                 out = parallel(
#     971                     delayed(_fit_and_score)(
#     972                         clone(base_estimator),
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/parallel.py in __call__(self, iterable)
#      75             for delayed_func, args, kwargs in iterable
#      76         )
# ---> 77         return super().__call__(iterable_with_config)
#      78
#      79
#
# /usr/local/lib/python3.11/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1916             output = self._get_sequential_output(iterable)
#    1917             next(output)
# -> 1918             return output if self.return_generator else list(output)
#    1919
#    1920         # Let's create an ID that uniquely identifies the current call. If the
#
# /usr/local/lib/python3.11/dist-packages/joblib/parallel.py in _get_sequential_output(self, iterable)
#    1845                 self.n_dispatched_batches += 1
#    1846                 self.n_dispatched_tasks += 1
# -> 1847                 res = func(*args, **kwargs)
#    1848                 self.n_completed_tasks += 1
#    1849                 self.print_progress()
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/parallel.py in __call__(self, *args, **kwargs)
#     137             config = {}
#     138         with config_context(**config):
# --> 139             return self.function(*args, **kwargs)
#     140
#     141
#
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, score_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     864             estimator.fit(X_train, **fit_params)
#     865         else:
# --> 866             estimator.fit(X_train, y_train, **fit_params)
#     867
#     868     except Exception:
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     485             # parallel_backend contexts set at a higher level,
#     486             # since correctness does not rely on using threads.
# --> 487             trees = Parallel(
#     488                 n_jobs=self.n_jobs,
#     489                 verbose=self.verbose,
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/parallel.py in __call__(self, iterable)
#      75             for delayed_func, args, kwargs in iterable
#      76         )
# ---> 77         return super().__call__(iterable_with_config)
#      78
#      79
#
# /usr/local/lib/python3.11/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1916             output = self._get_sequential_output(iterable)
#    1917             next(output)
# -> 1918             return output if self.return_generator else list(output)
#    1919
#    1920         # Let's create an ID that uniquely identifies the current call. If the
#
# /usr/local/lib/python3.11/dist-packages/joblib/parallel.py in _get_sequential_output(self, iterable)
#    1845                 self.n_dispatched_batches += 1
#    1846                 self.n_dispatched_tasks += 1
# -> 1847                 res = func(*args, **kwargs)
#    1848                 self.n_completed_tasks += 1
#    1849                 self.print_progress()
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/parallel.py in __call__(self, *args, **kwargs)
#     137             config = {}
#     138         with config_context(**config):
# --> 139             return self.function(*args, **kwargs)
#     140
#     141
#
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap, missing_values_in_feature_mask)
#     187             curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
#     188
# --> 189         tree._fit(
#     190             X,
#     191             y,
#
# /usr/local/lib/python3.11/dist-packages/sklearn/tree/_classes.py in _fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     470             )
#     471
# --> 472         builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#     473
#     474         if self.n_outputs_ == 1 and is_classifier(self):
#
# KeyboardInterrupt:

# %%
# Get the best parameters and model
best_params = random_search.best_params_
best_model = random_search.best_estimator_
best_r2 = -random_search.best_score_
print("Ridge Regression best params:", best_params)
print("Ridge Regression best R² on validation set: {:.4f}".format(best_r2))

# %%
# Train a final RandomForestRegressor using the best parameters
final_model = RandomForestRegressor(**best_params,bootstrap=True,oob_score=True, random_state=42)
final_model.fit(X_train, y_train)

# %%
# Generate predictions for the test set
test_predictions = final_model.predict(X_test)

# %%
# Create a submission dataframe (assuming the sample_submission.csv expects 'Id' and 'SalePrice')
submission = pd.DataFrame({'Id': test_ids, 'SalePrice': test_predictions})
submission.to_csv('submission_Random_forest.csv', index=False)

print("Submission file 'submission.csv' created successfully!")

# %% [markdown]
# ## XGBOOST

# %%
param_grid = {
    'n_estimators': list(range(1000, 1601, 50)),
    'max_depth': randint(2, 7),
    'learning_rate': [0.01, 0.03, 0.1, 0.3, 0.05, 0.5],
    'subsample': [0.7, 0.6, 0.5, 0.4, 0.3],
    'colsample_bytree': [0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1],
}
# param_grid = {
#     'n_estimators': randint(50, 1000)
# }

# %%
xgb_reg = xgb.XGBRegressor(
    objective='reg:squarederror',
    random_state=42,
)

# %%
# Set up RandomizedSearchCV using negative RMSE as the scoring metric
random_search_xgb = RandomizedSearchCV(estimator=xgb_reg,
                                   param_distributions=param_grid,
                                   n_iter=50,
                                   cv=4,
                                   scoring='neg_root_mean_squared_error',
                                   random_state=42,
                                   n_jobs=1,
                                   verbose=2)

# %%
# Run the search
random_search_xgb.fit(X_train, y_train)
# Out:
# Fitting 4 folds for each of 50 candidates, totalling 200 fits
# [CV] END colsample_bytree=0.4, learning_rate=0.05, max_depth=4, n_estimators=1350, subsample=0.3; total time=  30.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.05, max_depth=4, n_estimators=1350, subsample=0.3; total time=   2.8s
# [CV] END colsample_bytree=0.4, learning_rate=0.05, max_depth=4, n_estimators=1350, subsample=0.3; total time=   2.8s
# [CV] END colsample_bytree=0.4, learning_rate=0.05, max_depth=4, n_estimators=1350, subsample=0.3; total time=   2.9s
# [CV] END colsample_bytree=0.3, learning_rate=0.03, max_depth=4, n_estimators=1300, subsample=0.5; total time=   4.5s
# [CV] END colsample_bytree=0.3, learning_rate=0.03, max_depth=4, n_estimators=1300, subsample=0.5; total time=   2.5s
# [CV] END colsample_bytree=0.3, learning_rate=0.03, max_depth=4, n_estimators=1300, subsample=0.5; total time=   2.5s
# [CV] END colsample_bytree=0.3, learning_rate=0.03, max_depth=4, n_estimators=1300, subsample=0.5; total time=   2.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1350, subsample=0.5; total time=   6.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1350, subsample=0.5; total time=   4.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1350, subsample=0.5; total time=   6.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1350, subsample=0.5; total time=   4.6s
# [CV] END colsample_bytree=0.2, learning_rate=0.05, max_depth=3, n_estimators=1350, subsample=0.4; total time=   1.9s
# [CV] END colsample_bytree=0.2, learning_rate=0.05, max_depth=3, n_estimators=1350, subsample=0.4; total time=   3.9s
# [CV] END colsample_bytree=0.2, learning_rate=0.05, max_depth=3, n_estimators=1350, subsample=0.4; total time=   2.0s
# [CV] END colsample_bytree=0.2, learning_rate=0.05, max_depth=3, n_estimators=1350, subsample=0.4; total time=   2.0s
# [CV] END colsample_bytree=0.2, learning_rate=0.5, max_depth=3, n_estimators=1550, subsample=0.3; total time=   2.3s
# [CV] END colsample_bytree=0.2, learning_rate=0.5, max_depth=3, n_estimators=1550, subsample=0.3; total time=   2.3s
# [CV] END colsample_bytree=0.2, learning_rate=0.5, max_depth=3, n_estimators=1550, subsample=0.3; total time=   4.1s
# [CV] END colsample_bytree=0.2, learning_rate=0.5, max_depth=3, n_estimators=1550, subsample=0.3; total time=   2.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.3, max_depth=3, n_estimators=1250, subsample=0.3; total time=   2.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.3, max_depth=3, n_estimators=1250, subsample=0.3; total time=   2.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.3, max_depth=3, n_estimators=1250, subsample=0.3; total time=   4.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.3, max_depth=3, n_estimators=1250, subsample=0.3; total time=   2.5s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=1500, subsample=0.5; total time=   2.6s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=1500, subsample=0.5; total time=   2.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=1500, subsample=0.5; total time=   2.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=1500, subsample=0.5; total time=   3.8s
# [CV] END colsample_bytree=0.6, learning_rate=0.3, max_depth=5, n_estimators=1100, subsample=0.4; total time=   4.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.3, max_depth=5, n_estimators=1100, subsample=0.4; total time=   4.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.3, max_depth=5, n_estimators=1100, subsample=0.4; total time=   5.9s
# [CV] END colsample_bytree=0.6, learning_rate=0.3, max_depth=5, n_estimators=1100, subsample=0.4; total time=   4.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=1200, subsample=0.5; total time=   2.6s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=1200, subsample=0.5; total time=   4.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=1200, subsample=0.5; total time=   2.5s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=1200, subsample=0.5; total time=   2.5s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=1150, subsample=0.7; total time=   1.8s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=1150, subsample=0.7; total time=   3.7s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=1150, subsample=0.7; total time=   1.8s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=1150, subsample=0.7; total time=   1.8s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=3, n_estimators=1450, subsample=0.7; total time=   2.5s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=3, n_estimators=1450, subsample=0.7; total time=   2.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=3, n_estimators=1450, subsample=0.7; total time=   4.5s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=3, n_estimators=1450, subsample=0.7; total time=   2.4s
# [CV] END colsample_bytree=0.6, learning_rate=0.05, max_depth=3, n_estimators=1150, subsample=0.4; total time=   2.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.05, max_depth=3, n_estimators=1150, subsample=0.4; total time=   2.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.05, max_depth=3, n_estimators=1150, subsample=0.4; total time=   3.5s
# [CV] END colsample_bytree=0.6, learning_rate=0.05, max_depth=3, n_estimators=1150, subsample=0.4; total time=   2.6s
# [CV] END colsample_bytree=0.4, learning_rate=0.3, max_depth=6, n_estimators=1350, subsample=0.5; total time=   4.8s
# [CV] END colsample_bytree=0.4, learning_rate=0.3, max_depth=6, n_estimators=1350, subsample=0.5; total time=   7.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.3, max_depth=6, n_estimators=1350, subsample=0.5; total time=   6.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.3, max_depth=6, n_estimators=1350, subsample=0.5; total time=   6.8s
# [CV] END colsample_bytree=0.2, learning_rate=0.01, max_depth=5, n_estimators=1050, subsample=0.4; total time=   2.2s
# [CV] END colsample_bytree=0.2, learning_rate=0.01, max_depth=5, n_estimators=1050, subsample=0.4; total time=   2.2s
# [CV] END colsample_bytree=0.2, learning_rate=0.01, max_depth=5, n_estimators=1050, subsample=0.4; total time=   2.2s
# [CV] END colsample_bytree=0.2, learning_rate=0.01, max_depth=5, n_estimators=1050, subsample=0.4; total time=   4.3s
# [CV] END colsample_bytree=0.6, learning_rate=0.5, max_depth=3, n_estimators=1150, subsample=0.3; total time=   2.2s
# [CV] END colsample_bytree=0.6, learning_rate=0.5, max_depth=3, n_estimators=1150, subsample=0.3; total time=   2.2s
# [CV] END colsample_bytree=0.6, learning_rate=0.5, max_depth=3, n_estimators=1150, subsample=0.3; total time=   2.2s
# [CV] END colsample_bytree=0.6, learning_rate=0.5, max_depth=3, n_estimators=1150, subsample=0.3; total time=   2.3s
# [CV] END colsample_bytree=0.6, learning_rate=0.03, max_depth=5, n_estimators=1050, subsample=0.6; total time=   5.5s
# [CV] END colsample_bytree=0.6, learning_rate=0.03, max_depth=5, n_estimators=1050, subsample=0.6; total time=   3.8s
# [CV] END colsample_bytree=0.6, learning_rate=0.03, max_depth=5, n_estimators=1050, subsample=0.6; total time=   5.7s
# [CV] END colsample_bytree=0.6, learning_rate=0.03, max_depth=5, n_estimators=1050, subsample=0.6; total time=   3.7s
# [CV] END colsample_bytree=0.2, learning_rate=0.3, max_depth=5, n_estimators=1400, subsample=0.3; total time=   3.2s
# [CV] END colsample_bytree=0.2, learning_rate=0.3, max_depth=5, n_estimators=1400, subsample=0.3; total time=   5.0s
# [CV] END colsample_bytree=0.2, learning_rate=0.3, max_depth=5, n_estimators=1400, subsample=0.3; total time=   3.1s
# [CV] END colsample_bytree=0.2, learning_rate=0.3, max_depth=5, n_estimators=1400, subsample=0.3; total time=   3.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.03, max_depth=6, n_estimators=1350, subsample=0.6; total time=   6.8s
# [CV] END colsample_bytree=0.3, learning_rate=0.03, max_depth=6, n_estimators=1350, subsample=0.6; total time=   4.8s
# [CV] END colsample_bytree=0.3, learning_rate=0.03, max_depth=6, n_estimators=1350, subsample=0.6; total time=   6.8s
# [CV] END colsample_bytree=0.3, learning_rate=0.03, max_depth=6, n_estimators=1350, subsample=0.6; total time=   4.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.3, max_depth=5, n_estimators=1550, subsample=0.3; total time=   7.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.3, max_depth=5, n_estimators=1550, subsample=0.3; total time=   5.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.3, max_depth=5, n_estimators=1550, subsample=0.3; total time=   7.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.3, max_depth=5, n_estimators=1550, subsample=0.3; total time=   6.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=1000, subsample=0.7; total time=   7.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=1000, subsample=0.7; total time=   7.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=1000, subsample=0.7; total time=   5.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=1000, subsample=0.7; total time=   7.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=5, n_estimators=1350, subsample=0.5; total time=   4.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=5, n_estimators=1350, subsample=0.5; total time=   6.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=5, n_estimators=1350, subsample=0.5; total time=   4.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=5, n_estimators=1350, subsample=0.5; total time=   4.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=4, n_estimators=1100, subsample=0.7; total time=   4.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=4, n_estimators=1100, subsample=0.7; total time=   2.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=4, n_estimators=1100, subsample=0.7; total time=   2.8s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=4, n_estimators=1100, subsample=0.7; total time=   4.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=3, n_estimators=1300, subsample=0.6; total time=   2.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=3, n_estimators=1300, subsample=0.6; total time=   2.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=3, n_estimators=1300, subsample=0.6; total time=   2.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=3, n_estimators=1300, subsample=0.6; total time=   2.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.3, max_depth=2, n_estimators=1350, subsample=0.4; total time=   4.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.3, max_depth=2, n_estimators=1350, subsample=0.4; total time=   2.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.3, max_depth=2, n_estimators=1350, subsample=0.4; total time=   2.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.3, max_depth=2, n_estimators=1350, subsample=0.4; total time=   2.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.01, max_depth=6, n_estimators=1100, subsample=0.4; total time=   6.4s
# [CV] END colsample_bytree=0.6, learning_rate=0.01, max_depth=6, n_estimators=1100, subsample=0.4; total time=   4.6s
# [CV] END colsample_bytree=0.6, learning_rate=0.01, max_depth=6, n_estimators=1100, subsample=0.4; total time=   6.6s
# [CV] END colsample_bytree=0.6, learning_rate=0.01, max_depth=6, n_estimators=1100, subsample=0.4; total time=   4.6s
# [CV] END colsample_bytree=0.2, learning_rate=0.1, max_depth=4, n_estimators=1000, subsample=0.5; total time=   1.8s
# [CV] END colsample_bytree=0.2, learning_rate=0.1, max_depth=4, n_estimators=1000, subsample=0.5; total time=   1.9s
# [CV] END colsample_bytree=0.2, learning_rate=0.1, max_depth=4, n_estimators=1000, subsample=0.5; total time=   3.7s
# [CV] END colsample_bytree=0.2, learning_rate=0.1, max_depth=4, n_estimators=1000, subsample=0.5; total time=   1.8s
# [CV] END colsample_bytree=0.3, learning_rate=0.5, max_depth=4, n_estimators=1000, subsample=0.3; total time=   2.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.5, max_depth=4, n_estimators=1000, subsample=0.3; total time=   2.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.5, max_depth=4, n_estimators=1000, subsample=0.3; total time=   2.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.5, max_depth=4, n_estimators=1000, subsample=0.3; total time=   3.9s
# [CV] END colsample_bytree=0.6, learning_rate=0.5, max_depth=4, n_estimators=1400, subsample=0.6; total time=   3.5s
# [CV] END colsample_bytree=0.6, learning_rate=0.5, max_depth=4, n_estimators=1400, subsample=0.6; total time=   3.6s
# [CV] END colsample_bytree=0.6, learning_rate=0.5, max_depth=4, n_estimators=1400, subsample=0.6; total time=   5.4s
# [CV] END colsample_bytree=0.6, learning_rate=0.5, max_depth=4, n_estimators=1400, subsample=0.6; total time=   3.6s
# [CV] END colsample_bytree=0.6, learning_rate=0.3, max_depth=6, n_estimators=1100, subsample=0.7; total time=   4.8s
# [CV] END colsample_bytree=0.6, learning_rate=0.3, max_depth=6, n_estimators=1100, subsample=0.7; total time=   6.6s
# [CV] END colsample_bytree=0.6, learning_rate=0.3, max_depth=6, n_estimators=1100, subsample=0.7; total time=   5.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.3, max_depth=6, n_estimators=1100, subsample=0.7; total time=   6.7s
# [CV] END colsample_bytree=0.4, learning_rate=0.05, max_depth=5, n_estimators=1200, subsample=0.3; total time=   3.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.05, max_depth=5, n_estimators=1200, subsample=0.3; total time=   3.6s
# [CV] END colsample_bytree=0.4, learning_rate=0.05, max_depth=5, n_estimators=1200, subsample=0.3; total time=   5.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.05, max_depth=5, n_estimators=1200, subsample=0.3; total time=   3.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1600, subsample=0.5; total time=   7.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1600, subsample=0.5; total time=   5.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1600, subsample=0.5; total time=   7.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=1600, subsample=0.5; total time=   5.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=5, n_estimators=1050, subsample=0.6; total time=   5.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=5, n_estimators=1050, subsample=0.6; total time=   3.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=5, n_estimators=1050, subsample=0.6; total time=   3.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=5, n_estimators=1050, subsample=0.6; total time=   3.4s
# [CV] END colsample_bytree=0.3, learning_rate=0.5, max_depth=2, n_estimators=1200, subsample=0.4; total time=   3.4s
# [CV] END colsample_bytree=0.3, learning_rate=0.5, max_depth=2, n_estimators=1200, subsample=0.4; total time=   1.6s
# [CV] END colsample_bytree=0.3, learning_rate=0.5, max_depth=2, n_estimators=1200, subsample=0.4; total time=   1.6s
# [CV] END colsample_bytree=0.3, learning_rate=0.5, max_depth=2, n_estimators=1200, subsample=0.4; total time=   1.6s
# [CV] END colsample_bytree=0.4, learning_rate=0.3, max_depth=5, n_estimators=1150, subsample=0.5; total time=   3.6s
# [CV] END colsample_bytree=0.4, learning_rate=0.3, max_depth=5, n_estimators=1150, subsample=0.5; total time=   5.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.3, max_depth=5, n_estimators=1150, subsample=0.5; total time=   3.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.3, max_depth=5, n_estimators=1150, subsample=0.5; total time=   3.4s
# [CV] END colsample_bytree=0.6, learning_rate=0.3, max_depth=2, n_estimators=1300, subsample=0.7; total time=   3.9s
# [CV] END colsample_bytree=0.6, learning_rate=0.3, max_depth=2, n_estimators=1300, subsample=0.7; total time=   1.9s
# [CV] END colsample_bytree=0.6, learning_rate=0.3, max_depth=2, n_estimators=1300, subsample=0.7; total time=   1.9s
# [CV] END colsample_bytree=0.6, learning_rate=0.3, max_depth=2, n_estimators=1300, subsample=0.7; total time=   1.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=4, n_estimators=1400, subsample=0.4; total time=   5.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=4, n_estimators=1400, subsample=0.4; total time=   3.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=4, n_estimators=1400, subsample=0.4; total time=   3.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=4, n_estimators=1400, subsample=0.4; total time=   5.4s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=4, n_estimators=1300, subsample=0.5; total time=   2.5s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=4, n_estimators=1300, subsample=0.5; total time=   2.5s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=4, n_estimators=1300, subsample=0.5; total time=   2.5s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=4, n_estimators=1300, subsample=0.5; total time=   4.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.5, max_depth=6, n_estimators=1000, subsample=0.5; total time=   4.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.5, max_depth=6, n_estimators=1000, subsample=0.5; total time=   4.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.5, max_depth=6, n_estimators=1000, subsample=0.5; total time=   6.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.5, max_depth=6, n_estimators=1000, subsample=0.5; total time=   4.5s
# [CV] END colsample_bytree=0.6, learning_rate=0.3, max_depth=4, n_estimators=1250, subsample=0.7; total time=   5.2s
# [CV] END colsample_bytree=0.6, learning_rate=0.3, max_depth=4, n_estimators=1250, subsample=0.7; total time=   3.3s
# [CV] END colsample_bytree=0.6, learning_rate=0.3, max_depth=4, n_estimators=1250, subsample=0.7; total time=   3.3s
# [CV] END colsample_bytree=0.6, learning_rate=0.3, max_depth=4, n_estimators=1250, subsample=0.7; total time=   5.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=1450, subsample=0.4; total time=   2.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=1450, subsample=0.4; total time=   2.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=1450, subsample=0.4; total time=   1.9s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=1450, subsample=0.4; total time=   2.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=3, n_estimators=1100, subsample=0.7; total time=   3.8s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=3, n_estimators=1100, subsample=0.7; total time=   1.8s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=3, n_estimators=1100, subsample=0.7; total time=   1.9s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=3, n_estimators=1100, subsample=0.7; total time=   2.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=2, n_estimators=1500, subsample=0.7; total time=   1.9s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=2, n_estimators=1500, subsample=0.7; total time=   2.4s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=2, n_estimators=1500, subsample=0.7; total time=   3.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=2, n_estimators=1500, subsample=0.7; total time=   1.9s
# [CV] END colsample_bytree=0.6, learning_rate=0.03, max_depth=5, n_estimators=1250, subsample=0.3; total time=   4.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.03, max_depth=5, n_estimators=1250, subsample=0.3; total time=   6.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.03, max_depth=5, n_estimators=1250, subsample=0.3; total time=   4.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.03, max_depth=5, n_estimators=1250, subsample=0.3; total time=   4.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=4, n_estimators=1050, subsample=0.3; total time=   4.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=4, n_estimators=1050, subsample=0.3; total time=   2.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=4, n_estimators=1050, subsample=0.3; total time=   2.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=4, n_estimators=1050, subsample=0.3; total time=   2.6s
# [CV] END colsample_bytree=0.4, learning_rate=0.03, max_depth=5, n_estimators=1300, subsample=0.5; total time=   5.6s
# [CV] END colsample_bytree=0.4, learning_rate=0.03, max_depth=5, n_estimators=1300, subsample=0.5; total time=   3.8s
# [CV] END colsample_bytree=0.4, learning_rate=0.03, max_depth=5, n_estimators=1300, subsample=0.5; total time=   5.8s
# [CV] END colsample_bytree=0.4, learning_rate=0.03, max_depth=5, n_estimators=1300, subsample=0.5; total time=   3.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=6, n_estimators=1150, subsample=0.6; total time=   4.9s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=6, n_estimators=1150, subsample=0.6; total time=   6.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=6, n_estimators=1150, subsample=0.6; total time=   4.8s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=6, n_estimators=1150, subsample=0.6; total time=   6.8s
# [CV] END colsample_bytree=0.2, learning_rate=0.5, max_depth=4, n_estimators=1000, subsample=0.7; total time=   1.8s
# [CV] END colsample_bytree=0.2, learning_rate=0.5, max_depth=4, n_estimators=1000, subsample=0.7; total time=   1.8s
# [CV] END colsample_bytree=0.2, learning_rate=0.5, max_depth=4, n_estimators=1000, subsample=0.7; total time=   1.9s
# [CV] END colsample_bytree=0.2, learning_rate=0.5, max_depth=4, n_estimators=1000, subsample=0.7; total time=   3.7s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=1100, subsample=0.4; total time=   4.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=1100, subsample=0.4; total time=   4.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=1100, subsample=0.4; total time=   6.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=1100, subsample=0.4; total time=   4.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=1100, subsample=0.6; total time=   5.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=1100, subsample=0.6; total time=   3.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=1100, subsample=0.6; total time=   3.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=1100, subsample=0.6; total time=   5.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=1300, subsample=0.4; total time=   4.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=1300, subsample=0.4; total time=   4.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=1300, subsample=0.4; total time=   6.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=1300, subsample=0.4; total time=   4.2s
# RandomizedSearchCV(cv=4,
#                    estimator=XGBRegressor(base_score=None, booster=None,
#                                           callbacks=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None, device=None,
#                                           early_stopping_rounds=None,
#                                           enable_categorical=False,
#                                           eval_metric=None, feature_types=None,
#                                           gamma=None, grow_policy=None,
#                                           importance_type=None,
#                                           interaction_constraints=None,
#                                           learning_rate=...
#                    param_distributions={'colsample_bytree': [0.7, 0.6, 0.5, 0.4,
#                                                              0.3, 0.2],
#                                         'learning_rate': [0.01, 0.03, 0.1, 0.3,
#                                                           0.05, 0.5],
#                                         'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x796ef6098810>,
#                                         'n_estimators': [1000, 1050, 1100, 1150,
#                                                          1200, 1250, 1300, 1350,
#                                                          1400, 1450, 1500, 1550,
#                                                          1600],
#                                         'subsample': [0.7, 0.6, 0.5, 0.4, 0.3]},
#                    random_state=42, scoring='neg_root_mean_squared_error',
#                    verbose=2)

# %%
# Get the best parameters and model
best_params_xgb = random_search_xgb.best_params_
best_model_xgb = random_search_xgb.best_estimator_
best_rmse_xgb = -random_search_xgb.best_score_
print("Ridge Regression best params:", best_params_xgb)
print("Ridge Regression best RMSE on validation set: {:.4f}".format(best_rmse_xgb))
# Out:
# Ridge Regression best params: {'colsample_bytree': 0.3, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 1300, 'subsample': 0.5}
# Ridge Regression best RMSE on validation set: 21324.4272

# %%
# Evaluate on the validation set
# val_predictions = best_model.predict(X_val)
# rmse_val = np.sqrt(mean_squared_error(y_val, val_predictions))
# print("Best Parameters:", best_params)
# print("Validation RMSE:", rmse_val)

# %%
# Train the final XGBRegressor using the best parameters
final_model_xgb = xgb.XGBRegressor(**best_params_xgb, objective='reg:squarederror', random_state=42)
final_model_xgb.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.3, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=4, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=1300, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
# Generate predictions for the test set
test_predictions_xgb = final_model_xgb.predict(X_test)

# %%
# Create a submission dataframe (assumes sample_submission.csv expects 'Id' and 'SalePrice')
submission = pd.DataFrame({'Id': test_ids, 'SalePrice': test_predictions_xgb})
submission.to_csv('submission_XGBoost.csv', index=False)

print("Submission file 'submission_XGBoost.csv' created successfully!")
# Out:
# Submission file 'submission_XGBoost.csv' created successfully!

# %% [markdown]
# ## Linear Regression

# %%
param_dist_ridge = {
    'alpha': uniform(0.01, 10)   # Sample alpha between 0.01 and 10
}

# %%
ridge = Ridge()

random_search_ridge = RandomizedSearchCV(
    estimator=ridge,
    param_distributions=param_dist_ridge,
    n_iter=50,
    cv=5,
    scoring='neg_root_mean_squared_error',
    random_state=42,
    n_jobs=1,
    verbose=2,
    return_train_score=True
)

# %%
random_search_ridge.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV] END ...........................alpha=3.7554011884736247; total time=   0.2s
# [CV] END ...........................alpha=3.7554011884736247; total time=   0.0s
# [CV] END ...........................alpha=3.7554011884736247; total time=   0.1s
# [CV] END ...........................alpha=3.7554011884736247; total time=   0.0s
# [CV] END ...........................alpha=3.7554011884736247; total time=   0.0s
# [CV] END .............................alpha=9.51714306409916; total time=   0.2s
# [CV] END .............................alpha=9.51714306409916; total time=   0.0s
# [CV] END .............................alpha=9.51714306409916; total time=   0.0s
# [CV] END .............................alpha=9.51714306409916; total time=   0.0s
# [CV] END .............................alpha=9.51714306409916; total time=   0.0s
# [CV] END ...........................alpha=7.3299394181140505; total time=   0.0s
# [CV] END ...........................alpha=7.3299394181140505; total time=   0.1s
# [CV] END ...........................alpha=7.3299394181140505; total time=   0.0s
# [CV] END ...........................alpha=7.3299394181140505; total time=   0.0s
# [CV] END ...........................alpha=7.3299394181140505; total time=   0.0s
# [CV] END ............................alpha=5.996584841970366; total time=   0.0s
# [CV] END ............................alpha=5.996584841970366; total time=   0.0s
# [CV] END ............................alpha=5.996584841970366; total time=   0.0s
# [CV] END ............................alpha=5.996584841970366; total time=   0.0s
# [CV] END ............................alpha=5.996584841970366; total time=   0.0s
# [CV] END ...........................alpha=1.5701864044243652; total time=   0.0s
# [CV] END ...........................alpha=1.5701864044243652; total time=   0.0s
# [CV] END ...........................alpha=1.5701864044243652; total time=   0.0s
# [CV] END ...........................alpha=1.5701864044243652; total time=   0.0s
# [CV] END ...........................alpha=1.5701864044243652; total time=   0.0s
# [CV] END ...........................alpha=1.5699452033620265; total time=   0.1s
# [CV] END ...........................alpha=1.5699452033620265; total time=   0.0s
# [CV] END ...........................alpha=1.5699452033620265; total time=   0.0s
# [CV] END ...........................alpha=1.5699452033620265; total time=   0.0s
# [CV] END ...........................alpha=1.5699452033620265; total time=   0.0s
# [CV] END ...........................alpha=0.5908361216819946; total time=   0.0s
# [CV] END ...........................alpha=0.5908361216819946; total time=   0.1s
# [CV] END .............................alpha=6.63522284353982; total time=   0.0s
# [CV] END .............................alpha=6.63522284353982; total time=   0.2s
# [CV] END .............................alpha=6.63522284353982; total time=   0.0s
# [CV] END ...........................alpha=3.1271107608941096; total time=   0.0s
# [CV] END ...........................alpha=3.1271107608941096; total time=   0.2s
# [CV] END ...........................alpha=3.1271107608941096; total time=   0.0s
# [CV] END ...........................alpha=3.1271107608941096; total time=   0.0s
# [CV] END ...........................alpha=3.1271107608941096; total time=   0.0s
# [CV] END ............................alpha=5.210680211778108; total time=   0.0s
# [CV] END ............................alpha=5.210680211778108; total time=   0.0s
# [CV] END ............................alpha=5.210680211778108; total time=   0.1s
# [CV] END ............................alpha=5.210680211778108; total time=   0.0s
# [CV] END ............................alpha=5.210680211778108; total time=   0.0s
# [CV] END ............................alpha=5.477102793432796; total time=   0.0s
# [CV] END ............................alpha=5.477102793432796; total time=   0.0s
# [CV] END ............................alpha=5.477102793432796; total time=   0.0s
# [CV] END ............................alpha=5.477102793432796; total time=   0.1s
# [CV] END ............................alpha=5.477102793432796; total time=   0.0s
# [CV] END ...........................alpha=1.8585445552552704; total time=   0.0s
# [CV] END ...........................alpha=1.8585445552552704; total time=   0.0s
# [CV] END ...........................alpha=1.8585445552552704; total time=   0.0s
# [CV] END ...........................alpha=1.8585445552552704; total time=   0.0s
# [CV] END ...........................alpha=1.8585445552552704; total time=   0.0s
# RandomizedSearchCV(cv=5, estimator=Ridge(), n_iter=50, n_jobs=1,
#                    param_distributions={'alpha': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x78ce38c67710>},
#                    random_state=42, return_train_score=True,
#                    scoring='neg_root_mean_squared_error', verbose=2)

# %%
# Best hyperparameters and score (convert negative RMSE to RMSE)
best_params_ridge = random_search_ridge.best_params_
best_rmse_ridge = -random_search_ridge.best_score_
print("Ridge Regression best params:", best_params_ridge)
print("Ridge Regression best RMSE on validation set: {:.4f}".format(best_rmse_ridge))
# Out:
# Ridge Regression best params: {'alpha': 9.709098521619943}
# Ridge Regression best RMSE on validation set: 25950.1214

# %%
# Train final model on the original training set using best hyperparameters
final_ridge = Ridge(**best_params_ridge)
final_ridge.fit(X_train, y_train)
# Out:
# Ridge(alpha=9.709098521619943)

# %%
# Generate predictions for the test set
test_predictions_ridge = final_ridge.predict(X_test)

# %%
# Create a submission dataframe (assumes sample_submission.csv expects 'Id' and 'SalePrice')
submission = pd.DataFrame({'Id': test_ids, 'SalePrice': test_predictions_ridge})
submission.to_csv('submission_ridge.csv', index=False)

print("Submission file 'submission_ridge.csv' created successfully!")
# Out:
# Submission file 'submission_ridge.csv' created successfully!

# %% [markdown]
# ## SVM

# %%
#param_dist_svr = {
#    'C': uniform(0.1, 10),
#    'epsilon': uniform(0.01, 1),
#    'kernel': ['rbf', 'linear']
#}

# %%
param_grid_svr = {
    'C': [0.1, 1, 3, 10],
    'epsilon': [0.01, 0.1, 0.3, 1],
    'kernel': ['rbf', 'linear']
}

# %%
svr = SVR()

# %%
# random_search_svr = RandomizedSearchCV(
#    estimator=svr,
#    param_distributions=param_dist_svr,
#    n_iter=50,
#    cv=5,
#    scoring='neg_root_mean_squared_error',
#    random_state=42,
#    n_jobs=-1,
#    verbose=2,
#    return_train_score=True
#)

# %%
# Set up GridSearchCV
grid_search_svr = GridSearchCV(
    estimator=svr,
    param_grid=param_grid_svr,
    scoring='neg_root_mean_squared_error',
    cv=3,
    verbose=2
)

# %%
grid_search_svr.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 32 candidates, totalling 96 fits
# [CV] END ....................C=0.1, epsilon=0.01, kernel=rbf; total time=   0.3s
# [CV] END ....................C=0.1, epsilon=0.01, kernel=rbf; total time=   0.3s
# [CV] END ....................C=0.1, epsilon=0.01, kernel=rbf; total time=   0.3s
# [CV] END .................C=0.1, epsilon=0.01, kernel=linear; total time=   1.9s
# [CV] END .................C=0.1, epsilon=0.01, kernel=linear; total time=   1.2s
# [CV] END .................C=0.1, epsilon=0.01, kernel=linear; total time=   1.9s
# [CV] END .....................C=0.1, epsilon=0.1, kernel=rbf; total time=   0.4s
# [CV] END .....................C=0.1, epsilon=0.1, kernel=rbf; total time=   0.4s
# [CV] END .....................C=0.1, epsilon=0.1, kernel=rbf; total time=   0.4s
# [CV] END ..................C=0.1, epsilon=0.1, kernel=linear; total time=   2.6s
# [CV] END ..................C=0.1, epsilon=0.1, kernel=linear; total time=   1.2s
# [CV] END ..................C=0.1, epsilon=0.1, kernel=linear; total time=   1.7s
# [CV] END .....................C=0.1, epsilon=0.3, kernel=rbf; total time=   0.3s
# [CV] END .....................C=0.1, epsilon=0.3, kernel=rbf; total time=   0.3s
# [CV] END .....................C=0.1, epsilon=0.3, kernel=rbf; total time=   0.3s
# [CV] END ..................C=0.1, epsilon=0.3, kernel=linear; total time=   1.4s
# [CV] END ..................C=0.1, epsilon=0.3, kernel=linear; total time=   1.2s
# [CV] END ..................C=0.1, epsilon=0.3, kernel=linear; total time=   2.1s
# [CV] END .......................C=0.1, epsilon=1, kernel=rbf; total time=   0.3s
# [CV] END .......................C=0.1, epsilon=1, kernel=rbf; total time=   0.4s
# [CV] END .......................C=0.1, epsilon=1, kernel=rbf; total time=   0.4s
# [CV] END ....................C=0.1, epsilon=1, kernel=linear; total time=   2.4s
# [CV] END ....................C=0.1, epsilon=1, kernel=linear; total time=   1.2s
# [CV] END ....................C=0.1, epsilon=1, kernel=linear; total time=   2.3s
# [CV] END ......................C=1, epsilon=0.01, kernel=rbf; total time=   0.3s
# [CV] END ......................C=1, epsilon=0.01, kernel=rbf; total time=   0.3s
# [CV] END ......................C=1, epsilon=0.01, kernel=rbf; total time=   0.3s
# [CV] END ...................C=1, epsilon=0.01, kernel=linear; total time=   9.7s
# [CV] END ...................C=1, epsilon=0.01, kernel=linear; total time=   6.8s
# [CV] END ...................C=1, epsilon=0.01, kernel=linear; total time=  30.9s
# [CV] END .......................C=1, epsilon=0.1, kernel=rbf; total time=   0.3s
# [CV] END .......................C=1, epsilon=0.1, kernel=rbf; total time=   0.3s
# [CV] END .......................C=1, epsilon=0.1, kernel=rbf; total time=   0.3s
# [CV] END ....................C=1, epsilon=0.1, kernel=linear; total time=   5.8s
# [CV] END ....................C=1, epsilon=0.1, kernel=linear; total time=   9.6s
# [CV] END ....................C=1, epsilon=0.1, kernel=linear; total time=  23.9s
# [CV] END .......................C=1, epsilon=0.3, kernel=rbf; total time=   0.3s
# [CV] END .......................C=1, epsilon=0.3, kernel=rbf; total time=   0.3s
# [CV] END .......................C=1, epsilon=0.3, kernel=rbf; total time=   0.3s
# [CV] END ....................C=1, epsilon=0.3, kernel=linear; total time=   5.8s
# [CV] END ....................C=1, epsilon=0.3, kernel=linear; total time=   9.3s
# [CV] END ....................C=1, epsilon=0.3, kernel=linear; total time=  26.1s
# [CV] END .........................C=1, epsilon=1, kernel=rbf; total time=   0.3s
# [CV] END .........................C=1, epsilon=1, kernel=rbf; total time=   0.3s
# [CV] END .........................C=1, epsilon=1, kernel=rbf; total time=   0.3s
# [CV] END ......................C=1, epsilon=1, kernel=linear; total time=   8.4s
# [CV] END ......................C=1, epsilon=1, kernel=linear; total time=  13.6s
# [CV] END ......................C=1, epsilon=1, kernel=linear; total time=  30.0s
# [CV] END ......................C=3, epsilon=0.01, kernel=rbf; total time=   0.4s
# [CV] END ......................C=3, epsilon=0.01, kernel=rbf; total time=   0.4s
# [CV] END ......................C=3, epsilon=0.01, kernel=rbf; total time=   0.4s
# [CV] END ...................C=3, epsilon=0.01, kernel=linear; total time=  23.9s
# [CV] END ...................C=3, epsilon=0.01, kernel=linear; total time= 1.2min
# [CV] END ...................C=3, epsilon=0.01, kernel=linear; total time=  45.1s
# [CV] END .......................C=3, epsilon=0.1, kernel=rbf; total time=   0.3s
# [CV] END .......................C=3, epsilon=0.1, kernel=rbf; total time=   0.3s
# [CV] END .......................C=3, epsilon=0.1, kernel=rbf; total time=   0.3s
# [CV] END ....................C=3, epsilon=0.1, kernel=linear; total time=  19.9s
# [CV] END ....................C=3, epsilon=0.1, kernel=linear; total time= 1.0min
# [CV] END ....................C=3, epsilon=0.1, kernel=linear; total time=  32.0s
# [CV] END .......................C=3, epsilon=0.3, kernel=rbf; total time=   0.3s
# [CV] END .......................C=3, epsilon=0.3, kernel=rbf; total time=   0.3s
# [CV] END .......................C=3, epsilon=0.3, kernel=rbf; total time=   0.3s
# [CV] END ....................C=3, epsilon=0.3, kernel=linear; total time=  25.5s
# [CV] END ....................C=3, epsilon=0.3, kernel=linear; total time= 1.1min
# [CV] END ....................C=3, epsilon=0.3, kernel=linear; total time=  42.9s
# [CV] END .........................C=3, epsilon=1, kernel=rbf; total time=   0.3s
# [CV] END .........................C=3, epsilon=1, kernel=rbf; total time=   0.3s
# [CV] END .........................C=3, epsilon=1, kernel=rbf; total time=   0.3s
# [CV] END ......................C=3, epsilon=1, kernel=linear; total time=  17.3s
# [CV] END ......................C=3, epsilon=1, kernel=linear; total time=  53.0s
# [CV] END ......................C=3, epsilon=1, kernel=linear; total time=  38.0s
# [CV] END .....................C=10, epsilon=0.01, kernel=rbf; total time=   0.3s
# [CV] END .....................C=10, epsilon=0.01, kernel=rbf; total time=   0.3s
# [CV] END .....................C=10, epsilon=0.01, kernel=rbf; total time=   0.3s
# [CV] END ..................C=10, epsilon=0.01, kernel=linear; total time= 1.4min
# [CV] END ..................C=10, epsilon=0.01, kernel=linear; total time= 3.9min
# [CV] END ..................C=10, epsilon=0.01, kernel=linear; total time= 3.3min
# [CV] END ......................C=10, epsilon=0.1, kernel=rbf; total time=   0.3s
# [CV] END ......................C=10, epsilon=0.1, kernel=rbf; total time=   0.3s
# [CV] END ......................C=10, epsilon=0.1, kernel=rbf; total time=   0.3s
# [CV] END ...................C=10, epsilon=0.1, kernel=linear; total time=  58.4s
# [CV] END ...................C=10, epsilon=0.1, kernel=linear; total time= 4.2min
# [CV] END ...................C=10, epsilon=0.1, kernel=linear; total time= 1.4min
# [CV] END ......................C=10, epsilon=0.3, kernel=rbf; total time=   0.3s
# [CV] END ......................C=10, epsilon=0.3, kernel=rbf; total time=   0.3s
# [CV] END ......................C=10, epsilon=0.3, kernel=rbf; total time=   0.3s
# [CV] END ...................C=10, epsilon=0.3, kernel=linear; total time= 1.0min
# [CV] END ...................C=10, epsilon=0.3, kernel=linear; total time= 4.7min
# [CV] END ...................C=10, epsilon=0.3, kernel=linear; total time= 2.0min
# [CV] END ........................C=10, epsilon=1, kernel=rbf; total time=   0.3s
# [CV] END ........................C=10, epsilon=1, kernel=rbf; total time=   0.3s
# [CV] END ........................C=10, epsilon=1, kernel=rbf; total time=   0.3s
# [CV] END .....................C=10, epsilon=1, kernel=linear; total time= 1.0min
# [CV] END .....................C=10, epsilon=1, kernel=linear; total time= 3.6min
# [CV] END .....................C=10, epsilon=1, kernel=linear; total time= 2.9min
# GridSearchCV(cv=3, estimator=SVR(),
#              param_grid={'C': [0.1, 1, 3, 10], 'epsilon': [0.01, 0.1, 0.3, 1],
#                          'kernel': ['rbf', 'linear']},
#              scoring='neg_root_mean_squared_error', verbose=2)

# %%
# Fit the randomized search on the combined dataset
# random_search_svr.fit(X_train, y_train)

# %%
# best_params_svr = random_search_svr.best_params_
# best_rmse_svr = -random_search_svr.best_score_
# print("SVR best params:", best_params_svr)
# print("SVR best RMSE on validation set: {:.4f}".format(best_rmse_svr))

# %%
best_params_svr = grid_search_svr.best_params_
best_rmse_svr = -grid_search_svr.best_score_
print("Best Parameters:", best_params_svr)
print("Best RMSE:", best_rmse_svr)

# %%
final_svr = SVR(**best_params_svr)
final_svr.fit(X_train, y_train)

# %%
# Generate predictions for the test set
test_predictions_svr = final_svr.predict(X_test)

# %%
submission = pd.DataFrame({'Id': test_ids, 'SalePrice': test_predictions_svr})
submission.to_csv('submission_svr.csv', index=False)

print("Submission file 'submission_svr.csv' created successfully!")

# %% [markdown]
# ## Final Results

# %%
best_models = {
    'Random Forest': random_search.best_estimator_,
    'XGBoost': random_search_xgb.best_estimator_,
    'Linear Regression': random_search_ridge.best_estimator_,
    'SVM': grid_search_svr.best_estimator_
}

# %%
# Prepare a list to store results
results = []

# Evaluate each model on the validation set
for model_name, model in best_models.items():
    y_pred = model.predict(X_val)
    rmse = np.sqrt(mean_squared_error(y_val, y_pred))
    # Convert the best params dictionary to a formatted string for display
    best_params = model.get_params()
    best_params_str = ", ".join([f"{k}={v}" for k, v in best_params.items() if k in best_models[model_name].get_params()])

    results.append({
        'Model': model_name,
        'RMSE': rmse,
        'Best Parameters': best_params_str
    })

# Create a DataFrame to display the results in a table format
results_df = pd.DataFrame(results)
print(results_df)

# %% [markdown]
# ## Final Results

# %%
models = {
    "Random Forest": (random_search.best_estimator_, random_search.best_params_),
    "XGBoost": (random_search_xgb.best_estimator_, random_search_xgb.best_params_),
    "Linear Regression": (random_search_ridge.best_estimator_, random_search_ridge.best_params_),
    "SVM": (grid_search_svr.best_estimator_, grid_search_svr.best_params_)
}

# Prepare a list to store the evaluation results
results = []

# Evaluate each model on the validation set
for model_name, (model, best_params) in models.items():
    # Predict on the validation set
    y_pred = model.predict(X_val)
    # Compute RMSE (ensure it's positive)
    rmse = np.sqrt(mean_squared_error(y_val, y_pred))

    # Append the model results, including the best parameters dictionary
    results.append({
        "Model": model_name,
        "RMSE": rmse,
        "Best Parameters": best_params
    })

# Create a DataFrame to display the results in a neat table
results_df = pd.DataFrame(results)
print(results_df)
