# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_selection import mutual_info_regression, mutual_info_classif
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.decomposition import PCA
from scipy.stats import randint, uniform
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, RandomizedSearchCV, PredefinedSplit, GridSearchCV
from sklearn.linear_model import Ridge, LinearRegression
from sklearn.svm import SVR
import xgboost as xgb
from sklearn.metrics import mean_squared_error

# %%
##############################################################################
# 1) Define global resources so we can reuse the same objects for train & test
##############################################################################

# --- Ordinal mapping for your ordinal columns ---
ordinal_mapping = {
    "GarageQual":    {"Ex": 5, "Gd": 4, "TA": 3, "Fa": 2, "Po": 1, "NA": 0},
    "Fence":         {"GdPrv": 4, "MnPrv": 3, "GdWo": 2, "MnWw": 1, "NA": 0},
    "GarageFinish":  {"Fin": 3, "RFn": 2, "Unf": 1, "NA": 0},
    "KitchenQual":   {"Ex": 4, "Gd": 3, "TA": 2, "Fa": 1, "Po": 0},
    "GarageCond":    {"Ex": 5, "Gd": 4, "TA": 3, "Fa": 2, "Po": 1, "NA": 0},
    "HeatingQC":     {"Ex": 4, "Gd": 3, "TA": 2, "Fa": 1, "Po": 0},
    "ExterQual":     {"Ex": 4, "Gd": 3, "TA": 2, "Fa": 1, "Po": 0},
    "BsmtCond":      {"Ex": 5, "Gd": 4, "TA": 3, "Fa": 2, "Po": 1, "NA": 0},
    "LandSlope":     {"Gtl": 2, "Mod": 1, "Sev": 0},
    "ExterCond":     {"Ex": 4, "Gd": 3, "TA": 2, "Fa": 1, "Po": 0},
    "BsmtExposure":  {"Gd": 4, "Av": 3, "Mn": 2, "No": 1, "NA": 0},
    "PavedDrive":    {"Y": 2, "P": 1, "N": 0},
    "BsmtQual":      {"Ex": 5, "Gd": 4, "TA": 3, "Fa": 2, "Po": 1, "NA": 0},
    "LotShape":      {"Reg": 3, "IR1": 2, "IR2": 1, "IR3": 0},
    "BsmtFinType2":  {"GLQ": 6, "ALQ": 5, "BLQ": 4, "Rec": 3, "LwQ": 2, "Unf": 1, "NA": 0},
    "BsmtFinType1":  {"GLQ": 6, "ALQ": 5, "BLQ": 4, "Rec": 3, "LwQ": 2, "Unf": 1, "NA": 0},
    "FireplaceQu":   {"Ex": 5, "Gd": 4, "TA": 3, "Fa": 2, "Po": 1, "NA": 0},
    "Utilities":     {"AllPub": 3, "NoSewr": 2, "NoSeWa": 1, "ELO": 0},
    "Functional":    {"Typ": 7, "Min1": 6, "Min2": 5, "Mod": 4, "Maj1": 3,
                      "Maj2": 2, "Sev": 1, "Sal": 0},
    "PoolQC":        {"Ex": 5, "Gd": 4, "TA": 3, "Fa": 2, "Po": 1, "NA": 0},
}
# Extract the list of ordinal columns from that mapping
ordinal_cols = list(ordinal_mapping.keys())

# --- Nominal features (for One-Hot Encoding) ---
nominal_features = [
    "MSZoning", "Street", "Alley", "LandContour", "LotConfig", "Neighborhood",
    "Condition1", "Condition2", "BldgType", "HouseStyle", "RoofStyle", "RoofMatl",
    "Exterior1st", "Exterior2nd", "MasVnrType", "Foundation", "Heating",
    "CentralAir", "Electrical", "GarageType", "MiscFeature", "SaleType",
    "SaleCondition"
]

# Create ONE global OrdinalEncoder and ONE global OneHotEncoder.
# We'll fit them on train, then reuse them to transform test.
ordinal_encoder = OrdinalEncoder(
    categories=[list(ordinal_mapping[col].keys()) for col in ordinal_cols],
    handle_unknown="use_encoded_value",
    unknown_value=-1
)
one_hot_encoder = OneHotEncoder(handle_unknown='ignore', sparse_output=False)

##############################################################################
# 2) Main preprocessing function
##############################################################################
def preprocess_data(df, is_train=True):
    """
    Preprocess a housing DataFrame.
    If is_train=True, drops outliers and fits the encoders.
    If is_train=False, only transforms using the fitted encoders (NO outlier removal).

    Returns:
      (X, y) if is_train=True
      X if is_train=False
    """

    # Make a copy so we don't overwrite the original data
    df = df.copy()

    # If this is training data, grab the target 'SalePrice'
    # and remove it from the DataFrame.
    if is_train:
        y = df['SalePrice']
        df.drop('SalePrice', axis=1, inplace=True)
    else:
        y = None  # no target in test set

    # 1) Convert certain columns to numeric if they exist
    cols_to_numeric = [
        "LotFrontage", "MasVnrArea", "BsmtFinSF1", "BsmtFinSF2", "BsmtUnfSF",
        "TotalBsmtSF", "BsmtFullBath", "GarageCars", "BsmtHalfBath", "GarageYrBlt"
    ]
    for col in cols_to_numeric:
        if col in df.columns:
            df[col] = pd.to_numeric(df[col], errors="coerce")

    # 2) Fill numeric columns with 0, categorical with "NA"
    numeric_cols = df.select_dtypes(include=['number']).columns
    df[numeric_cols] = df[numeric_cols].fillna(0)

    # Identify any columns of object/string dtype
    cat_cols = df.select_dtypes(include=['object']).columns
    for cat_col in cat_cols:
        df[cat_col] = df[cat_col].fillna("NA")

    # 3) Feature engineering examples (abbreviated from your original code)
    #    Only do these if the columns exist in df.
    if set(["FullBath","HalfBath","BsmtFullBath","BsmtHalfBath"]).issubset(df.columns):
        df["TotalBath"] = (
            df["FullBath"] +
            0.5 * df["HalfBath"] +
            df["BsmtFullBath"] +
            0.5 * df["BsmtHalfBath"]
        )
    else:
        # If any are missing, you can either create them or skip
        df["TotalBath"] = 0

    if "GarageYrBlt" in df.columns:
        df["Has_garage"] = df["GarageYrBlt"].notnull().astype(int)

    if set(["YrSold","YearBuilt"]).issubset(df.columns):
        df["House_Age"] = df["YrSold"] - df["YearBuilt"]

    if set(["YearBuilt","YearRemodAdd"]).issubset(df.columns):
        df["Is_Remodeled"] = (df["YearBuilt"] != df["YearRemodAdd"]).astype(int)

    # ... etc. for other features from your original code ...
    # e.g., if you want "House_Age2", "GrLivArea" / "LotArea" ratio, etc.

    # 4) Outlier removal: only do this on TRAIN.
    #    Make sure to drop rows from y as well to keep them aligned.
    if is_train:
        # (a) LotFrontage > 200
        if "LotFrontage" in df.columns:
            idx = df[df["LotFrontage"] > 200].index
            df.drop(idx, inplace=True)
            y.drop(idx, inplace=True)

        # (b) LotArea > 100000
        if "LotArea" in df.columns:
            idx = df[df["LotArea"] > 100000].index
            df.drop(idx, inplace=True)
            y.drop(idx, inplace=True)

        # (c) BsmtFinSF1 > 4000
        if "BsmtFinSF1" in df.columns:
            idx = df[df["BsmtFinSF1"] > 4000].index
            df.drop(idx, inplace=True)
            y.drop(idx, inplace=True)

        # (d) TotalBsmtSF > 6000
        if "TotalBsmtSF" in df.columns:
            idx = df[df["TotalBsmtSF"] > 6000].index
            df.drop(idx, inplace=True)
            y.drop(idx, inplace=True)

        # (e) 1stFlrSF > 4000
        if "1stFlrSF" in df.columns:
            idx = df[df["1stFlrSF"] > 4000].index
            df.drop(idx, inplace=True)
            y.drop(idx, inplace=True)

        # (f) GrLivArea > 4000 & y < 300000
        if "GrLivArea" in df.columns:
            idx = df[(df["GrLivArea"] > 4000) & (y < 300000)].index
            df.drop(idx, inplace=True)
            y.drop(idx, inplace=True)

        # (g) LowQualFinSF > 550
        if "LowQualFinSF" in df.columns:
            idx = df[df["LowQualFinSF"] > 550].index
            df.drop(idx, inplace=True)
            y.drop(idx, inplace=True)

    # 5) Ordinal Encoding for the columns in ordinal_mapping
    #    We'll only encode columns that actually exist in df.
    existing_ordinal = [col for col in ordinal_cols if col in df.columns]

    # Clean up whitespace if any
    for col in existing_ordinal:
        df[col] = df[col].astype(str).str.strip()

    # If train: fit_transform
    # If test:  transform only
    if len(existing_ordinal) > 0:
        if is_train:
            df[existing_ordinal] = ordinal_encoder.fit_transform(df[existing_ordinal])
        else:
            df[existing_ordinal] = ordinal_encoder.transform(df[existing_ordinal])
        # Replace unknown encodings (-1) with 0
        df.replace(-1, 0, inplace=True)

    # 6) One-Hot Encoding for nominal features
    existing_nominal = [col for col in nominal_features if col in df.columns]

    if len(existing_nominal) > 0:
        if is_train:
            # Fit on train
            encoded = one_hot_encoder.fit_transform(df[existing_nominal])
        else:
            # Transform test
            encoded = one_hot_encoder.transform(df[existing_nominal])

        # Convert to DataFrame
        encoded_df = pd.DataFrame(
            encoded,
            columns=one_hot_encoder.get_feature_names_out(existing_nominal),
            index=df.index
        )
        # Drop original nominal cols, then join
        df.drop(columns=existing_nominal, inplace=True)
        df = df.join(encoded_df)

    # Return final results
    if is_train:
        return df, y
    else:
        return df

# %%
df_train = pd.read_csv("train.csv")
X_train, y_train = preprocess_data(df_train, is_train=True)

# %%
df_test = pd.read_csv("test.csv")
test_ids = df_test['Id'].copy()
X_test = preprocess_data(df_test, is_train=False)

# %%
print(f"New train shape: {X_train.shape}, test shape: {X_test.shape}")
# Out:
# New train shape: (1452, 230), test shape: (1459, 230)

# %% [markdown]
# ## Random Forest

# %%
# Example parameter distribution:
param_dist = {
    'n_estimators': randint(100, 2000),        # Number of trees
    'max_depth': randint(1, 20),             # Maximum tree depth
    'min_samples_split': randint(2, 20),     # Minimum samples required to split an internal node
    'min_samples_leaf': randint(1, 10),      # Minimum samples required at a leaf node
    'max_features': ['sqrt', 'log2', None], # Number of features to consider at each split
    'criterion': ['squared_error', 'absolute_error'] # For regression
}

# %%
# Initialize the RandomForestRegressor
rf = RandomForestRegressor(bootstrap=True,oob_score=True, random_state=42)

# %%
cv_dummy = [(np.arange(len(X_train)), np.arange(len(X_train)))]
random_search = RandomizedSearchCV(
    estimator=rf,
    param_distributions=param_dist,
    n_iter=50,
    scoring='neg_root_mean_squared_error',
    random_state=42,
    n_jobs=1,
    verbose=2,
    return_train_score=True,
    cv=cv_dummy
)

# %%
random_search.fit(X_train, y_train)
# Out:
# Fitting 1 folds for each of 50 candidates, totalling 50 fits
# [CV] END criterion=squared_error, max_depth=15, max_features=None, min_samples_leaf=8, min_samples_split=8, n_estimators=221; total time=   3.7s
# [CV] END criterion=squared_error, max_depth=11, max_features=None, min_samples_leaf=8, min_samples_split=5, n_estimators=971; total time=  16.5s
# [CV] END criterion=absolute_error, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=3, n_estimators=443; total time=   4.4s
# [CV] END criterion=absolute_error, max_depth=6, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=559; total time=   7.6s
# [CV] END criterion=absolute_error, max_depth=12, max_features=sqrt, min_samples_leaf=1, min_samples_split=11, n_estimators=1599; total time=  48.7s
# [CV] END criterion=absolute_error, max_depth=16, max_features=None, min_samples_leaf=3, min_samples_split=13, n_estimators=1690; total time= 8.5min
# [CV] END criterion=absolute_error, max_depth=3, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=120; total time=   2.0s
# [CV] END criterion=squared_error, max_depth=7, max_features=log2, min_samples_leaf=4, min_samples_split=15, n_estimators=341; total time=   0.7s
# [CV] END criterion=absolute_error, max_depth=9, max_features=log2, min_samples_leaf=5, min_samples_split=3, n_estimators=1463; total time=  21.9s
# [CV] END criterion=absolute_error, max_depth=15, max_features=None, min_samples_leaf=8, min_samples_split=16, n_estimators=134; total time=  33.2s
# [CV] END criterion=absolute_error, max_depth=17, max_features=log2, min_samples_leaf=8, min_samples_split=5, n_estimators=1125; total time=  16.1s
# [CV] END criterion=absolute_error, max_depth=6, max_features=log2, min_samples_leaf=4, min_samples_split=19, n_estimators=829; total time=  11.3s
# [CV] END criterion=absolute_error, max_depth=2, max_features=log2, min_samples_leaf=4, min_samples_split=15, n_estimators=1986; total time=  16.7s
# [CV] END criterion=absolute_error, max_depth=15, max_features=log2, min_samples_leaf=7, min_samples_split=9, n_estimators=1848; total time=  27.0s
# [CV] END criterion=absolute_error, max_depth=13, max_features=log2, min_samples_leaf=5, min_samples_split=14, n_estimators=1164; total time=  17.6s
# [CV] END criterion=squared_error, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=620; total time=   2.2s
# [CV] END criterion=absolute_error, max_depth=1, max_features=None, min_samples_leaf=3, min_samples_split=18, n_estimators=491; total time=  48.0s
# [CV] END criterion=squared_error, max_depth=3, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=330; total time=   0.6s
# [CV] END criterion=absolute_error, max_depth=9, max_features=None, min_samples_leaf=9, min_samples_split=9, n_estimators=879; total time= 3.5min
# [CV] END criterion=absolute_error, max_depth=1, max_features=None, min_samples_leaf=7, min_samples_split=6, n_estimators=198; total time=  18.3s
# [CV] END criterion=absolute_error, max_depth=8, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=1862; total time=  28.5s
# [CV] END criterion=squared_error, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=1128; total time=   3.2s
# [CV] END criterion=absolute_error, max_depth=14, max_features=None, min_samples_leaf=9, min_samples_split=16, n_estimators=1138; total time= 4.6min
# [CV] END criterion=absolute_error, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=1364; total time=  35.2s
# [CV] END criterion=absolute_error, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=848; total time=   9.9s
# [CV] END criterion=squared_error, max_depth=11, max_features=sqrt, min_samples_leaf=4, min_samples_split=14, n_estimators=1283; total time=   3.7s
# [CV] END criterion=squared_error, max_depth=19, max_features=log2, min_samples_leaf=2, min_samples_split=11, n_estimators=656; total time=   1.6s
# [CV] END criterion=absolute_error, max_depth=6, max_features=log2, min_samples_leaf=7, min_samples_split=8, n_estimators=289; total time=   3.9s
# [CV] END criterion=squared_error, max_depth=1, max_features=sqrt, min_samples_leaf=9, min_samples_split=14, n_estimators=1868; total time=   2.8s
# [CV] END criterion=squared_error, max_depth=7, max_features=log2, min_samples_leaf=8, min_samples_split=10, n_estimators=417; total time=   0.8s
# [CV] END criterion=squared_error, max_depth=1, max_features=None, min_samples_leaf=8, min_samples_split=16, n_estimators=1950; total time=   7.4s
# [CV] END criterion=absolute_error, max_depth=9, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=1633; total time=  46.2s
# [CV] END criterion=squared_error, max_depth=2, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=1748; total time=  10.4s
# [CV] END criterion=absolute_error, max_depth=17, max_features=None, min_samples_leaf=1, min_samples_split=3, n_estimators=741; total time= 4.7min
# [CV] END criterion=absolute_error, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=1176; total time=  27.0s
# [CV] END criterion=absolute_error, max_depth=6, max_features=None, min_samples_leaf=4, min_samples_split=12, n_estimators=1307; total time= 5.6min
# [CV] END criterion=squared_error, max_depth=17, max_features=None, min_samples_leaf=6, min_samples_split=6, n_estimators=983; total time=  18.2s
# [CV] END criterion=absolute_error, max_depth=6, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=1247; total time=  19.0s
# [CV] END criterion=squared_error, max_depth=6, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=502; total time=   1.3s
# [CV] END criterion=absolute_error, max_depth=3, max_features=None, min_samples_leaf=3, min_samples_split=8, n_estimators=1943; total time= 6.3min
# [CV] END criterion=squared_error, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=9, n_estimators=740; total time=   2.6s
# [CV] END criterion=squared_error, max_depth=18, max_features=None, min_samples_leaf=3, min_samples_split=8, n_estimators=1887; total time=  39.8s
# [CV] END criterion=absolute_error, max_depth=16, max_features=sqrt, min_samples_leaf=4, min_samples_split=18, n_estimators=101; total time=   2.6s
# [CV] END criterion=squared_error, max_depth=16, max_features=log2, min_samples_leaf=5, min_samples_split=6, n_estimators=1283; total time=   3.0s
# [CV] END criterion=squared_error, max_depth=9, max_features=sqrt, min_samples_leaf=3, min_samples_split=17, n_estimators=307; total time=   0.9s
# [CV] END criterion=squared_error, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=9, n_estimators=1543; total time=   6.0s
# [CV] END criterion=absolute_error, max_depth=8, max_features=log2, min_samples_leaf=3, min_samples_split=17, n_estimators=609; total time=   9.3s
# [CV] END criterion=squared_error, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=437; total time=   1.1s
# [CV] END criterion=absolute_error, max_depth=3, max_features=sqrt, min_samples_leaf=9, min_samples_split=5, n_estimators=260; total time=   4.1s
# [CV] END criterion=absolute_error, max_depth=1, max_features=log2, min_samples_leaf=5, min_samples_split=17, n_estimators=1627; total time=   9.9s
# RandomizedSearchCV(cv=[(array([   0,    1,    2, ..., 1449, 1450, 1451]),
#                         array([   0,    1,    2, ..., 1449, 1450, 1451]))],
#                    estimator=RandomForestRegressor(oob_score=True,
#                                                    random_state=42),
#                    n_iter=50, n_jobs=1,
#                    param_distributions={'criterion': ['squared_error',
#                                                       'absolute_error'],
#                                         'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x7c4ab1a848d0>,
#                                         'max_features': [...
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x7c4ab0ae41d0>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x7c4ab0ae6990>,
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x7c4ab0b08ed0>},
#                    random_state=42, return_train_score=True,
#                    scoring='neg_root_mean_squared_error', verbose=2)

# %%
# Get the best parameters and model
best_params = random_search.best_params_
best_model = random_search.best_estimator_
best_rmse = -random_search.best_score_
print("Ridge Regression best params:", best_params)
print("Ridge Regression best RMSE on validation set: {:.4f}".format(best_rmse))
# Out:
# Ridge Regression best params: {'criterion': 'absolute_error', 'max_depth': 17, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 741}
# Ridge Regression best RMSE on validation set: 10127.9483

# %%
# Train a final RandomForestRegressor using the best parameters
final_model = RandomForestRegressor(**best_params,bootstrap=True,oob_score=True, random_state=42)
final_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(criterion='absolute_error', max_depth=17,
#                       max_features=None, min_samples_split=3, n_estimators=741,
#                       oob_score=True, random_state=42)

# %%
# Generate predictions for the test set
test_predictions = final_model.predict(X_test)

# %%
# Create a submission dataframe (assuming the sample_submission.csv expects 'Id' and 'SalePrice')
submission = pd.DataFrame({'Id': test_ids, 'SalePrice': test_predictions})
submission.to_csv('submission_Random_forest.csv', index=False)

print("Submission file 'submission.csv' created successfully!")
# Out:
# Submission file 'submission.csv' created successfully!

# %% [markdown]
# ## XGBOOST

# %%
X, X_val, y, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
param_grid = {
    'n_estimators': randint(50, 500),
    'max_depth': randint(1, 20),
    'learning_rate': uniform(0.01, 0.3),
    'subsample': uniform(0.5, 0.5),   # or (0.5, 0.5) means range [0.5..1.0]
    'colsample_bytree': uniform(0.5, 0.5),
}

# %%
xgb_reg = xgb.XGBRegressor(
    objective='reg:squarederror',
    random_state=42,
    # If you want bagging-like behavior in each tree:
    # subsample=0.8, colsample_bytree=0.8,  # or tune them in param_grid
)

# %%
# Set up RandomizedSearchCV using negative RMSE as the scoring metric
random_search_xgb = RandomizedSearchCV(estimator=xgb_reg,
                                   param_distributions=param_grid,
                                   n_iter=50,
                                   cv=3,
                                   scoring='neg_root_mean_squared_error',
                                   random_state=42,
                                   n_jobs=1,
                                   verbose=2)

# %%
# Run the search
random_search_xgb.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# [CV] END colsample_bytree=0.6872700594236812, learning_rate=0.2952142919229748, max_depth=11, n_estimators=121, subsample=0.7993292420985183; total time=   2.7s
# [CV] END colsample_bytree=0.6872700594236812, learning_rate=0.2952142919229748, max_depth=11, n_estimators=121, subsample=0.7993292420985183; total time=   1.3s
# [CV] END colsample_bytree=0.6872700594236812, learning_rate=0.2952142919229748, max_depth=11, n_estimators=121, subsample=0.7993292420985183; total time=   1.3s
# [CV] END colsample_bytree=0.5780093202212182, learning_rate=0.05679835610086079, max_depth=11, n_estimators=137, subsample=0.6668543055695109; total time=   1.4s
# [CV] END colsample_bytree=0.5780093202212182, learning_rate=0.05679835610086079, max_depth=11, n_estimators=137, subsample=0.6668543055695109; total time=   1.1s
# [CV] END colsample_bytree=0.5780093202212182, learning_rate=0.05679835610086079, max_depth=11, n_estimators=137, subsample=0.6668543055695109; total time=   1.1s
# [CV] END colsample_bytree=0.5714334089609704, learning_rate=0.20526654188465587, max_depth=2, n_estimators=393, subsample=0.9162213204002109; total time=   0.4s
# [CV] END colsample_bytree=0.5714334089609704, learning_rate=0.20526654188465587, max_depth=2, n_estimators=393, subsample=0.9162213204002109; total time=   0.4s
# [CV] END colsample_bytree=0.5714334089609704, learning_rate=0.20526654188465587, max_depth=2, n_estimators=393, subsample=0.9162213204002109; total time=   0.5s
# [CV] END colsample_bytree=0.6061695553391381, learning_rate=0.06454749016213018, max_depth=1, n_estimators=363, subsample=0.762378215816119; total time=   0.4s
# [CV] END colsample_bytree=0.6061695553391381, learning_rate=0.06454749016213018, max_depth=1, n_estimators=363, subsample=0.762378215816119; total time=   0.4s
# [CV] END colsample_bytree=0.6061695553391381, learning_rate=0.06454749016213018, max_depth=1, n_estimators=363, subsample=0.762378215816119; total time=   0.4s
# [CV] END colsample_bytree=0.7159725093210578, learning_rate=0.09736874205941257, max_depth=10, n_estimators=237, subsample=0.6831809216468459; total time=   2.9s
# [CV] END colsample_bytree=0.7159725093210578, learning_rate=0.09736874205941257, max_depth=10, n_estimators=237, subsample=0.6831809216468459; total time=   1.9s
# [CV] END colsample_bytree=0.7159725093210578, learning_rate=0.09736874205941257, max_depth=10, n_estimators=237, subsample=0.6831809216468459; total time=   1.7s
# [CV] END colsample_bytree=0.728034992108518, learning_rate=0.24555278841790407, max_depth=19, n_estimators=413, subsample=0.7571172192068059; total time=   5.7s
# [CV] END colsample_bytree=0.728034992108518, learning_rate=0.24555278841790407, max_depth=19, n_estimators=413, subsample=0.7571172192068059; total time=   6.8s
# [CV] END colsample_bytree=0.728034992108518, learning_rate=0.24555278841790407, max_depth=19, n_estimators=413, subsample=0.7571172192068059; total time=   5.2s
# [CV] END colsample_bytree=0.7962072844310213, learning_rate=0.02393512381599932, max_depth=19, n_estimators=184, subsample=0.5852620618436457; total time=   4.3s
# [CV] END colsample_bytree=0.7962072844310213, learning_rate=0.02393512381599932, max_depth=19, n_estimators=184, subsample=0.5852620618436457; total time=   2.8s
# [CV] END colsample_bytree=0.7962072844310213, learning_rate=0.02393512381599932, max_depth=19, n_estimators=184, subsample=0.5852620618436457; total time=   2.8s
# [CV] END colsample_bytree=0.5325257964926398, learning_rate=0.29466566117599996, max_depth=14, n_estimators=291, subsample=0.692708251269958; total time=   3.7s
# [CV] END colsample_bytree=0.5325257964926398, learning_rate=0.29466566117599996, max_depth=14, n_estimators=291, subsample=0.692708251269958; total time=   2.6s
# [CV] END colsample_bytree=0.5325257964926398, learning_rate=0.29466566117599996, max_depth=14, n_estimators=291, subsample=0.692708251269958; total time=   2.5s
# [CV] END colsample_bytree=0.5079831261101071, learning_rate=0.0792681476866447, max_depth=15, n_estimators=493, subsample=0.5610191174223894; total time=   4.6s
# [CV] END colsample_bytree=0.5079831261101071, learning_rate=0.0792681476866447, max_depth=15, n_estimators=493, subsample=0.5610191174223894; total time=   5.2s
# [CV] END colsample_bytree=0.5079831261101071, learning_rate=0.0792681476866447, max_depth=15, n_estimators=493, subsample=0.5610191174223894; total time=   4.2s
# [CV] END colsample_bytree=0.7475884550556351, learning_rate=0.02031655633456552, max_depth=14, n_estimators=130, subsample=0.6293899908000085; total time=   1.8s
# [CV] END colsample_bytree=0.7475884550556351, learning_rate=0.02031655633456552, max_depth=14, n_estimators=130, subsample=0.6293899908000085; total time=   2.9s
# [CV] END colsample_bytree=0.7475884550556351, learning_rate=0.02031655633456552, max_depth=14, n_estimators=130, subsample=0.6293899908000085; total time=   1.7s
# [CV] END colsample_bytree=0.831261142176991, learning_rate=0.10351332282682328, max_depth=6, n_estimators=103, subsample=0.7733551396716398; total time=   0.4s
# [CV] END colsample_bytree=0.831261142176991, learning_rate=0.10351332282682328, max_depth=6, n_estimators=103, subsample=0.7733551396716398; total time=   0.4s
# [CV] END colsample_bytree=0.831261142176991, learning_rate=0.10351332282682328, max_depth=6, n_estimators=103, subsample=0.7733551396716398; total time=   0.6s
# [CV] END colsample_bytree=0.5924272277627636, learning_rate=0.30087538832936755, max_depth=12, n_estimators=211, subsample=0.6975751180009072; total time=   1.8s
# [CV] END colsample_bytree=0.5924272277627636, learning_rate=0.30087538832936755, max_depth=12, n_estimators=211, subsample=0.6975751180009072; total time=   1.9s
# [CV] END colsample_bytree=0.5924272277627636, learning_rate=0.30087538832936755, max_depth=12, n_estimators=211, subsample=0.6975751180009072; total time=   2.1s
# [CV] END colsample_bytree=0.9633294328968971, learning_rate=0.22818159875692626, max_depth=15, n_estimators=264, subsample=0.7604171300129119; total time=   4.4s
# [CV] END colsample_bytree=0.9633294328968971, learning_rate=0.22818159875692626, max_depth=15, n_estimators=264, subsample=0.7604171300129119; total time=   3.7s
# [CV] END colsample_bytree=0.9633294328968971, learning_rate=0.22818159875692626, max_depth=15, n_estimators=264, subsample=0.7604171300129119; total time=   4.3s
# [CV] END colsample_bytree=0.9805860121746746, learning_rate=0.2633601546034454, max_depth=13, n_estimators=387, subsample=0.7698460661945399; total time=   3.7s
# [CV] END colsample_bytree=0.9805860121746746, learning_rate=0.2633601546034454, max_depth=13, n_estimators=387, subsample=0.7698460661945399; total time=   4.0s
# [CV] END colsample_bytree=0.9805860121746746, learning_rate=0.2633601546034454, max_depth=13, n_estimators=387, subsample=0.7698460661945399; total time=   4.9s
# [CV] END colsample_bytree=0.7933755828319241, learning_rate=0.2995765921792414, max_depth=13, n_estimators=90, subsample=0.6481367528520412; total time=   1.1s
# [CV] END colsample_bytree=0.7933755828319241, learning_rate=0.2995765921792414, max_depth=13, n_estimators=90, subsample=0.6481367528520412; total time=   1.1s
# [CV] END colsample_bytree=0.7933755828319241, learning_rate=0.2995765921792414, max_depth=13, n_estimators=90, subsample=0.6481367528520412; total time=   1.0s
# [CV] END colsample_bytree=0.5826334695315012, learning_rate=0.01469092202235818, max_depth=9, n_estimators=393, subsample=0.6974407590877849; total time=   2.4s
# [CV] END colsample_bytree=0.5826334695315012, learning_rate=0.01469092202235818, max_depth=9, n_estimators=393, subsample=0.6974407590877849; total time=   2.7s
# [CV] END colsample_bytree=0.5826334695315012, learning_rate=0.01469092202235818, max_depth=9, n_estimators=393, subsample=0.6974407590877849; total time=   3.6s
# [CV] END colsample_bytree=0.6467440873590191, learning_rate=0.014223946814525337, max_depth=19, n_estimators=130, subsample=0.855670976374325; total time=   2.0s
# [CV] END colsample_bytree=0.6467440873590191, learning_rate=0.014223946814525337, max_depth=19, n_estimators=130, subsample=0.855670976374325; total time=   2.0s
# [CV] END colsample_bytree=0.6467440873590191, learning_rate=0.014223946814525337, max_depth=19, n_estimators=130, subsample=0.855670976374325; total time=   1.9s
# [CV] END colsample_bytree=0.8950877702656028, learning_rate=0.19178799243430342, max_depth=10, n_estimators=280, subsample=0.8255385127509722; total time=   3.8s
# [CV] END colsample_bytree=0.8950877702656028, learning_rate=0.19178799243430342, max_depth=10, n_estimators=280, subsample=0.8255385127509722; total time=   2.7s
# [CV] END colsample_bytree=0.8950877702656028, learning_rate=0.19178799243430342, max_depth=10, n_estimators=280, subsample=0.8255385127509722; total time=   2.7s
# [CV] END colsample_bytree=0.9574798377718904, learning_rate=0.2650115733369398, max_depth=12, n_estimators=467, subsample=0.5477050582452057; total time=   3.4s
# [CV] END colsample_bytree=0.9574798377718904, learning_rate=0.2650115733369398, max_depth=12, n_estimators=467, subsample=0.5477050582452057; total time=   5.0s
# [CV] END colsample_bytree=0.9574798377718904, learning_rate=0.2650115733369398, max_depth=12, n_estimators=467, subsample=0.5477050582452057; total time=   3.9s
# [CV] END colsample_bytree=0.6854091260991332, learning_rate=0.2106523757990822, max_depth=5, n_estimators=148, subsample=0.7956488938538635; total time=   0.4s
# [CV] END colsample_bytree=0.6854091260991332, learning_rate=0.2106523757990822, max_depth=5, n_estimators=148, subsample=0.7956488938538635; total time=   0.4s
# [CV] END colsample_bytree=0.6854091260991332, learning_rate=0.2106523757990822, max_depth=5, n_estimators=148, subsample=0.7956488938538635; total time=   0.4s
# [CV] END colsample_bytree=0.6373608964950321, learning_rate=0.17837302775431035, max_depth=3, n_estimators=150, subsample=0.9858560476945519; total time=   0.4s
# [CV] END colsample_bytree=0.6373608964950321, learning_rate=0.17837302775431035, max_depth=3, n_estimators=150, subsample=0.9858560476945519; total time=   0.3s
# [CV] END colsample_bytree=0.6373608964950321, learning_rate=0.17837302775431035, max_depth=3, n_estimators=150, subsample=0.9858560476945519; total time=   0.3s
# [CV] END colsample_bytree=0.9244569121330419, learning_rate=0.22651885634946198, max_depth=14, n_estimators=408, subsample=0.5202167947692157; total time=   5.5s
# [CV] END colsample_bytree=0.9244569121330419, learning_rate=0.22651885634946198, max_depth=14, n_estimators=408, subsample=0.5202167947692157; total time=   3.7s
# [CV] END colsample_bytree=0.9244569121330419, learning_rate=0.22651885634946198, max_depth=14, n_estimators=408, subsample=0.5202167947692157; total time=   3.8s
# [CV] END colsample_bytree=0.8553314448428937, learning_rate=0.0432672462435494, max_depth=13, n_estimators=228, subsample=0.5157145928433671; total time=   3.2s
# [CV] END colsample_bytree=0.8553314448428937, learning_rate=0.0432672462435494, max_depth=13, n_estimators=228, subsample=0.5157145928433671; total time=   2.3s
# [CV] END colsample_bytree=0.8553314448428937, learning_rate=0.0432672462435494, max_depth=13, n_estimators=228, subsample=0.5157145928433671; total time=   2.3s
# [CV] END colsample_bytree=0.8182052056318903, learning_rate=0.104306794322898, max_depth=4, n_estimators=271, subsample=0.5696657272029378; total time=   0.6s
# [CV] END colsample_bytree=0.8182052056318903, learning_rate=0.104306794322898, max_depth=4, n_estimators=271, subsample=0.5696657272029378; total time=   0.6s
# [CV] END colsample_bytree=0.8182052056318903, learning_rate=0.104306794322898, max_depth=4, n_estimators=271, subsample=0.5696657272029378; total time=   0.5s
# [CV] END colsample_bytree=0.8022086896389087, learning_rate=0.17195232739050195, max_depth=4, n_estimators=62, subsample=0.5384899549143964; total time=   0.2s
# [CV] END colsample_bytree=0.8022086896389087, learning_rate=0.17195232739050195, max_depth=4, n_estimators=62, subsample=0.5384899549143964; total time=   0.2s
# [CV] END colsample_bytree=0.8022086896389087, learning_rate=0.17195232739050195, max_depth=4, n_estimators=62, subsample=0.5384899549143964; total time=   0.5s
# [CV] END colsample_bytree=0.6448757264568841, learning_rate=0.058366386176201324, max_depth=2, n_estimators=219, subsample=0.9040601897822085; total time=   0.4s
# [CV] END colsample_bytree=0.6448757264568841, learning_rate=0.058366386176201324, max_depth=2, n_estimators=219, subsample=0.9040601897822085; total time=   0.3s
# [CV] END colsample_bytree=0.6448757264568841, learning_rate=0.058366386176201324, max_depth=2, n_estimators=219, subsample=0.9040601897822085; total time=   0.6s
# [CV] END colsample_bytree=0.8167018782552118, learning_rate=0.2714381770563153, max_depth=12, n_estimators=93, subsample=0.7082549739351831; total time=   2.1s
# [CV] END colsample_bytree=0.8167018782552118, learning_rate=0.2714381770563153, max_depth=12, n_estimators=93, subsample=0.7082549739351831; total time=   1.1s
# [CV] END colsample_bytree=0.8167018782552118, learning_rate=0.2714381770563153, max_depth=12, n_estimators=93, subsample=0.7082549739351831; total time=   1.0s
# [CV] END colsample_bytree=0.9416401294594341, learning_rate=0.10730350630158218, max_depth=7, n_estimators=239, subsample=0.5550259622638384; total time=   1.2s
# [CV] END colsample_bytree=0.9416401294594341, learning_rate=0.10730350630158218, max_depth=7, n_estimators=239, subsample=0.5550259622638384; total time=   1.2s
# [CV] END colsample_bytree=0.9416401294594341, learning_rate=0.10730350630158218, max_depth=7, n_estimators=239, subsample=0.5550259622638384; total time=   1.1s
# [CV] END colsample_bytree=0.6139675812709708, learning_rate=0.1381323365878769, max_depth=13, n_estimators=282, subsample=0.6523906290790145; total time=   2.6s
# [CV] END colsample_bytree=0.6139675812709708, learning_rate=0.1381323365878769, max_depth=13, n_estimators=282, subsample=0.6523906290790145; total time=   3.9s
# [CV] END colsample_bytree=0.6139675812709708, learning_rate=0.1381323365878769, max_depth=13, n_estimators=282, subsample=0.6523906290790145; total time=   2.6s
# [CV] END colsample_bytree=0.5823279265714709, learning_rate=0.1702268258126326, max_depth=5, n_estimators=274, subsample=0.5599326836668415; total time=   0.6s
# [CV] END colsample_bytree=0.5823279265714709, learning_rate=0.1702268258126326, max_depth=5, n_estimators=274, subsample=0.5599326836668415; total time=   0.8s
# [CV] END colsample_bytree=0.5823279265714709, learning_rate=0.1702268258126326, max_depth=5, n_estimators=274, subsample=0.5599326836668415; total time=   0.6s
# [CV] END colsample_bytree=0.668807585701814, learning_rate=0.29287291117375575, max_depth=9, n_estimators=229, subsample=0.681814801189647; total time=   1.6s
# [CV] END colsample_bytree=0.668807585701814, learning_rate=0.29287291117375575, max_depth=9, n_estimators=229, subsample=0.681814801189647; total time=   1.6s
# [CV] END colsample_bytree=0.668807585701814, learning_rate=0.29287291117375575, max_depth=9, n_estimators=229, subsample=0.681814801189647; total time=   2.7s
# [CV] END colsample_bytree=0.9858910413604803, learning_rate=0.2987341884826334, max_depth=7, n_estimators=435, subsample=0.856135294962221; total time=   2.1s
# [CV] END colsample_bytree=0.9858910413604803, learning_rate=0.2987341884826334, max_depth=7, n_estimators=435, subsample=0.856135294962221; total time=   2.1s
# [CV] END colsample_bytree=0.9858910413604803, learning_rate=0.2987341884826334, max_depth=7, n_estimators=435, subsample=0.856135294962221; total time=   1.9s
# [CV] END colsample_bytree=0.5740434649766999, learning_rate=0.30932214551468257, max_depth=17, n_estimators=51, subsample=0.7513395116144308; total time=   0.8s
# [CV] END colsample_bytree=0.5740434649766999, learning_rate=0.30932214551468257, max_depth=17, n_estimators=51, subsample=0.7513395116144308; total time=   0.8s
# [CV] END colsample_bytree=0.5740434649766999, learning_rate=0.30932214551468257, max_depth=17, n_estimators=51, subsample=0.7513395116144308; total time=   0.7s
# [CV] END colsample_bytree=0.5257393756249946, learning_rate=0.09359393927098342, max_depth=1, n_estimators=434, subsample=0.6197809453334862; total time=   0.4s
# [CV] END colsample_bytree=0.5257393756249946, learning_rate=0.09359393927098342, max_depth=1, n_estimators=434, subsample=0.6197809453334862; total time=   0.4s
# [CV] END colsample_bytree=0.5257393756249946, learning_rate=0.09359393927098342, max_depth=1, n_estimators=434, subsample=0.6197809453334862; total time=   0.6s
# [CV] END colsample_bytree=0.5724474360456115, learning_rate=0.1568358280832689, max_depth=6, n_estimators=465, subsample=0.7963483619396967; total time=   2.3s
# [CV] END colsample_bytree=0.5724474360456115, learning_rate=0.1568358280832689, max_depth=6, n_estimators=465, subsample=0.7963483619396967; total time=   1.2s
# [CV] END colsample_bytree=0.5724474360456115, learning_rate=0.1568358280832689, max_depth=6, n_estimators=465, subsample=0.7963483619396967; total time=   1.2s
# [CV] END colsample_bytree=0.5404266631663577, learning_rate=0.12089633681842132, max_depth=17, n_estimators=304, subsample=0.9015698781899479; total time=   3.9s
# [CV] END colsample_bytree=0.5404266631663577, learning_rate=0.12089633681842132, max_depth=17, n_estimators=304, subsample=0.9015698781899479; total time=   5.3s
# [CV] END colsample_bytree=0.5404266631663577, learning_rate=0.12089633681842132, max_depth=17, n_estimators=304, subsample=0.9015698781899479; total time=   3.7s
# [CV] END colsample_bytree=0.7351503172230192, learning_rate=0.3050269422684529, max_depth=11, n_estimators=289, subsample=0.8991725624922755; total time=   2.4s
# [CV] END colsample_bytree=0.7351503172230192, learning_rate=0.3050269422684529, max_depth=11, n_estimators=289, subsample=0.8991725624922755; total time=   2.2s
# [CV] END colsample_bytree=0.7351503172230192, learning_rate=0.3050269422684529, max_depth=11, n_estimators=289, subsample=0.8991725624922755; total time=   3.4s
# [CV] END colsample_bytree=0.5753587719827147, learning_rate=0.1624596330222156, max_depth=16, n_estimators=398, subsample=0.9291794024068599; total time=   4.2s
# [CV] END colsample_bytree=0.5753587719827147, learning_rate=0.1624596330222156, max_depth=16, n_estimators=398, subsample=0.9291794024068599; total time=   4.3s
# [CV] END colsample_bytree=0.5753587719827147, learning_rate=0.1624596330222156, max_depth=16, n_estimators=398, subsample=0.9291794024068599; total time=   5.0s
# [CV] END colsample_bytree=0.6629794526009424, learning_rate=0.07607231426966449, max_depth=3, n_estimators=196, subsample=0.6743329936458646; total time=   0.3s
# [CV] END colsample_bytree=0.6629794526009424, learning_rate=0.07607231426966449, max_depth=3, n_estimators=196, subsample=0.6743329936458646; total time=   0.3s
# [CV] END colsample_bytree=0.6629794526009424, learning_rate=0.07607231426966449, max_depth=3, n_estimators=196, subsample=0.6743329936458646; total time=   0.5s
# [CV] END colsample_bytree=0.5480882755457104, learning_rate=0.2921569793468812, max_depth=8, n_estimators=177, subsample=0.75887567526374; total time=   0.9s
# [CV] END colsample_bytree=0.5480882755457104, learning_rate=0.2921569793468812, max_depth=8, n_estimators=177, subsample=0.75887567526374; total time=   0.9s
# [CV] END colsample_bytree=0.5480882755457104, learning_rate=0.2921569793468812, max_depth=8, n_estimators=177, subsample=0.75887567526374; total time=   0.8s
# [CV] END colsample_bytree=0.918855052953664, learning_rate=0.2127070351117842, max_depth=18, n_estimators=200, subsample=0.770723986913783; total time=   4.4s
# [CV] END colsample_bytree=0.918855052953664, learning_rate=0.2127070351117842, max_depth=18, n_estimators=200, subsample=0.770723986913783; total time=   3.2s
# [CV] END colsample_bytree=0.918855052953664, learning_rate=0.2127070351117842, max_depth=18, n_estimators=200, subsample=0.770723986913783; total time=   3.0s
# [CV] END colsample_bytree=0.847892199672541, learning_rate=0.0785650065391899, max_depth=16, n_estimators=395, subsample=0.9910841716647179; total time=   7.3s
# [CV] END colsample_bytree=0.847892199672541, learning_rate=0.0785650065391899, max_depth=16, n_estimators=395, subsample=0.9910841716647179; total time=   6.4s
# [CV] END colsample_bytree=0.847892199672541, learning_rate=0.0785650065391899, max_depth=16, n_estimators=395, subsample=0.9910841716647179; total time=   7.4s
# [CV] END colsample_bytree=0.7583179456355071, learning_rate=0.0882487524491227, max_depth=1, n_estimators=353, subsample=0.9827096756443968; total time=   0.3s
# [CV] END colsample_bytree=0.7583179456355071, learning_rate=0.0882487524491227, max_depth=1, n_estimators=353, subsample=0.9827096756443968; total time=   0.4s
# [CV] END colsample_bytree=0.7583179456355071, learning_rate=0.0882487524491227, max_depth=1, n_estimators=353, subsample=0.9827096756443968; total time=   0.3s
# [CV] END colsample_bytree=0.7791467268035488, learning_rate=0.2747909029568019, max_depth=9, n_estimators=282, subsample=0.6746047873063304; total time=   1.9s
# [CV] END colsample_bytree=0.7791467268035488, learning_rate=0.2747909029568019, max_depth=9, n_estimators=282, subsample=0.6746047873063304; total time=   2.2s
# [CV] END colsample_bytree=0.7791467268035488, learning_rate=0.2747909029568019, max_depth=9, n_estimators=282, subsample=0.6746047873063304; total time=   3.0s
# [CV] END colsample_bytree=0.8629778394351197, learning_rate=0.27913307798577314, max_depth=1, n_estimators=457, subsample=0.9254642243837563; total time=   0.4s
# [CV] END colsample_bytree=0.8629778394351197, learning_rate=0.27913307798577314, max_depth=1, n_estimators=457, subsample=0.9254642243837563; total time=   0.4s
# [CV] END colsample_bytree=0.8629778394351197, learning_rate=0.27913307798577314, max_depth=1, n_estimators=457, subsample=0.9254642243837563; total time=   0.4s
# [CV] END colsample_bytree=0.9678174971104738, learning_rate=0.24560219533418307, max_depth=8, n_estimators=389, subsample=0.7903433107182274; total time=   2.3s
# [CV] END colsample_bytree=0.9678174971104738, learning_rate=0.24560219533418307, max_depth=8, n_estimators=389, subsample=0.7903433107182274; total time=   2.3s
# [CV] END colsample_bytree=0.9678174971104738, learning_rate=0.24560219533418307, max_depth=8, n_estimators=389, subsample=0.7903433107182274; total time=   2.4s
# [CV] END colsample_bytree=0.6861413832808716, learning_rate=0.29204003273733353, max_depth=18, n_estimators=433, subsample=0.6526819301721967; total time=   6.2s
# [CV] END colsample_bytree=0.6861413832808716, learning_rate=0.29204003273733353, max_depth=18, n_estimators=433, subsample=0.6526819301721967; total time=   5.2s
# [CV] END colsample_bytree=0.6861413832808716, learning_rate=0.29204003273733353, max_depth=18, n_estimators=433, subsample=0.6526819301721967; total time=   5.7s
# [CV] END colsample_bytree=0.7428068767931133, learning_rate=0.1445272428958742, max_depth=9, n_estimators=210, subsample=0.5090376818077604; total time=   1.3s
# [CV] END colsample_bytree=0.7428068767931133, learning_rate=0.1445272428958742, max_depth=9, n_estimators=210, subsample=0.5090376818077604; total time=   1.3s
# [CV] END colsample_bytree=0.7428068767931133, learning_rate=0.1445272428958742, max_depth=9, n_estimators=210, subsample=0.5090376818077604; total time=   1.2s
# [CV] END colsample_bytree=0.7469468575917173, learning_rate=0.06364681276639864, max_depth=8, n_estimators=184, subsample=0.8604699621260646; total time=   1.3s
# [CV] END colsample_bytree=0.7469468575917173, learning_rate=0.06364681276639864, max_depth=8, n_estimators=184, subsample=0.8604699621260646; total time=   2.2s
# [CV] END colsample_bytree=0.7469468575917173, learning_rate=0.06364681276639864, max_depth=8, n_estimators=184, subsample=0.8604699621260646; total time=   1.0s
# [CV] END colsample_bytree=0.6540303959261946, learning_rate=0.1727620691664698, max_depth=19, n_estimators=424, subsample=0.6252309093027921; total time=   5.1s
# [CV] END colsample_bytree=0.6540303959261946, learning_rate=0.1727620691664698, max_depth=19, n_estimators=424, subsample=0.6252309093027921; total time=   6.3s
# [CV] END colsample_bytree=0.6540303959261946, learning_rate=0.1727620691664698, max_depth=19, n_estimators=424, subsample=0.6252309093027921; total time=   4.9s
# RandomizedSearchCV(cv=3,
#                    estimator=XGBRegressor(base_score=None, booster=None,
#                                           callbacks=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None, device=None,
#                                           early_stopping_rounds=None,
#                                           enable_categorical=False,
#                                           eval_metric=None, feature_types=None,
#                                           gamma=None, grow_policy=None,
#                                           importance_type=None,
#                                           interaction_constraints=None,
#                                           learning_rate=...
#                                         'learning_rate': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7c4a9d1f0910>,
#                                         'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x7c4a9d1f3b50>,
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x7c4a9d1f2e90>,
#                                         'subsample': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7c4a9d1aed10>},
#                    random_state=42, scoring='neg_root_mean_squared_error',
#                    verbose=2)

# %%
# Get the best parameters and model
best_params_xgb = random_search_xgb.best_params_
best_model_xgb = random_search_xgb.best_estimator_
best_rmse_xgb = -random_search.best_score_
print("Ridge Regression best params:", best_params_xgb)
print("Ridge Regression best RMSE on validation set: {:.4f}".format(best_rmse_xgb))
# Out:
# Ridge Regression best params: {'colsample_bytree': 0.6629794526009424, 'learning_rate': 0.07607231426966449, 'max_depth': 3, 'n_estimators': 196, 'subsample': 0.6743329936458646}
# Ridge Regression best RMSE on validation set: 10127.9483

# %%
# Evaluate on the validation set
# val_predictions = best_model.predict(X_val)
# rmse_val = np.sqrt(mean_squared_error(y_val, val_predictions))
# print("Best Parameters:", best_params)
# print("Validation RMSE:", rmse_val)

# %%
# Train the final XGBRegressor using the best parameters
final_model_xgb = xgb.XGBRegressor(**best_params_xgb, objective='reg:squarederror', random_state=42)
final_model_xgb.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.6629794526009424, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.07607231426966449, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=196, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
# Generate predictions for the test set
test_predictions_xgb = final_model_xgb.predict(X_test)

# %%
# Create a submission dataframe (assumes sample_submission.csv expects 'Id' and 'SalePrice')
submission = pd.DataFrame({'Id': test_ids, 'SalePrice': test_predictions_xgb})
submission.to_csv('submission_XGBoost.csv', index=False)

print("Submission file 'submission_XGBoost.csv' created successfully!")
# Out:
# Submission file 'submission_XGBoost.csv' created successfully!

# %% [markdown]
# ## Linear Regression

# %%
param_dist_ridge = {
    'alpha': uniform(0.01, 10)   # Sample alpha between 0.01 and 10
}

# %%
ridge = Ridge()

random_search_ridge = RandomizedSearchCV(
    estimator=ridge,
    param_distributions=param_dist_ridge,
    n_iter=50,
    cv=5,
    scoring='neg_root_mean_squared_error',
    random_state=42,
    n_jobs=1,
    verbose=2,
    return_train_score=True
)

# %%
random_search_ridge.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV]
pha': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7c4a9cccd990>},
#                    random_state=42, return_train_score=True,
#                    scoring='neg_root_mean_squared_error', verbose=2)

# %%
# Best hyperparameters and score (convert negative RMSE to RMSE)
best_params_ridge = random_search_ridge.best_params_
best_rmse_ridge = -random_search_ridge.best_score_
print("Ridge Regression best params:", best_params_ridge)
print("Ridge Regression best RMSE on validation set: {:.4f}".format(best_rmse_ridge))
# Out:
# Ridge Regression best params: {'alpha': 9.709098521619943}
# Ridge Regression best RMSE on validation set: 25950.1214

# %%
# Train final model on the original training set using best hyperparameters
final_ridge = Ridge(**best_params_ridge)
final_ridge.fit(X_train, y_train)
# Out:
# Ridge(alpha=9.709098521619943)

# %%
# Generate predictions for the test set
test_predictions_ridge = final_ridge.predict(X_test)

# %%
# Create a submission dataframe (assumes sample_submission.csv expects 'Id' and 'SalePrice')
submission = pd.DataFrame({'Id': test_ids, 'SalePrice': test_predictions_ridge})
submission.to_csv('submission_ridge.csv', index=False)

print("Submission file 'submission_ridge.csv' created successfully!")
# Out:
# Submission file 'submission_ridge.csv' created successfully!

# %% [markdown]
# ## SVM

# %%
#param_dist_svr = {
#    'C': uniform(0.1, 10),
#    'epsilon': uniform(0.01, 1),
#    'kernel': ['rbf', 'linear']
#}

# %%
param_grid_svr = {
    'C': [0.1, 1, 3, 10],
    'epsilon': [0.01, 0.1, 0.3, 1],
    'kernel': ['rbf', 'linear']
}

# %%
svr = SVR()

# %%
# random_search_svr = RandomizedSearchCV(
#    estimator=svr,
#    param_distributions=param_dist_svr,
#    n_iter=50,
#    cv=5,
#    scoring='neg_root_mean_squared_error',
#    random_state=42,
#    n_jobs=-1,
#    verbose=2,
#    return_train_score=True
#)

# %%
# Set up GridSearchCV
grid_search_svr = GridSearchCV(
    estimator=svr,
    param_grid=param_grid_svr,
    scoring='neg_root_mean_squared_error',
    cv=3,
    verbose=2
)

# %%
grid_search_svr.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 32 candidates, totalling 96 fits
# [CV] END ....................C=0.1, epsilon=0.01, kernel=rbf; total time=   0.2s
# [CV] END ....................C=0.1, epsilon=0.01, kernel=rbf; total time=   0.2s
# [CV] END ....................C=0.1, epsilon=0.01, kernel=rbf; total time=   0.1s
# [CV] END .................C=0.1, epsilon=0.01, kernel=linear; total time=   1.1s
# [CV] END .................C=0.1, epsilon=0.01, kernel=linear; total time=   0.6s
# [CV] END .................C=0.1, epsilon=0.01, kernel=linear; total time=   1.1s
# [CV] END .....................C=0.1, epsilon=0.1, kernel=rbf; total time=   0.2s
# [CV] END .....................C=0.1, epsilon=0.1, kernel=rbf; total time=   0.2s
# [CV] END .....................C=0.1, epsilon=0.1, kernel=rbf; total time=   0.2s
# [CV] END ..................C=0.1, epsilon=0.1, kernel=linear; total time=   1.4s
# [CV] END ..................C=0.1, epsilon=0.1, kernel=linear; total time=   0.7s
# [CV] END ..................C=0.1, epsilon=0.1, kernel=linear; total time=   1.0s
# [CV] END .....................C=0.1, epsilon=0.3, kernel=rbf; total time=   0.1s
# [CV] END .....................C=0.1, epsilon=0.3, kernel=rbf; total time=   0.1s
# [CV] END .....................C=0.1, epsilon=0.3, kernel=rbf; total time=   0.1s
# [CV] END ..................C=0.1, epsilon=0.3, kernel=linear; total time=   0.8s
# [CV] END ..................C=0.1, epsilon=0.3, kernel=linear; total time=   0.7s
# [CV] END ..................C=0.1, epsilon=0.3, kernel=linear; total time=   1.2s
# [CV] END .......................C=0.1, epsilon=1, kernel=rbf; total time=   0.1s
# [CV] END .......................C=0.1, epsilon=1, kernel=rbf; total time=   0.1s
# [CV] END .......................C=0.1, epsilon=1, kernel=rbf; total time=   0.1s
# [CV] END ....................C=0.1, epsilon=1, kernel=linear; total time=   0.8s
# [CV] END ....................C=0.1, epsilon=1, kernel=linear; total time=   0.6s
# [CV] END ....................C=0.1, epsilon=1, kernel=linear; total time=   1.3s
# [CV] END ......................C=1, epsilon=0.01, kernel=rbf; total time=   0.1s
# [CV] END ......................C=1, epsilon=0.01, kernel=rbf; total time=   0.1s
# [CV] END ......................C=1, epsilon=0.01, kernel=rbf; total time=   0.1s
# [CV] END ...................C=1, epsilon=0.01, kernel=linear; total time=   5.0s
# [CV] END ...................C=1, epsilon=0.01, kernel=linear; total time=   3.6s
# [CV] END ...................C=1, epsilon=0.01, kernel=linear; total time=  15.8s
# [CV] END .......................C=1, epsilon=0.1, kernel=rbf; total time=   0.2s
# [CV] END .......................C=1, epsilon=0.1, kernel=rbf; total time=   0.2s
# [CV] END .......................C=1, epsilon=0.1, kernel=rbf; total time=   0.2s
# [CV] END ....................C=1, epsilon=0.1, kernel=linear; total time=   3.3s
# [CV] END ....................C=1, epsilon=0.1, kernel=linear; total time=   4.4s
# [CV] END ....................C=1, epsilon=0.1, kernel=linear; total time=  12.5s
# [CV] END .......................C=1, epsilon=0.3, kernel=rbf; total time=   0.1s
# [CV] END .......................C=1, epsilon=0.3, kernel=rbf; total time=   0.1s
# [CV] END .......................C=1, epsilon=0.3, kernel=rbf; total time=   0.1s
# [CV] END ....................C=1, epsilon=0.3, kernel=linear; total time=   3.6s
# [CV] END ....................C=1, epsilon=0.3, kernel=linear; total time=   4.5s
# [CV] END ....................C=1, epsilon=0.3, kernel=linear; total time=  13.6s
# [CV] END .........................C=1, epsilon=1, kernel=rbf; total time=   0.2s
# [CV] END .........................C=1, epsilon=1, kernel=rbf; total time=   0.1s
# [CV] END .........................C=1, epsilon=1, kernel=rbf; total time=   0.1s
# [CV] END ......................C=1, epsilon=1, kernel=linear; total time=   4.3s
# [CV] END ......................C=1, epsilon=1, kernel=linear; total time=   6.6s
# [CV] END ......................C=1, epsilon=1, kernel=linear; total time=  16.2s
# [CV] END ......................C=3, epsilon=0.01, kernel=rbf; total time=   0.1s
# [CV] END ......................C=3, epsilon=0.01, kernel=rbf; total time=   0.1s
# [CV] END ......................C=3, epsilon=0.01, kernel=rbf; total time=   0.1s
# [CV] END ...................C=3, epsilon=0.01, kernel=linear; total time=  11.6s
# [CV] END ...................C=3, epsilon=0.01, kernel=linear; total time=  39.0s
# [CV] END ...................C=3, epsilon=0.01, kernel=linear; total time=  23.8s
# [CV] END .......................C=3, epsilon=0.1, kernel=rbf; total time=   0.1s
# [CV] END .......................C=3, epsilon=0.1, kernel=rbf; total time=   0.1s
# [CV] END .......................C=3, epsilon=0.1, kernel=rbf; total time=   0.1s
# [CV] END ....................C=3, epsilon=0.1, kernel=linear; total time=  10.4s
# [CV] END ....................C=3, epsilon=0.1, kernel=linear; total time=  33.6s
# [CV] END ....................C=3, epsilon=0.1, kernel=linear; total time=  17.4s
# [CV] END .......................C=3, epsilon=0.3, kernel=rbf; total time=   0.2s
# [CV] END .......................C=3, epsilon=0.3, kernel=rbf; total time=   0.1s
# [CV] END .......................C=3, epsilon=0.3, kernel=rbf; total time=   0.2s
# [CV] END ....................C=3, epsilon=0.3, kernel=linear; total time=  12.7s
# [CV] END ....................C=3, epsilon=0.3, kernel=linear; total time=  36.4s
# [CV] END ....................C=3, epsilon=0.3, kernel=linear; total time=  23.0s
# [CV] END .........................C=3, epsilon=1, kernel=rbf; total time=   0.1s
# [CV] END .........................C=3, epsilon=1, kernel=rbf; total time=   0.1s
# [CV] END .........................C=3, epsilon=1, kernel=rbf; total time=   0.1s
# [CV] END ......................C=3, epsilon=1, kernel=linear; total time=   9.3s
# [CV] END ......................C=3, epsilon=1, kernel=linear; total time=  28.1s
# [CV] END ......................C=3, epsilon=1, kernel=linear; total time=  20.4s
# [CV] END .....................C=10, epsilon=0.01, kernel=rbf; total time=   0.1s
# [CV] END .....................C=10, epsilon=0.01, kernel=rbf; total time=   0.1s
# [CV] END .....................C=10, epsilon=0.01, kernel=rbf; total time=   0.1s
# [CV] END ..................C=10, epsilon=0.01, kernel=linear; total time=  43.3s
# [CV] END ..................C=10, epsilon=0.01, kernel=linear; total time= 2.1min
# [CV] END ..................C=10, epsilon=0.01, kernel=linear; total time= 1.8min
# [CV] END ......................C=10, epsilon=0.1, kernel=rbf; total time=   0.1s
# [CV] END ......................C=10, epsilon=0.1, kernel=rbf; total time=   0.1s
# [CV] END ......................C=10, epsilon=0.1, kernel=rbf; total time=   0.1s
# [CV] END ...................C=10, epsilon=0.1, kernel=linear; total time=  30.9s
# [CV] END ...................C=10, epsilon=0.1, kernel=linear; total time= 2.3min
# [CV] END ...................C=10, epsilon=0.1, kernel=linear; total time=  44.2s
# [CV] END ......................C=10, epsilon=0.3, kernel=rbf; total time=   0.2s
# [CV] END ......................C=10, epsilon=0.3, kernel=rbf; total time=   0.2s
# [CV] END ......................C=10, epsilon=0.3, kernel=rbf; total time=   0.2s
# [CV] END ...................C=10, epsilon=0.3, kernel=linear; total time=  31.6s
# [CV] END ...................C=10, epsilon=0.3, kernel=linear; total time= 2.5min
# [CV] END ...................C=10, epsilon=0.3, kernel=linear; total time= 1.1min
# [CV] END ........................C=10, epsilon=1, kernel=rbf; total time=   0.1s
# [CV] END ........................C=10, epsilon=1, kernel=rbf; total time=   0.1s
# [CV] END ........................C=10, epsilon=1, kernel=rbf; total time=   0.1s
# [CV] END .....................C=10, epsilon=1, kernel=linear; total time=  32.2s
# [CV] END .....................C=10, epsilon=1, kernel=linear; total time= 2.0min
# [CV] END .....................C=10, epsilon=1, kernel=linear; total time= 1.6min
# GridSearchCV(cv=3, estimator=SVR(),
#              param_grid={'C': [0.1, 1, 3, 10], 'epsilon': [0.01, 0.1, 0.3, 1],
#                          'kernel': ['rbf', 'linear']},
#              scoring='neg_root_mean_squared_error', verbose=2)

# %%
# Fit the randomized search on the combined dataset
# random_search_svr.fit(X_train, y_train)

# %%
# best_params_svr = random_search_svr.best_params_
# best_rmse_svr = -random_search_svr.best_score_
# print("SVR best params:", best_params_svr)
# print("SVR best RMSE on validation set: {:.4f}".format(best_rmse_svr))

# %%
best_params_svr = grid_search_svr.best_params_
best_rmse_svr = -grid_search_svr.best_score_
print("Best Parameters:", best_params_svr)
print("Best RMSE:", best_rmse_svr)
# Out:
# Best Parameters: {'C': 10, 'epsilon': 0.01, 'kernel': 'linear'}
# Best RMSE: 33373.708739748916

# %%
final_svr = SVR(**best_params_svr)
final_svr.fit(X_train, y_train)
# Out:
# SVR(C=10, epsilon=0.01, kernel='linear')

# %%
# Generate predictions for the test set
test_predictions_svr = final_svr.predict(X_test)

# %%
submission = pd.DataFrame({'Id': test_ids, 'SalePrice': test_predictions_svr})
submission.to_csv('submission_svr.csv', index=False)

print("Submission file 'submission_svr.csv' created successfully!")
# Out:
# Submission file 'submission_svr.csv' created successfully!

# %% [markdown]
# ## Final Results

# %%
best_models = {
    'Random Forest': random_search.best_estimator_,
    'XGBoost': random_search_xgb.best_estimator_,
    'Linear Regression': random_search_ridge.best_estimator_,
    'SVM': grid_search_svr.best_estimator_
}

# %%
# Prepare a list to store results
results = []

# Evaluate each model on the validation set
for model_name, model in best_models.items():
    y_pred = model.predict(X_val)
    rmse = np.sqrt(mean_squared_error(y_val, y_pred))
    # Convert the best params dictionary to a formatted string for display
    best_params = model.get_params()
    best_params_str = ", ".join([f"{k}={v}" for k, v in best_params.items() if k in best_models[model_name].get_params()])

    results.append({
        'Model': model_name,
        'RMSE': rmse,
        'Best Parameters': best_params_str
    })

# Create a DataFrame to display the results in a table format
results_df = pd.DataFrame(results)
print(results_df)
# Out:
#                Model          RMSE  \
# 0      Random Forest   9280.205315
# 1            XGBoost  13002.850149
# 2  Linear Regression  21946.317519
# 3                SVM  26600.682989
#
#                                      Best Parameters
# 0  bootstrap=True, ccp_alpha=0.0, criterion=absol...
# 1  objective=reg:squarederror, base_score=None, b...
# 2  alpha=9.709098521619943, copy_X=True, fit_inte...
# 3  C=10, cache_size=200, coef0=0.0, degree=3, eps...

# %% [markdown]
# ## Final Results

# %%
models = {
    "Random Forest": (random_search.best_estimator_, random_search.best_params_),
    "XGBoost": (random_search_xgb.best_estimator_, random_search_xgb.best_params_),
    "Linear Regression": (random_search_ridge.best_estimator_, random_search_ridge.best_params_),
    "SVM": (grid_search_svr.best_estimator_, grid_search_svr.best_params_)
}

# Prepare a list to store the evaluation results
results = []

# Evaluate each model on the validation set
for model_name, (model, best_params) in models.items():
    # Predict on the validation set
    y_pred = model.predict(X_val)
    # Compute RMSE (ensure it's positive)
    rmse = np.sqrt(mean_squared_error(y_val, y_pred))

    # Append the model results, including the best parameters dictionary
    results.append({
        "Model": model_name,
        "RMSE": rmse,
        "Best Parameters": best_params
    })

# Create a DataFrame to display the results in a neat table
results_df = pd.DataFrame(results)
print(results_df)
# Out:
#                Model          RMSE  \
# 0      Random Forest   9280.205315
# 1            XGBoost  13002.850149
# 2  Linear Regression  21946.317519
# 3                SVM  26600.682989
#
#                                      Best Parameters
# 0  {'criterion': 'absolute_error', 'max_depth': 1...
# 1  {'colsample_bytree': 0.6629794526009424, 'lear...
# 2                       {'alpha': 9.709098521619943}
# 3     {'C': 10, 'epsilon': 0.01, 'kernel': 'linear'}
