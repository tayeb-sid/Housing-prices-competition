# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV
import joblib
from sklearn.metrics import mean_squared_log_error
from scipy.stats import randint, uniform

# %%
import numpy as np
import pandas as pd
import joblib
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, mean_squared_log_error
from scipy.stats import randint

# Load the datasets
train = pd.read_csv("../bilel/final_data_nv.csv")
test = pd.read_csv("../bilel/final_test_data_nv.csv")
sample_submission = pd.read_csv("../home-data-for-ml-course/sample_submission.csv")

# Define Features (X) and Target (y)
y_train = train["SalePrice"]  # Target variable
X_train = train.drop(columns=["SalePrice"])  # Remove target from train data

X_test = test.copy()  # Keep test dataset separate

# Define Hyperparameter Grid for RandomizedSearchCV
param_dist = {
    'n_estimators': randint(100, 2000),        # Number of trees
    'max_depth': randint(1, 20),               # Maximum tree depth
    'min_samples_split': randint(2, 20),       # Minimum samples required to split an internal node
    'min_samples_leaf': randint(1, 10),        # Minimum samples required at a leaf node
    'max_features': ['sqrt', 'log2', None],    # Number of features to consider at each split
    'criterion': ['squared_error', 'absolute_error']  # For regression
}

# Initialize the RandomForestRegressor
rf = RandomForestRegressor(bootstrap=True, oob_score=True, random_state=42)

random_search = RandomizedSearchCV(
    estimator=rf,
    param_distributions=param_dist,
    n_iter=50,
    scoring='neg_root_mean_squared_error',
    random_state=42,
    n_jobs=-1,
    verbose=2,
    return_train_score=True,
    cv=3  # Using cross-validation of 3 folds instead of dummy cv
)

# Fit RandomizedSearchCV
random_search.fit(X_train, y_train)

# Get the best parameters and model
best_params = random_search.best_params_
best_model = random_search.best_estimator_
best_rmse = -random_search.best_score_
print("Best Parameters Found:", best_params)
print("Best RMSE on validation set: {:.4f}".format(best_rmse))

# Train a final RandomForestRegressor using the best parameters
final_model = RandomForestRegressor(**best_params, bootstrap=True, oob_score=True, random_state=42)
final_model.fit(X_train, y_train)

# Evaluate Model on Training Data
y_train_pred = final_model.predict(X_train)
train_r2 = r2_score(y_train, y_train_pred)
train_mae = mean_absolute_error(y_train, y_train_pred)
train_rmse = np.sqrt(mean_squared_error(y_train, y_train_pred))
train_rmsle = np.sqrt(mean_squared_log_error(y_train, np.maximum(y_train_pred, 0)))

# Display Model Performance
print("\n Model Performance on Training Set:")
print(f" Training R² Score: {train_r2:.4f}")
print(f" Training MAE: {train_mae:.2f}")
print(f" Training RMSE: {train_rmse:.2f}")
print(f" Training RMSLE: {train_rmsle:.4f}")
# Remplir les NaN avec la médiane pour les colonnes numériques

X_train = X_train.fillna(X_train.median())
X_test = X_test.fillna(X_test.median())

# Make Predictions on Test Set
y_test_pred = final_model.predict(X_test)

# Prepare Submission File
submission = pd.DataFrame({"Id": sample_submission["Id"], "SalePrice": y_test_pred})
submission.to_csv("submission_final_nouveau.csv", index=False)
print("\n Predictions saved to submission_final_billal.csv ")

# Save the trained model
joblib.dump(final_model, 'best_model.pkl')
print("Model saved as best_model.pkl")
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# [CV] END criterion=squared_error, max_depth=15, max_features=None, min_samples_leaf=8, min_samples_split=8, n_estimators=221; total time=   2.3s
# [CV] END criterion=squared_error, max_depth=15, max_features=None, min_samples_leaf=8, min_samples_split=8, n_estimators=221; total time=   2.3s
# [CV] END criterion=squared_error, max_depth=15, max_features=None, min_samples_leaf=8, min_samples_split=8, n_estimators=221; total time=   2.3s
# [CV] END criterion=absolute_error, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=3, n_estimators=443; total time=   4.0s
# [CV] END criterion=absolute_error, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=3, n_estimators=443; total time=   3.9s
# [CV] END criterion=absolute_error, max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=3, n_estimators=443; total time=   3.8s
# [CV] END criterion=absolute_error, max_depth=6, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=559; total time=   6.2s
# [CV] END criterion=absolute_error, max_depth=6, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=559; total time=   6.2s
# [CV] END criterion=squared_error, max_depth=11, max_features=None, min_samples_leaf=8, min_samples_split=5, n_estimators=971; total time=   9.9s
# [CV] END criterion=squared_error, max_depth=11, max_features=None, min_samples_leaf=8, min_samples_split=5, n_estimators=971; total time=   9.8s
# [CV] END criterion=squared_error, max_depth=11, max_features=None, min_samples_leaf=8, min_samples_split=5, n_estimators=971; total time=  10.0s
# [CV] END criterion=absolute_error, max_depth=6, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=559; total time=   6.0s
# [CV] END criterion=absolute_error, max_depth=3, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=120; total time=   1.3s
# [CV] END criterion=absolute_error, max_depth=3, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=120; total time=   1.3s
# [CV] END criterion=squared_error, max_depth=7, max_features=log2, min_samples_leaf=4, min_samples_split=15, n_estimators=341; total time=   0.6s
# [CV] END criterion=squared_error, max_depth=7, max_features=log2, min_samples_leaf=4, min_samples_split=15, n_estimators=341; total time=   0.6s
# [CV] END criterion=absolute_error, max_depth=3, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=120; total time=   1.4s
# [CV] END criterion=squared_error, max_depth=7, max_features=log2, min_samples_leaf=4, min_samples_split=15, n_estimators=341; total time=   0.6s
# [CV] END criterion=absolute_error, max_depth=9, max_features=log2, min_samples_leaf=5, min_samples_split=3, n_estimators=1463; total time=  16.4s
# [CV] END criterion=absolute_error, max_depth=9, max_features=log2, min_samples_leaf=5, min_samples_split=3, n_estimators=1463; total time=  16.2s
# [CV] END criterion=absolute_error, max_depth=12, max_features=sqrt, min_samples_leaf=1, min_samples_split=11, n_estimators=1599; total time=  28.9s
# [CV] END criterion=absolute_error, max_depth=12, max_features=sqrt, min_samples_leaf=1, min_samples_split=11, n_estimators=1599; total time=  28.6s
# [CV] END criterion=absolute_error, max_depth=12, max_features=sqrt, min_samples_leaf=1, min_samples_split=11, n_estimators=1599; total time=  28.6s
# [CV] END criterion=absolute_error, max_depth=15, max_features=None, min_samples_leaf=8, min_samples_split=16, n_estimators=134; total time=  14.5s
# [CV] END criterion=absolute_error, max_depth=9, max_features=log2, min_samples_leaf=5, min_samples_split=3, n_estimators=1463; total time=  16.4s
# [CV] END criterion=absolute_error, max_depth=15, max_features=None, min_samples_leaf=8, min_samples_split=16, n_estimators=134; total time=  14.5s
# [CV] END criterion=absolute_error, max_depth=15, max_features=None, min_samples_leaf=8, min_samples_split=16, n_estimators=134; total time=  14.4s
# [CV] END criterion=absolute_error, max_depth=17, max_features=log2, min_samples_leaf=8, min_samples_split=5, n_estimators=1125; total time=  11.8s
# [CV] END criterion=absolute_error, max_depth=17, max_features=log2, min_samples_leaf=8, min_samples_split=5, n_estimators=1125; total time=  11.8s
# [CV] END criterion=absolute_error, max_depth=6, max_features=log2, min_samples_leaf=4, min_samples_split=19, n_estimators=829; total time=   8.7s
# [CV] END criterion=absolute_error, max_depth=6, max_features=log2, min_samples_leaf=4, min_samples_split=19, n_estimators=829; total time=   8.6s
# [CV] END criterion=absolute_error, max_depth=17, max_features=log2, min_samples_leaf=8, min_samples_split=5, n_estimators=1125; total time=  11.8s
# [CV] END criterion=absolute_error, max_depth=6, max_features=log2, min_samples_leaf=4, min_samples_split=19, n_estimators=829; total time=   8.8s
# [CV] END criterion=absolute_error, max_depth=2, max_features=log2, min_samples_leaf=4, min_samples_split=15, n_estimators=1986; total time=  13.0s
# [CV] END criterion=absolute_error, max_depth=2, max_features=log2, min_samples_leaf=4, min_samples_split=15, n_estimators=1986; total time=  12.8s
# [CV] END criterion=absolute_error, max_depth=2, max_features=log2, min_samples_leaf=4, min_samples_split=15, n_estimators=1986; total time=  12.9s
# [CV] END criterion=absolute_error, max_depth=15, max_features=log2, min_samples_leaf=7, min_samples_split=9, n_estimators=1848; total time=  20.1s
# [CV] END criterion=absolute_error, max_depth=15, max_features=log2, min_samples_leaf=7, min_samples_split=9, n_estimators=1848; total time=  20.0s
# [CV] END criterion=squared_error, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=620; total time=   1.7s
# [CV] END criterion=squared_error, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=620; total time=   1.6s
# [CV] END criterion=absolute_error, max_depth=13, max_features=log2, min_samples_leaf=5, min_samples_split=14, n_estimators=1164; total time=  13.5s
# [CV] END criterion=squared_error, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=620; total time=   1.8s
# [CV] END criterion=absolute_error, max_depth=13, max_features=log2, min_samples_leaf=5, min_samples_split=14, n_estimators=1164; total time=  13.3s
# [CV] END criterion=absolute_error, max_depth=15, max_features=log2, min_samples_leaf=7, min_samples_split=9, n_estimators=1848; total time=  20.3s
# [CV] END criterion=squared_error, max_depth=3, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=330; total time=   0.5s
# [CV] END criterion=squared_error, max_depth=3, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=330; total time=   0.5s
# [CV] END criterion=squared_error, max_depth=3, max_features=sqrt, min_samples_leaf=5, min_samples_split=11, n_estimators=330; total time=   0.5s
# [CV] END criterion=absolute_error, max_depth=13, max_features=log2, min_samples_leaf=5, min_samples_split=14, n_estimators=1164; total time=  13.5s
# [CV] END criterion=absolute_error, max_depth=1, max_features=None, min_samples_leaf=3, min_samples_split=18, n_estimators=491; total time=  20.4s
# [CV] END criterion=absolute_error, max_depth=1, max_features=None, min_samples_leaf=3, min_samples_split=18, n_estimators=491; total time=  20.2s
# [CV] END criterion=absolute_error, max_depth=1, max_features=None, min_samples_leaf=3, min_samples_split=18, n_estimators=491; total time=  20.3s
# [CV] END criterion=absolute_error, max_depth=1, max_features=None, min_samples_leaf=7, min_samples_split=6, n_estimators=198; total time=   8.0s
# [CV] END criterion=absolute_error, max_depth=1, max_features=None, min_samples_leaf=7, min_samples_split=6, n_estimators=198; total time=   8.0s
# [CV] END criterion=absolute_error, max_depth=1, max_features=None, min_samples_leaf=7, min_samples_split=6, n_estimators=198; total time=   8.0s
# [CV] END criterion=absolute_error, max_depth=8, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=1862; total time=  21.5s
# [CV] END criterion=absolute_error, max_depth=8, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=1862; total time=  21.2s
# [CV] END criterion=squared_error, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=1128; total time=   2.4s
# [CV] END criterion=squared_error, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=1128; total time=   2.5s
# [CV] END criterion=squared_error, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=1128; total time=   2.4s
# [CV] END criterion=absolute_error, max_depth=8, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=1862; total time=  21.7s
# [CV] END criterion=absolute_error, max_depth=9, max_features=None, min_samples_leaf=9, min_samples_split=9, n_estimators=879; total time= 1.6min
# [CV] END criterion=absolute_error, max_depth=9, max_features=None, min_samples_leaf=9, min_samples_split=9, n_estimators=879; total time= 1.6min
# [CV] END criterion=absolute_error, max_depth=9, max_features=None, min_samples_leaf=9, min_samples_split=9, n_estimators=879; total time= 1.5min
# [CV] END criterion=absolute_error, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=1364; total time=  22.8s
# [CV] END criterion=absolute_error, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=1364; total time=  22.6s
# [CV] END criterion=absolute_error, max_depth=16, max_features=None, min_samples_leaf=3, min_samples_split=13, n_estimators=1690; total time= 3.6min
# [CV] END criterion=absolute_error, max_depth=16, max_features=None, min_samples_leaf=3, min_samples_split=13, n_estimators=1690; total time= 3.6min
# [CV] END criterion=absolute_error, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=848; total time=   7.9s
# [CV] END criterion=absolute_error, max_depth=16, max_features=None, min_samples_leaf=3, min_samples_split=13, n_estimators=1690; total time= 3.7min
# [CV] END criterion=squared_error, max_depth=11, max_features=sqrt, min_samples_leaf=4, min_samples_split=14, n_estimators=1283; total time=   2.9s
# [CV] END criterion=absolute_error, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=1364; total time=  23.0s
# [CV] END criterion=squared_error, max_depth=11, max_features=sqrt, min_samples_leaf=4, min_samples_split=14, n_estimators=1283; total time=   2.9s
# [CV] END criterion=squared_error, max_depth=11, max_features=sqrt, min_samples_leaf=4, min_samples_split=14, n_estimators=1283; total time=   2.9s
# [CV] END criterion=squared_error, max_depth=19, max_features=log2, min_samples_leaf=2, min_samples_split=11, n_estimators=656; total time=   1.3s
# [CV] END criterion=squared_error, max_depth=19, max_features=log2, min_samples_leaf=2, min_samples_split=11, n_estimators=656; total time=   1.3s
# [CV] END criterion=absolute_error, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=848; total time=   7.6s
# [CV] END criterion=squared_error, max_depth=19, max_features=log2, min_samples_leaf=2, min_samples_split=11, n_estimators=656; total time=   1.3s
# [CV] END criterion=absolute_error, max_depth=4, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=848; total time=   7.7s
# [CV] END criterion=absolute_error, max_depth=6, max_features=log2, min_samples_leaf=7, min_samples_split=8, n_estimators=289; total time=   2.9s
# [CV] END criterion=absolute_error, max_depth=6, max_features=log2, min_samples_leaf=7, min_samples_split=8, n_estimators=289; total time=   2.9s
# [CV] END criterion=squared_error, max_depth=1, max_features=sqrt, min_samples_leaf=9, min_samples_split=14, n_estimators=1868; total time=   2.1s
# [CV] END criterion=squared_error, max_depth=1, max_features=sqrt, min_samples_leaf=9, min_samples_split=14, n_estimators=1868; total time=   2.3s
# [CV] END criterion=absolute_error, max_depth=6, max_features=log2, min_samples_leaf=7, min_samples_split=8, n_estimators=289; total time=   2.9s
# [CV] END criterion=squared_error, max_depth=7, max_features=log2, min_samples_leaf=8, min_samples_split=10, n_estimators=417; total time=   0.7s
# [CV] END criterion=squared_error, max_depth=7, max_features=log2, min_samples_leaf=8, min_samples_split=10, n_estimators=417; total time=   0.7s
# [CV] END criterion=squared_error, max_depth=7, max_features=log2, min_samples_leaf=8, min_samples_split=10, n_estimators=417; total time=   0.7s
# [CV] END criterion=squared_error, max_depth=1, max_features=sqrt, min_samples_leaf=9, min_samples_split=14, n_estimators=1868; total time=   2.2s
# [CV] END criterion=squared_error, max_depth=1, max_features=None, min_samples_leaf=8, min_samples_split=16, n_estimators=1950; total time=   4.5s
# [CV] END criterion=squared_error, max_depth=1, max_features=None, min_samples_leaf=8, min_samples_split=16, n_estimators=1950; total time=   4.4s
# [CV] END criterion=squared_error, max_depth=1, max_features=None, min_samples_leaf=8, min_samples_split=16, n_estimators=1950; total time=   4.4s
# [CV] END criterion=squared_error, max_depth=2, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=1748; total time=   6.3s
# [CV] END criterion=squared_error, max_depth=2, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=1748; total time=   6.2s
# [CV] END criterion=squared_error, max_depth=2, max_features=None, min_samples_leaf=1, min_samples_split=6, n_estimators=1748; total time=   6.3s
# [CV] END criterion=absolute_error, max_depth=9, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=1633; total time=  27.8s
# [CV] END criterion=absolute_error, max_depth=9, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=1633; total time=  27.5s
# [CV] END criterion=absolute_error, max_depth=9, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=1633; total time=  27.6s
# [CV] END criterion=absolute_error, max_depth=14, max_features=None, min_samples_leaf=9, min_samples_split=16, n_estimators=1138; total time= 2.0min
# [CV] END criterion=absolute_error, max_depth=14, max_features=None, min_samples_leaf=9, min_samples_split=16, n_estimators=1138; total time= 2.1min
# [CV] END criterion=absolute_error, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=1176; total time=  16.2s
# [CV] END criterion=absolute_error, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=1176; total time=  16.0s
# [CV] END criterion=absolute_error, max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=1176; total time=  16.0s
# [CV] END criterion=squared_error, max_depth=17, max_features=None, min_samples_leaf=6, min_samples_split=6, n_estimators=983; total time=  10.1s
# [CV] END criterion=absolute_error, max_depth=14, max_features=None, min_samples_leaf=9, min_samples_split=16, n_estimators=1138; total time= 2.0min
# [CV] END criterion=squared_error, max_depth=17, max_features=None, min_samples_leaf=6, min_samples_split=6, n_estimators=983; total time=  10.0s
# [CV] END criterion=squared_error, max_depth=17, max_features=None, min_samples_leaf=6, min_samples_split=6, n_estimators=983; total time=  11.3s
# [CV] END criterion=absolute_error, max_depth=6, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=1247; total time=  15.2s
# [CV] END criterion=absolute_error, max_depth=6, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=1247; total time=  14.0s
# [CV] END criterion=squared_error, max_depth=6, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=502; total time=   1.0s
# [CV] END criterion=squared_error, max_depth=6, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=502; total time=   1.0s
# [CV] END criterion=squared_error, max_depth=6, max_features=sqrt, min_samples_leaf=3, min_samples_split=5, n_estimators=502; total time=   1.0s
# [CV] END criterion=absolute_error, max_depth=6, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=1247; total time=  14.2s
# [CV] END criterion=absolute_error, max_depth=17, max_features=None, min_samples_leaf=1, min_samples_split=3, n_estimators=741; total time= 2.0min
# [CV] END criterion=absolute_error, max_depth=17, max_features=None, min_samples_leaf=1, min_samples_split=3, n_estimators=741; total time= 2.0min
# [CV] END criterion=squared_error, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=9, n_estimators=740; total time=   1.8s
# [CV] END criterion=squared_error, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=9, n_estimators=740; total time=   1.8s
# [CV] END criterion=squared_error, max_depth=1, max_features=None, min_samples_leaf=2, min_samples_split=9, n_estimators=740; total time=   1.8s
# [CV] END criterion=absolute_error, max_depth=17, max_features=None, min_samples_leaf=1, min_samples_split=3, n_estimators=741; total time= 2.0min
# [CV] END criterion=squared_error, max_depth=18, max_features=None, min_samples_leaf=3, min_samples_split=8, n_estimators=1887; total time=  23.8s
# [CV] END criterion=squared_error, max_depth=18, max_features=None, min_samples_leaf=3, min_samples_split=8, n_estimators=1887; total time=  23.2s
# [CV] END criterion=absolute_error, max_depth=16, max_features=sqrt, min_samples_leaf=4, min_samples_split=18, n_estimators=101; total time=   1.7s
# [CV] END criterion=absolute_error, max_depth=16, max_features=sqrt, min_samples_leaf=4, min_samples_split=18, n_estimators=101; total time=   1.7s
# [CV] END criterion=absolute_error, max_depth=16, max_features=sqrt, min_samples_leaf=4, min_samples_split=18, n_estimators=101; total time=   1.6s
# [CV] END criterion=squared_error, max_depth=16, max_features=log2, min_samples_leaf=5, min_samples_split=6, n_estimators=1283; total time=   2.9s
# [CV] END criterion=squared_error, max_depth=16, max_features=log2, min_samples_leaf=5, min_samples_split=6, n_estimators=1283; total time=   4.2s
# [CV] END criterion=squared_error, max_depth=16, max_features=log2, min_samples_leaf=5, min_samples_split=6, n_estimators=1283; total time=   6.0s
# [CV] END criterion=squared_error, max_depth=9, max_features=sqrt, min_samples_leaf=3, min_samples_split=17, n_estimators=307; total time=   0.9s
# [CV] END criterion=squared_error, max_depth=9, max_features=sqrt, min_samples_leaf=3, min_samples_split=17, n_estimators=307; total time=   0.9s
# [CV] END criterion=squared_error, max_depth=9, max_features=sqrt, min_samples_leaf=3, min_samples_split=17, n_estimators=307; total time=   0.8s
# [CV] END criterion=squared_error, max_depth=18, max_features=None, min_samples_leaf=3, min_samples_split=8, n_estimators=1887; total time=  29.3s
# [CV] END criterion=squared_error, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=9, n_estimators=1543; total time=   4.9s
# [CV] END criterion=squared_error, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=9, n_estimators=1543; total time=   4.3s
# [CV] END criterion=absolute_error, max_depth=6, max_features=None, min_samples_leaf=4, min_samples_split=12, n_estimators=1307; total time= 2.6min
# [CV] END criterion=squared_error, max_depth=1, max_features=None, min_samples_leaf=1, min_samples_split=9, n_estimators=1543; total time=   3.9s
# [CV] END criterion=absolute_error, max_depth=6, max_features=None, min_samples_leaf=4, min_samples_split=12, n_estimators=1307; total time= 2.6min
# [CV] END criterion=squared_error, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=437; total time=   0.7s
# [CV] END criterion=squared_error, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=437; total time=   0.7s
# [CV] END criterion=absolute_error, max_depth=6, max_features=None, min_samples_leaf=4, min_samples_split=12, n_estimators=1307; total time= 2.6min
# [CV] END criterion=squared_error, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=437; total time=   0.7s
# [CV] END criterion=absolute_error, max_depth=8, max_features=log2, min_samples_leaf=3, min_samples_split=17, n_estimators=609; total time=   7.6s
# [CV] END criterion=absolute_error, max_depth=8, max_features=log2, min_samples_leaf=3, min_samples_split=17, n_estimators=609; total time=   7.4s
# [CV] END criterion=absolute_error, max_depth=3, max_features=sqrt, min_samples_leaf=9, min_samples_split=5, n_estimators=260; total time=   2.8s
# [CV] END criterion=absolute_error, max_depth=3, max_features=sqrt, min_samples_leaf=9, min_samples_split=5, n_estimators=260; total time=   2.8s
# [CV] END criterion=absolute_error, max_depth=8, max_features=log2, min_samples_leaf=3, min_samples_split=17, n_estimators=609; total time=   7.5s
# [CV] END criterion=absolute_error, max_depth=3, max_features=sqrt, min_samples_leaf=9, min_samples_split=5, n_estimators=260; total time=   2.9s
# [CV] END criterion=absolute_error, max_depth=1, max_features=log2, min_samples_leaf=5, min_samples_split=17, n_estimators=1627; total time=   7.2s
# [CV] END criterion=absolute_error, max_depth=1, max_features=log2, min_samples_leaf=5, min_samples_split=17, n_estimators=1627; total time=   7.2s
# [CV] END criterion=absolute_error, max_depth=1, max_features=log2, min_samples_leaf=5, min_samples_split=17, n_estimators=1627; total time=   7.2s
# [CV] END criterion=absolute_error, max_depth=3, max_features=None, min_samples_leaf=3, min_samples_split=8, n_estimators=1943; total time= 2.6min
# [CV] END criterion=absolute_error, max_depth=3, max_features=None, min_samples_leaf=3, min_samples_split=8, n_estimators=1943; total time= 2.6min
# [CV] END criterion=absolute_error, max_depth=3, max_features=None, min_samples_leaf=3, min_samples_split=8, n_estimators=1943; total time= 2.4min
# Best Parameters Found: {'criterion': 'absolute_error', 'max_depth': 17, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 741}
# Best RMSE on validation set: 26096.5618
#
#  Model Performance on Training Set:
#  Training R² Score: 0.9854
#  Training MAE: 6127.96
#  Training RMSE: 9533.01
#  Training RMSLE: 0.0548
#
#  Predictions saved to submission_final_billal.csv
# Model saved as best_model.pkl
