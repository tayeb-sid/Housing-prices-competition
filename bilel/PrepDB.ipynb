# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder ,StandardScaler , LabelEncoder
from sklearn.feature_selection import mutual_info_regression
from sklearn.decomposition import PCA
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
import pandas as pd
from sklearn.preprocessing import OrdinalEncoder

import os
import math

# %%
train = pd.read_csv("../home-data-for-ml-course/train.csv")
test = pd.read_csv("../home-data-for-ml-course/test.csv")
submission = pd.read_csv("../home-data-for-ml-course/sample_submission.csv")
train.columns = train.columns.str.strip()

# %%
# data = train.select_dtypes(include=["number"])
# num_cols = len(data.columns)
# cols = 3 
# rows = (num_cols // cols) + (num_cols % cols > 0)  

# fig, axes = plt.subplots(rows, cols, figsize=(15, 5 * rows))
# axes = axes.flatten()


# for i, col in enumerate(data.columns):
#     sns.boxplot(x=data[col], ax=axes[i], width=0.3, flierprops={'marker': 'o', 'markerfacecolor': 'red', 'markersize': 5})
#     axes[i].set_title(f"Box Plot de {col}")

# # Supprimer les axes inutilisés
# for j in range(i + 1, len(axes)):
#     fig.delaxes(axes[j])

# plt.tight_layout()
# plt.show()

# %%
cols_to_numeric = [
        "LotFrontage", "MasVnrArea", "BsmtFinSF1", "BsmtFinSF2", "BsmtUnfSF",
        "TotalBsmtSF", "BsmtFullBath", "GarageCars", "BsmtHalfBath", "GarageYrBlt"
    ]
for col in cols_to_numeric:
    if col in train.columns:
        train[col] = pd.to_numeric(train[col], errors="coerce")
        test[col] = pd.to_numeric(test[col], errors="coerce")
        
cat_cols = train.select_dtypes(include=['object']).columns
for cat_col in cat_cols:
    train[cat_col] = train[cat_col].fillna("NA")
    test[cat_col] = test[cat_col].fillna("NA")

# %%
train=train.drop(train[(train['GrLivArea']>3000) & (train['SalePrice']<300000)].index)
train=train.drop(train[(train['OpenPorchSF']>500) & (train['SalePrice']<100000)].index)
train=train.drop(train[(train['BsmtFinSF1']>5000) & (train['SalePrice']<300000)].index)
train=train.drop(train[(train['YearBuilt']<1900) & (train['SalePrice']>400000)].index)
train=train.drop(train[(train['TotalBsmtSF']>3000) & (train['SalePrice']<300000)].index)
train=train.drop(train[(train['OverallCond']==2) & (train['SalePrice']>300000)].index)
train = train.drop(train[(train['TotRmsAbvGrd'] >13) 
                                  & (train['SalePrice'] < 250000)].index)

# %%
test = pd.concat([test, submission["SalePrice"]], axis=1)
data = pd.concat([train , test])

y_SalePrice = data['SalePrice']

# %%
data['MSSubClass'] = data['MSSubClass'].astype(str)

data['time'] = data['YrSold'] - data['YearBuilt']

data['Total_Area'] = data['GrLivArea'] + data['TotalBsmtSF']

data['Final_Area'] = data['Total_Area'] + data['GarageArea']

data['Overall_Plus'] = data['OverallQual'] + data['OverallCond']

data['Overall_Mi'] = data['OverallQual'] - data['OverallCond']

data['area'] = data['Final_Area'] + data['LotArea'] * 0.1

data['Lack_of_feature_index'] = data[['Street', "Alley", "MasVnrType", "GarageType", "MiscFeature", 'BsmtQual', 'FireplaceQu','PoolQC','Fence']].isnull().sum(axis=1) + \
                                 (data["MasVnrType"] == 'None') + (data["CentralAir"] == 'No')

data["MiscFeatureExtended"] = (data["PoolQC"].notnull()*1 + data["MiscFeature"].notnull()*1 + data["Fence"].notnull()*1).astype('int64')

data["Has_Alley"] = data["Alley"].notnull().astype('int64')

data['Lot_Occupation'] = data['GrLivArea'] / data['LotArea']

data['Number_Of_Floors'] = (data['TotalBsmtSF'] != 0).astype('int64') + (data['1stFlrSF'] != 0).astype('int64') + (data['2ndFlrSF'] != 0).astype('int64')

data['Total_Close_Live_Area'] = data['GrLivArea'] + data['TotalBsmtSF']

data['Outside_Live_Area'] = data['WoodDeckSF'] + data['OpenPorchSF'] + data['EnclosedPorch'] + data['3SsnPorch'] + data['ScreenPorch']

data['Total_Usable_Area'] = data['Total_Close_Live_Area'] + data['Outside_Live_Area']

data['Area_Quality_Indicator'] = data['Total_Usable_Area'] * data['OverallQual']

data['Area_Quality_Cond_Indicator'] = data['Total_Usable_Area'] * data['OverallQual'] * data['OverallCond']

data['TotalBath'] = (data['FullBath'] + (0.5 * data['HalfBath']) + data['BsmtFullBath'] + (0.5 * data['BsmtHalfBath']))

data['Has_garage'] = data['GarageYrBlt'].notnull().astype('int64')

data['House_Age'] = data['YrSold'] - data['YearBuilt']

data['Is_Remodeled'] = (data['YearBuilt'] != data['YearRemodAdd']).astype('int64')

data['HasBsmt'] = data['BsmtQual'].notnull().astype('int64')

data['Quality_condition'] = data['OverallQual'] * data['OverallCond']

data['Quality_conditition_2'] = data['OverallQual'] + data['OverallCond']

data['House_Age2'] = data['YrSold'] - data['YearRemodAdd']

# %%
data = data.drop(columns = ['Id', 'SalePrice'])

# %%
pd.set_option('display.max_columns', None)  
pd.set_option('display.max_rows', None)  

missing_percentage = data.isnull().mean() * 100
print(missing_percentage)
# Out:
# MSSubClass                      0.000000
# MSZoning                        0.000000
# LotFrontage                    16.712517
# LotArea                         0.000000
# Street                          0.000000
# Alley                           0.000000
# LotShape                        0.000000
# LandContour                     0.000000
# Utilities                       0.000000
# LotConfig                       0.000000
# LandSlope                       0.000000
# Neighborhood                    0.000000
# Condition1                      0.000000
# Condition2                      0.000000
# BldgType                        0.000000
# HouseStyle                      0.000000
# OverallQual                     0.000000
# OverallCond                     0.000000
# YearBuilt                       0.000000
# YearRemodAdd                    0.000000
# RoofStyle                       0.000000
# RoofMatl                        0.000000
# Exterior1st                     0.000000
# Exterior2nd                     0.000000
# MasVnrType                      0.000000
# MasVnrArea                      0.790922
# ExterQual                       0.000000
# ExterCond                       0.000000
# Foundation                      0.000000
# BsmtQual                        0.000000
# BsmtCond                        0.000000
# BsmtExposure                    0.000000
# BsmtFinType1                    0.000000
# BsmtFinSF1                      0.034388
# BsmtFinType2                    0.000000
# BsmtFinSF2                      0.034388
# BsmtUnfSF                       0.034388
# TotalBsmtSF                     0.034388
# Heating                         0.000000
# HeatingQC                       0.000000
# CentralAir                      0.000000
# Electrical                      0.000000
# 1stFlrSF                        0.000000
# 2ndFlrSF                        0.000000
# LowQualFinSF                    0.000000
# GrLivArea                       0.000000
# BsmtFullBath                    0.068776
# BsmtHalfBath                    0.068776
# FullBath                        0.000000
# HalfBath                        0.000000
# BedroomAbvGr                    0.000000
# KitchenAbvGr                    0.000000
# KitchenQual                     0.000000
# TotRmsAbvGrd                    0.000000
# Functional                      0.000000
# Fireplaces                      0.000000
# FireplaceQu                     0.000000
# GarageType                      0.000000
# GarageYrBlt                     5.364512
# GarageFinish                    0.000000
# GarageCars                      0.034388
# GarageArea                      0.034388
# GarageQual                      0.000000
# GarageCond                      0.000000
# PavedDrive                      0.000000
# WoodDeckSF                      0.000000
# OpenPorchSF                     0.000000
# EnclosedPorch                   0.000000
# 3SsnPorch                       0.000000
# ScreenPorch                     0.000000
# PoolArea                        0.000000
# PoolQC                          0.000000
# Fence                           0.000000
# MiscFeature                     0.000000
# MiscVal                         0.000000
# MoSold                          0.000000
# YrSold                          0.000000
# SaleType                        0.000000
# SaleCondition                   0.000000
# time                            0.000000
# Total_Area                      0.034388
# Final_Area                      0.068776
# Overall_Plus                    0.000000
# Overall_Mi                      0.000000
# area                            0.068776
# Lack_of_feature_index           0.000000
# MiscFeatureExtended             0.000000
# Has_Alley                       0.000000
# Lot_Occupation                  0.000000
# Number_Of_Floors                0.000000
# Total_Close_Live_Area           0.034388
# Outside_Live_Area               0.000000
# Total_Usable_Area               0.034388
# Area_Quality_Indicator          0.034388
# Area_Quality_Cond_Indicator     0.034388
# TotalBath                       0.068776
# Has_garage                      0.000000
# House_Age                       0.000000
# Is_Remodeled                    0.000000
# HasBsmt                         0.000000
# Quality_condition               0.000000
# Quality_conditition_2           0.000000
# House_Age2                      0.000000
# dtype: float64

# %%
data['LotFrontage'].fillna(data['LotFrontage'].median(), inplace=True)
data['GarageYrBlt'].fillna(data['GarageYrBlt'].median(), inplace=True)
data['BsmtFullBath'].fillna(data['BsmtFullBath'].mode()[0], inplace=True)
data['GarageType'].fillna(data['GarageType'].mode()[0], inplace=True)
data['GarageCond'].fillna(data['GarageCond'].mode()[0], inplace=True)
data['GarageQual'].fillna(data['GarageQual'].mode()[0], inplace=True)
data['BsmtFinType2'].fillna(data['BsmtFinType2'].mode()[0], inplace=True)
data['BsmtExposure'].fillna(data['BsmtExposure'].mode()[0], inplace=True)
data['BsmtCond'].fillna(data['BsmtCond'].mode()[0], inplace=True)
data['MSZoning'] = data['MSZoning'].fillna(data['MSZoning'].mode())
data['MasVnrArea'].fillna(data['MasVnrArea'].mode()[0], inplace=True)
data['FireplaceQu'].fillna(data['FireplaceQu'].mode()[0], inplace=True)
data['Electrical'].fillna(data['Electrical'].mode()[0], inplace=True)
data['TotalSF'] = data['TotalBsmtSF'] + data['1stFlrSF'] + data['2ndFlrSF']
data['TotalBathrooms'] = data['FullBath'] + (0.5 * data['HalfBath']) + data['BsmtFullBath'] + (0.5 * data['BsmtHalfBath'])



cols_to_fill = ['BsmtHalfBath' ,
    'Functional', 'Utilities', 'BsmtUnfSF', 
    'GarageArea', 'Exterior1st', 'Exterior2nd', 'TotalBsmtSF', 'GarageCars', 
    'Electrical', 'KitchenQual', 'SaleType', 'BsmtFinSF1', 'BsmtFinSF2'
]

# Remplacer les valeurs manquantes par le mode dans les colonnes spécifiées
for col in cols_to_fill:
    if col in data.columns:  # Vérifie si la colonne existe dans le DataFrame
        mode_value = data[col].mode()[0]  # On prend le premier mode trouvé
        data[col].fillna(mode_value, inplace=True)
# Out:
# /var/folders/rg/r64x99yx2k91vgyysnwnb7pc0000gn/T/ipykernel_19174/1118281666.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['LotFrontage'].fillna(data['LotFrontage'].median(), inplace=True)
# /var/folders/rg/r64x99yx2k91vgyysnwnb7pc0000gn/T/ipykernel_19174/1118281666.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['GarageYrBlt'].fillna(data['GarageYrBlt'].median(), inplace=True)
# /var/folders/rg/r64x99yx2k91vgyysnwnb7pc0000gn/T/ipykernel_19174/1118281666.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['BsmtFullBath'].fillna(data['BsmtFullBath'].mode()[0], inplace=True)
# /var/folders/rg/r64x99yx2k91vgyysnwnb7pc0000gn/T/ipykernel_19174/1118281666.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['GarageType'].fillna(data['GarageType'].mode()[0], inplace=True)
# /var/folders/rg/r64x99yx2k91vgyysnwnb7pc0000gn/T/ipykernel_19174/1118281666.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['GarageCond'].fillna(data['GarageCond'].mode()[0], inplace=True)
# /var/folders/rg/r64x99yx2k91vgyysnwnb7pc0000gn/T/ipykernel_19174/1118281666.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['GarageQual'].fillna(data['GarageQual'].mode()[0], inplace=True)
# /var/folders/rg/r64x99yx2k91vgyysnwnb7pc0000gn/T/ipykernel_19174/1118281666.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['BsmtFinType2'].fillna(data['BsmtFinType2'].mode()[0], inplace=True)
# /var/folders/rg/r64x99yx2k91vgyysnwnb7pc0000gn/T/ipykernel_19174/1118281666.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['BsmtExposure'].fillna(data['BsmtExposure'].mode()[0], inplace=True)
# /var/folders/rg/r64x99yx2k91vgyysnwnb7pc0000gn/T/ipykernel_19174/1118281666.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['BsmtCond'].fillna(data['BsmtCond'].mode()[0], inplace=True)
# /var/folders/rg/r64x99yx2k91vgyysnwnb7pc0000gn/T/ipykernel_19174/1118281666.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['MasVnrArea'].fillna(data['MasVnrArea'].mode()[0], inplace=True)
# /var/folders/rg/r64x99yx2k91vgyysnwnb7pc0000gn/T/ipykernel_19174/1118281666.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['FireplaceQu'].fillna(data['FireplaceQu'].mode()[0], inplace=True)
# /var/folders/rg/r64x99yx2k91vgyysnwnb7pc0000gn/T/ipykernel_19174/1118281666.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Electrical'].fillna(data['Electrical'].mode()[0], inplace=True)
# /var/folders/rg/r64x99yx2k91vgyysnwnb7pc0000gn/T/ipykernel_19174/1118281666.py:29: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[col].fillna(mode_value, inplace=True)

# %%
train_ordinal = ['LotShape', 'Utilities', 'LandSlope', 'ExterQual', 'ExterCond', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 
                 'BsmtFinType1', 'BsmtFinType2', 'HeatingQC', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageFinish', 
                 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence']

train_nominal = ["MSZoning", "Street", "Alley", "LandContour", "LotConfig", "Neighborhood", "Condition1", "Condition2", 
                 "BldgType", "HouseStyle", "RoofStyle", "RoofMatl", "Exterior1st", "Exterior2nd", "MasVnrType", "Foundation", 
                 "Heating", "CentralAir", "Electrical", "GarageType", "MiscFeature", "SaleType", "SaleCondition"]

# %%
ordinal_mapping = {
    "GarageQual": {"Ex": 5, "Gd": 4, "TA": 3, "Fa": 2, "Po": 1, "NA": 0},
    "Fence": {"GdPrv": 4, "MnPrv": 3, "GdWo": 2, "MnWw": 1, "NA": 0},
    "GarageFinish": {"Fin": 3, "RFn": 2, "Unf": 1, "NA": 0},
    "KitchenQual": {"Ex": 4, "Gd": 3, "TA": 2, "Fa": 1, "Po": 0},
    "GarageCond": {"Ex": 5, "Gd": 4, "TA": 3, "Fa": 2, "Po": 1, "NA": 0},
    "HeatingQC": {"Ex": 4, "Gd": 3, "TA": 2, "Fa": 1, "Po": 0},
    "ExterQual": {"Ex": 4, "Gd": 3, "TA": 2, "Fa": 1, "Po": 0},
    "BsmtCond": {"Ex": 5, "Gd": 4, "TA": 3, "Fa": 2, "Po": 1, "NA": 0},
    "LandSlope": {"Gtl": 2, "Mod": 1, "Sev": 0},
    "ExterCond": {"Ex": 4, "Gd": 3, "TA": 2, "Fa": 1, "Po": 0},
    "BsmtExposure": {"Gd": 4, "Av": 3, "Mn": 2, "No": 1, "NA": 0},
    "PavedDrive": {"Y": 2, "P": 1, "N": 0},
    "BsmtQual": {"Ex": 5, "Gd": 4, "TA": 3, "Fa": 2, "Po": 1, "NA": 0},
    "LotShape": {"Reg": 3, "IR1": 2, "IR2": 1, "IR3": 0},
    "BsmtFinType2": {"GLQ": 6, "ALQ": 5, "BLQ": 4, "Rec": 3, "LwQ": 2, "Unf": 1, "NA": 0},
    "BsmtFinType1": {"GLQ": 6, "ALQ": 5, "BLQ": 4, "Rec": 3, "LwQ": 2, "Unf": 1, "NA": 0},
    "FireplaceQu": {"Ex": 5, "Gd": 4, "TA": 3, "Fa": 2, "Po": 1, "NA": 0},
    "Utilities": {"AllPub": 3, "NoSewr": 2, "NoSeWa": 1, "ELO": 0},
    "Functional": {"Typ": 7, "Min1": 6, "Min2": 5, "Mod": 4, "Maj1": 3, "Maj2": 2, "Sev": 1, "Sal": 0},
    "PoolQC": {"Ex": 5, "Gd": 4, "TA": 3, "Fa": 2, "Po": 1, "NA": 0},
}

# Vérifier que les colonnes existent dans data avant transformation
ordinal_columns = [col for col in train_ordinal if col in data.columns]

# Transformer en chaînes de caractères et gérer les valeurs manquantes
for col in ordinal_columns:
    data[col] = data[col].astype(str).str.strip().fillna("NA")

# Transformer les mappings en liste de catégories ordonnées
ordinal_categories = [list(ordinal_mapping[col].keys()) for col in ordinal_columns]

# Encodage Ordinal
ordinal_encoder = OrdinalEncoder(categories=ordinal_categories, 
                                 handle_unknown="use_encoded_value", unknown_value=-1)

data[ordinal_columns] = ordinal_encoder.fit_transform(data[ordinal_columns])


# Encodage One-Hot
#data = pd.get_dummies(data, columns=nominal_columns, dtype=int)

label_encoders = {}
for col in train_nominal:
    le = LabelEncoder()
    data[col] = le.fit_transform(data[col].astype(str))
    label_encoders[col] = le
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 35
#      30     data[col] = data[col].astype(str).str.strip().fillna("NA")
#      32 ordinal_encoder = OrdinalEncoder(categories=[ordinal_mapping[col] for col in ordinal_columns],
#      33                                  handle_unknown="use_encoded_value", unknown_value=-1)
# ---> 35 data[ordinal_columns] = ordinal_encoder.fit_transform(data[ordinal_columns])
#      37 # Encodage One-Hot
#      38 #data = pd.get_dummies(data, columns=nominal_columns, dtype=int)
#      40 label_encoders = {}
#
# File ~/Desktop/Housing-prices-competition/.venv/lib/python3.13/site-packages/sklearn/utils/_set_output.py:319, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     317 @wraps(f)
#     318 def wrapped(self, X, *args, **kwargs):
# --> 319     data_to_wrap = f(self, X, *args, **kwargs)
#     320     if isinstance(data_to_wrap, tuple):
#     321         # only wrap the first output for cross decomposition
#     322         return_tuple = (
#     323             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     324             *data_to_wrap[1:],
#     325         )
#
# File ~/Desktop/Housing-prices-competition/.venv/lib/python3.13/site-packages/sklearn/base.py:918, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     903         warnings.warn(
#     904             (
#     905                 f"This object ({self.__class__.__name__}) has a `transform`"
#    (...)
#     913             UserWarning,
#     914         )
#     916 if y is None:
#     917     # fit method of arity 1 (unsupervised transformation)
# --> 918     return self.fit(X, **fit_params).transform(X)
#     919 else:
#     920     # fit method of arity 2 (supervised transformation)
#     921     return self.fit(X, y, **fit_params).transform(X)
#
# File ~/Desktop/Housing-prices-competition/.venv/lib/python3.13/site-packages/sklearn/base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~/Desktop/Housing-prices-competition/.venv/lib/python3.13/site-packages/sklearn/preprocessing/_encoders.py:1515, in OrdinalEncoder.fit(self, X, y)
#    1508     raise TypeError(
#    1509         "unknown_value should only be set when "
#    1510         "handle_unknown is 'use_encoded_value', "
#    1511         f"got {self.unknown_value}."
#    1512     )
#    1514 # `_fit` will only raise an error when `self.handle_unknown="error"`
# -> 1515 fit_results = self._fit(
#    1516     X,
#    1517     handle_unknown=self.handle_unknown,
#    1518     ensure_all_finite="allow-nan",
#    1519     return_and_ignore_missing_for_infrequent=True,
#    1520 )
#    1521 self._missing_indices = fit_results["missing_indices"]
#    1523 cardinalities = [len(categories) for categories in self.categories_]
#
# File ~/Desktop/Housing-prices-competition/.venv/lib/python3.13/site-packages/sklearn/preprocessing/_encoders.py:121, in _BaseEncoder._fit(self, X, handle_unknown, ensure_all_finite, return_counts, return_and_ignore_missing_for_infrequent)
#     116     Xi_dtype = Xi.dtype
#     118 cats = np.array(self.categories[i], dtype=Xi_dtype)
#     119 if (
#     120     cats.dtype == object
# --> 121     and isinstance(cats[0], bytes)
#     122     and Xi.dtype.kind != "S"
#     123 ):
#     124     msg = (
#     125         f"In column {i}, the predefined categories have type 'bytes'"
#     126         " which is incompatible with values of type"
#     127         f" '{type(Xi[0]).__name__}'."
#     128     )
#     129     raise ValueError(msg)
#
# IndexError: too many indices for array: array is 0-dimensional, but 1 were indexed

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# Sélectionner les features numériques de data
numeric_features = data.select_dtypes(include=['int64', 'float64']).columns

# Pipeline pour la standardisation
pipeline = Pipeline([
    ('scaler', StandardScaler())
])

# Appliquer la standardisation sur les features numériques de data
data[numeric_features] = pipeline.fit_transform(data[numeric_features])

# %%
from sklearn.preprocessing import PowerTransformer

# Sélectionner les colonnes numériques
numeric_value = data.select_dtypes(include=['float64', 'int64'])

# Calculer la skewness pour chaque feature numérique
skewness = numeric_value.apply(lambda x: x.skew()).sort_values(ascending=False)

# Définir un seuil de skewness
skew_threshold = 0.75

# Sélectionner les features fortement biaisées
highly_skewed = skewness[skewness > skew_threshold].index
print(f"🔍 Found {len(highly_skewed)} highly skewed features:\n", skewness[highly_skewed])

# Appliquer la transformation Yeo-Johnson
pt = PowerTransformer(method="yeo-johnson")
data[highly_skewed] = pt.fit_transform(data[highly_skewed])

print("✅ Yeo-Johnson transformation applied successfully!")
new_skewness = data[highly_skewed].apply(lambda x: x.skew())
print("📉 Skewness after transformation:\n", new_skewness)
# Out:
# 🔍 Found 331 highly skewed features:
#  Condition2_PosN                 53.925875
# Condition2_RRAn                 53.925875
# Exterior1st_AsphShn             53.925875
# RoofMatl_Membran                53.925875
# Electrical_NA                   53.925875
# MiscFeature_TenC                53.925875
# RoofMatl_Roll                   53.925875
# Exterior2nd_CBlock              53.925875
# Exterior1st_CBlock              53.925875
# Exterior1st_ImStucc             53.925875
# SaleType_NA                     53.925875
# Condition2_RRAe                 53.925875
# Heating_Floor                   53.925875
# Condition2_PosA                 53.925875
# Exterior2nd_Stone               53.925875
# Exterior2nd_Other               53.925875
# RoofMatl_Metal                  53.925875
# Exterior1st_AsphShn             53.925875
# Electrical_Mix                  53.925875
# Exterior2nd_AsphShn             53.925875
# RoofMatl_WdShngl                53.925875
# Exterior1st_CBlock              53.925875
# Exterior2nd_NA                  53.925875
# Exterior1st_NA                  53.925875
# Neighborhood_Blueste            38.111664
# RoofStyle_Shed                  38.111664
# Heating_OthW                    38.111664
# MiscFeature_Othr                38.111664
# MiscFeature_Gar2                38.111664
# Exterior1st_Stone               38.111664
# SaleType_Con                    38.111664
# Exterior1st_BrkComm             38.111664
# Condition1_RRNe                 38.111664
# Exterior2nd_CBlock              38.111664
# Condition2_Artery               38.111664
# MiscFeature_Othr                38.111664
# Condition2_PosN                 38.111664
# Heating_Grav                    38.111664
# Condition2_RRNn                 38.111664
# Heating_Wall                    38.111664
# Foundation_Wood                 38.111664
# Foundation_Wood                 31.101964
# MiscFeature_Gar2                31.101964
# Condition2_Artery               31.101964
# SaleType_Con                    31.101964
# Exterior2nd_AsphShn             31.101964
# SaleType_Oth                    31.101964
# Condition2_PosA                 31.101964
# SaleType_ConLw                  31.101964
# RoofStyle_Shed                  31.101964
# Electrical_FuseP                31.101964
# Condition1_RRNn                 26.921162
# SaleType_Oth                    26.921162
# RoofStyle_Mansard               26.921162
# Condition1_RRNe                 26.921162
# HouseStyle_2.5Fin               26.921162
# Heating_Wall                    26.921162
# Exterior1st_BrkComm             26.921162
# MSZoning_NA                     26.921162
# SaleType_ConLI                  26.921162
# SaleType_CWD                    26.921162
# SaleCondition_AdjLand           26.921162
# RoofMatl_WdShake                26.921162
# LotConfig_FR3                   26.921162
# HouseStyle_1.5Unf               24.066557
# Exterior2nd_ImStucc             24.066557
# Electrical_FuseP                24.066557
# Condition1_RRNn                 24.066557
# Exterior2nd_Stone               24.066557
# RoofMatl_WdShngl                24.066557
# SaleType_ConLI                  24.066557
# Foundation_Stone                24.066557
# SaleType_ConLw                  24.066557
# RoofMatl_WdShake                24.066557
# GarageType_CarPort              21.958281
# Street_Grvl                     21.958281
# Condition2_Feedr                21.958281
# GarageType_2Types               21.958281
# Foundation_Stone                21.958281
# Street_Grvl                     21.958281
# MiscVal                         21.917095
# PoolQC                          21.891140
# RoofStyle_Mansard               20.318879
# Heating_Grav                    20.318879
# Exterior2nd_Brk Cmn             20.318879
# Condition2_Feedr                20.318879
# RoofStyle_Flat                  20.318879
# Condition1_PosA                 18.996710
# MasVnrType_NA                   18.996710
# SaleType_CWD                    18.996710
# Neighborhood_Blueste            18.996710
# SaleCondition_AdjLand           18.996710
# PoolArea                        18.631364
# Neighborhood_NPkVill            17.900971
# SaleType_ConLD                  17.900971
# GarageType_CarPort              17.900971
# MSZoning_C (all)                17.900971
# Heating_GasW                    17.900971
# Exterior2nd_ImStucc             16.973527
# LotConfig_FR3                   16.973527
# MasVnrType_BrkCmn               16.973527
# MSZoning_RH                     16.973527
# Condition1_RRAe                 16.175207
# RoofStyle_Gambrel               16.175207
# RoofMatl_Tar&Grv                16.175207
# HouseStyle_2.5Unf               16.175207
# Neighborhood_Veenker            16.175207
# RoofStyle_Gambrel               16.175207
# Neighborhood_Blmngtn            16.175207
# RoofMatl_Tar&Grv                15.478521
# Condition1_PosA                 15.478521
# SaleCondition_Alloca            15.478521
# SaleCondition_Alloca            15.478521
# Neighborhood_Veenker            14.863535
# HouseStyle_2.5Unf               14.863535
# RoofStyle_Flat                  14.863535
# Neighborhood_NPkVill            14.315394
# Neighborhood_BrDale             14.315394
# HouseStyle_1.5Unf               14.315394
# Exterior2nd_Brk Cmn             13.822769
# MSZoning_C (all)                13.822769
# MasVnrType_BrkCmn               13.822769
# MSZoning_RH                     13.822769
# LowQualFinSF                    13.748856
# Neighborhood_BrDale             13.376850
# Neighborhood_ClearCr            13.376850
# LotArea                         13.160801
# Neighborhood_Blmngtn            12.970669
# GarageType_Basment              12.970669
# Neighborhood_MeadowV            12.970669
# GarageType_2Types               12.970669
# SaleType_ConLD                  12.970669
# Condition1_RRAe                 12.970669
# GarageType_Basment              12.598631
# Heating_GasW                    12.598631
# Condition1_PosN                 12.598631
# Exterior2nd_AsbShng             12.598631
# Exterior1st_Stucco              12.598631
# Neighborhood_MeadowV            11.939597
# Condition1_PosN                 11.939597
# Exterior1st_AsbShng             11.939597
# SaleCondition_Family            11.939597
# Exterior2nd_AsbShng             11.939597
# Exterior2nd_Stucco              11.645744
# Exterior2nd_BrkFace             11.372020
# 3SsnPorch                       11.359992
# Neighborhood_SWISU              11.116214
# Exterior1st_Stucco              11.116214
# Electrical_FuseF                11.116214
# Neighborhood_SWISU              11.116214
# LandContour_Low                 10.876443
# Neighborhood_StoneBr            10.876443
# Condition1_RRAn                 10.876443
# Foundation_Slab                 10.876443
# Exterior1st_AsbShng             10.876443
# Exterior2nd_Stucco              10.876443
# Exterior2nd_BrkFace             10.651089
# Foundation_Slab                 10.651089
# Neighborhood_StoneBr            10.438754
# Condition1_RRAn                 10.438754
# SaleCondition_Family            10.438754
# Exterior1st_WdShing             10.438754
# Electrical_FuseF                10.238223
# Neighborhood_ClearCr            10.238223
# Neighborhood_NoRidge             9.697462
# BldgType_2fmCon                  9.697462
# Exterior1st_WdShing              9.697462
# BldgType_2fmCon                  9.534726
# Neighborhood_Timber              9.089910
# LandContour_Low                  8.824434
# Neighborhood_IDOTRR              8.824434
# Alley_Pave                       8.699744
# HouseStyle_SFoyer                8.699744
# Exterior1st_BrkFace              8.699744
# Neighborhood_Timber              8.579947
# LotConfig_FR2                    8.579947
# Exterior2nd_Wd Shng              8.579947
# Alley_Pave                       8.353797
# Neighborhood_NoRidge             8.246895
# Exterior2nd_Wd Shng              8.044232
# SaleType_COD                     8.044232
# BldgType_Twnhs                   8.044232
# SaleType_COD                     7.948046
# Condition1_Artery                7.948046
# MiscFeature_Shed                 7.765028
# HouseStyle_SFoyer                7.765028
# Condition1_Artery                7.765028
# LotConfig_FR2                    7.677863
# Neighborhood_Mitchel             7.511476
# MiscFeature_Shed                 7.511476
# Alley_Grvl                       7.431990
# Exterior1st_BrkFace              7.431990
# LandContour_HLS                  7.431990
# Neighborhood_BrkSide             7.431990
# Neighborhood_Crawfor             7.354812
# Neighborhood_Crawfor             7.279832
# BldgType_Duplex                  7.279832
# BldgType_Twnhs                   7.206946
# LandContour_Bnk                  7.136056
# Neighborhood_IDOTRR              6.999911
# BldgType_Duplex                  6.934489
# Neighborhood_BrkSide             6.870733
# Neighborhood_NWAmes              6.870733
# Exterior2nd_CmentBd              6.870733
# Neighborhood_SawyerW             6.808573
# Exterior1st_CemntBd              6.808573
# LandContour_Bnk                  6.808573
# HouseStyle_SLvl                  6.574607
# MSZoning_FV                      6.465636
# HouseStyle_SLvl                  6.465636
# Exterior1st_CemntBd              6.465636
# Neighborhood_Mitchel             6.465636
# Exterior2nd_CmentBd              6.412975
# Neighborhood_SawyerW             6.412975
# Alley_Grvl                       6.213481
# LandContour_HLS                  6.213481
# Neighborhood_NWAmes              6.074490
# Neighborhood_Sawyer              6.030001
# MSZoning_FV                      6.030001
# GarageType_NA                    5.943604
# Neighborhood_NridgHt             5.943604
# Neighborhood_Sawyer              5.901640
# GarageType_NA                    5.860464
# Neighborhood_Gilbert             5.820051
# Condition1_Feedr                 5.820051
# LotConfig_CulDSac                5.703155
# Condition1_Feedr                 5.665566
# Neighborhood_Gilbert             5.556643
# Neighborhood_Somerst             5.556643
# GarageType_BuiltIn               5.521556
# Neighborhood_NridgHt             5.453109
# SaleCondition_Abnorml            5.453109
# Electrical_FuseA                 5.354525
# LotConfig_CulDSac                5.291357
# CentralAir_N                     5.291357
# Neighborhood_Edwards             5.291357
# Electrical_FuseA                 5.291357
# Neighborhood_Somerst             5.230107
# SaleCondition_Abnorml            5.170679
# GarageType_BuiltIn               5.170679
# Neighborhood_Edwards             5.170679
# CentralAir_N                     5.084755
# Exterior1st_Plywood              4.897881
# Neighborhood_OldTown             4.823057
# Exterior1st_Plywood              4.774773
# BldgType_TwnhsE                  4.774773
# BldgType_TwnhsE                  4.751090
# SaleType_New                     4.681798
# Neighborhood_CollgCr             4.681798
# SaleType_New                     4.637006
# SaleCondition_Partial            4.615013
# MasVnrType_Stone                 4.593282
# SaleCondition_Partial            4.571807
# MasVnrType_Stone                 4.508868
# Neighborhood_OldTown             4.488367
# Exterior2nd_Plywood              4.448056
# KitchenAbvGr                     4.313446
# Exterior2nd_Plywood              4.206343
# Foundation_BrkTil                4.171970
# BsmtFinSF2                       4.162834
# Neighborhood_CollgCr             4.056850
# HouseStyle_1.5Fin                4.009820
# EnclosedPorch                    3.956537
# BsmtHalfBath                     3.939310
# ScreenPorch                      3.928081
# HouseStyle_1.5Fin                3.904991
# Foundation_BrkTil                3.834000
# area                             3.629765
# Exterior2nd_Wd Sdng              3.474712
# Exterior2nd_Wd Sdng              3.463679
# Exterior2nd_HdBoard              3.420320
# Exterior1st_Wd Sdng              3.378156
# Exterior1st_Wd Sdng              3.357504
# Exterior2nd_HdBoard              3.337130
# Exterior2nd_MetalSd              3.277606
# MSZoning_RM                      3.248706
# Neighborhood_NAmes               3.229745
# Exterior1st_MetalSd              3.220354
# Exterior1st_HdBoard              3.211022
# Exterior1st_HdBoard              3.192532
# Neighborhood_NAmes               3.174271
# BsmtFinType2                     3.158876
# Exterior1st_MetalSd              3.120803
# Exterior2nd_MetalSd              3.094781
# MSZoning_RM                      3.019388
# LotConfig_Corner                 2.971220
# LotConfig_Corner                 2.886896
# RoofStyle_Hip                    2.842919
# Lot_Occupation                   2.823368
# RoofStyle_Hip                    2.725272
# MasVnrArea                       2.623851
# OpenPorchSF                      2.482863
# GarageType_Detchd                2.170415
# GarageType_Detchd                2.139835
# HouseStyle_2Story                1.996628
# MasVnrType_BrkFace               1.969743
# HouseStyle_2Story                1.939666
# MasVnrType_BrkFace               1.932251
# WoodDeckSF                       1.846010
# Fence                            1.760330
# Exterior2nd_VinylSd              1.736561
# Exterior2nd_VinylSd              1.708112
# Exterior1st_VinylSd              1.708112
# Exterior1st_VinylSd              1.701871
# Area_Quality_Indicator           1.630311
# Area_Quality_Cond_Indicator      1.545977
# Foundation_CBlock                1.449580
# Outside_Live_Area                1.381185
# Foundation_CBlock                1.373908
# Foundation_PConc                 1.347140
# ExterCond                        1.315395
# Foundation_PConc                 1.302042
# 1stFlrSF                         1.267728
# LotFrontage                      1.235507
# HouseStyle_1Story                1.163795
# HouseStyle_1Story                1.117619
# BsmtExposure                     1.117527
# GrLivArea                        1.032197
# Total_Usable_Area                1.026513
# TotalSF                          1.016532
# Total_Area                       1.012908
# Total_Close_Live_Area            1.012908
# BsmtFinSF1                       0.982852
# BsmtUnfSF                        0.923025
# GarageType_Attchd                0.908339
# MasVnrType_None                  0.901063
# Final_Area                       0.894505
# GarageType_Attchd                0.884799
# 2ndFlrSF                         0.855734
# MasVnrType_NA                    0.835110
# ExterQual                        0.790222
# dtype: float64
# ✅ Yeo-Johnson transformation applied successfully!
# 📉 Skewness after transformation:
#  Condition2_PosN                 53.925875
# Condition2_RRAn                 53.925875
# Exterior1st_AsphShn             53.925875
# RoofMatl_Membran                53.925875
# Electrical_NA                   53.925875
# MiscFeature_TenC                53.925875
# RoofMatl_Roll                   53.925875
# Exterior2nd_CBlock              53.925875
# Exterior1st_CBlock              53.925875
# Exterior1st_ImStucc             53.925875
# SaleType_NA                     53.925875
# Condition2_RRAe                 53.925875
# Heating_Floor                   53.925875
# Condition2_PosA                 53.925875
# Exterior2nd_Stone               53.925875
# Exterior2nd_Other               53.925875
# RoofMatl_Metal                  53.925875
# Exterior1st_AsphShn             53.925875
# Electrical_Mix                  53.925875
# Exterior2nd_AsphShn             53.925875
# RoofMatl_WdShngl                53.925875
# Exterior1st_CBlock              53.925875
# Exterior2nd_NA                  53.925875
# Exterior1st_NA                  53.925875
# Neighborhood_Blueste            38.111664
# RoofStyle_Shed                  38.111664
# Heating_OthW                    38.111664
# MiscFeature_Othr                38.111664
# MiscFeature_Gar2                38.111664
# Exterior1st_Stone               38.111664
# SaleType_Con                    38.111664
# Exterior1st_BrkComm             38.111664
# Condition1_RRNe                 38.111664
# Exterior2nd_CBlock              38.111664
# Condition2_Artery               38.111664
# MiscFeature_Othr                38.111664
# Condition2_PosN                 38.111664
# Heating_Grav                    38.111664
# Condition2_RRNn                 38.111664
# Heating_Wall                    38.111664
# Foundation_Wood                 38.111664
# Foundation_Wood                 31.101964
# MiscFeature_Gar2                31.101964
# Condition2_Artery               31.101964
# SaleType_Con                    31.101964
# Exterior2nd_AsphShn             31.101964
# SaleType_Oth                    31.101964
# Condition2_PosA                 31.101964
# SaleType_ConLw                  31.101964
# RoofStyle_Shed                  31.101964
# Electrical_FuseP                31.101964
# Condition1_RRNn                 26.921162
# SaleType_Oth                    26.921162
# RoofStyle_Mansard               26.921162
# Condition1_RRNe                 26.921162
# HouseStyle_2.5Fin               26.921162
# Heating_Wall                    26.921162
# Exterior1st_BrkComm             26.921162
# MSZoning_NA                     26.921162
# SaleType_ConLI                  26.921162
# SaleType_CWD                    26.921162
# SaleCondition_AdjLand           26.921162
# RoofMatl_WdShake                26.921162
# LotConfig_FR3                   26.921162
# HouseStyle_1.5Unf               24.066557
# Exterior2nd_ImStucc             24.066557
# Electrical_FuseP                24.066557
# Condition1_RRNn                 24.066557
# Exterior2nd_Stone               24.066557
# RoofMatl_WdShngl                24.066557
# SaleType_ConLI                  24.066557
# Foundation_Stone                24.066557
# SaleType_ConLw                  24.066557
# RoofMatl_WdShake                24.066557
# GarageType_CarPort              21.958281
# Street_Grvl                     21.958281
# Condition2_Feedr                21.958281
# GarageType_2Types               21.958281
# Foundation_Stone                21.958281
# Street_Grvl                     21.958281
# MiscVal                          5.029994
# PoolQC                          18.996710
# RoofStyle_Mansard               20.318879
# Heating_Grav                    20.318879
# Exterior2nd_Brk Cmn             20.318879
# Condition2_Feedr                20.318879
# RoofStyle_Flat                  20.318879
# Condition1_PosA                 18.996710
# MasVnrType_NA                   18.996710
# SaleType_CWD                    18.996710
# Neighborhood_Blueste            18.996710
# SaleCondition_AdjLand           18.996710
# PoolArea                        16.175207
# Neighborhood_NPkVill            17.900971
# SaleType_ConLD                  17.900971
# GarageType_CarPort              17.900971
# MSZoning_C (all)                17.900971
# Heating_GasW                    17.900971
# Exterior2nd_ImStucc             16.973527
# LotConfig_FR3                   16.973527
# MasVnrType_BrkCmn               16.973527
# MSZoning_RH                     16.973527
# Condition1_RRAe                 16.175207
# RoofStyle_Gambrel               16.175207
# RoofMatl_Tar&Grv                16.175207
# HouseStyle_2.5Unf               16.175207
# Neighborhood_Veenker            16.175207
# RoofStyle_Gambrel               16.175207
# Neighborhood_Blmngtn            16.175207
# RoofMatl_Tar&Grv                15.478521
# Condition1_PosA                 15.478521
# SaleCondition_Alloca            15.478521
# SaleCondition_Alloca            15.478521
# Neighborhood_Veenker            14.863535
# HouseStyle_2.5Unf               14.863535
# RoofStyle_Flat                  14.863535
# Neighborhood_NPkVill            14.315394
# Neighborhood_BrDale             14.315394
# HouseStyle_1.5Unf               14.315394
# Exterior2nd_Brk Cmn             13.822769
# MSZoning_C (all)                13.822769
# MasVnrType_BrkCmn               13.822769
# MSZoning_RH                     13.822769
# LowQualFinSF                     8.954362
# Neighborhood_BrDale             13.376850
# Neighborhood_ClearCr            13.376850
# LotArea                         -0.204820
# Neighborhood_Blmngtn            12.970669
# GarageType_Basment              12.970669
# Neighborhood_MeadowV            12.970669
# GarageType_2Types               12.970669
# SaleType_ConLD                  12.970669
# Condition1_RRAe                 12.970669
# GarageType_Basment              12.598631
# Heating_GasW                    12.598631
# Condition1_PosN                 12.598631
# Exterior2nd_AsbShng             12.598631
# Exterior1st_Stucco              12.598631
# Neighborhood_MeadowV            11.939597
# Condition1_PosN                 11.939597
# Exterior1st_AsbShng             11.939597
# SaleCondition_Family            11.939597
# Exterior2nd_AsbShng             11.939597
# Exterior2nd_Stucco              11.645744
# Exterior2nd_BrkFace             11.372020
# 3SsnPorch                        8.699744
# Neighborhood_SWISU              11.116214
# Exterior1st_Stucco              11.116214
# Electrical_FuseF                11.116214
# Neighborhood_SWISU              11.116214
# LandContour_Low                 10.876443
# Neighborhood_StoneBr            10.876443
# Condition1_RRAn                 10.876443
# Foundation_Slab                 10.876443
# Exterior1st_AsbShng             10.876443
# Exterior2nd_Stucco              10.876443
# Exterior2nd_BrkFace             10.651089
# Foundation_Slab                 10.651089
# Neighborhood_StoneBr            10.438754
# Condition1_RRAn                 10.438754
# SaleCondition_Family            10.438754
# Exterior1st_WdShing             10.438754
# Electrical_FuseF                10.238223
# Neighborhood_ClearCr            10.238223
# Neighborhood_NoRidge             9.697462
# BldgType_2fmCon                  9.697462
# Exterior1st_WdShing              9.697462
# BldgType_2fmCon                  9.534726
# Neighborhood_Timber              9.089910
# LandContour_Low                  8.824434
# Neighborhood_IDOTRR              8.824434
# Alley_Pave                       8.699744
# HouseStyle_SFoyer                8.699744
# Exterior1st_BrkFace              8.699744
# Neighborhood_Timber              8.579947
# LotConfig_FR2                    8.579947
# Exterior2nd_Wd Shng              8.579947
# Alley_Pave                       8.353797
# Neighborhood_NoRidge             8.246895
# Exterior2nd_Wd Shng              8.044232
# SaleType_COD                     8.044232
# BldgType_Twnhs                   8.044232
# SaleType_COD                     7.948046
# Condition1_Artery                7.948046
# MiscFeature_Shed                 7.765028
# HouseStyle_SFoyer                7.765028
# Condition1_Artery                7.765028
# LotConfig_FR2                    7.677863
# Neighborhood_Mitchel             7.511476
# MiscFeature_Shed                 7.511476
# Alley_Grvl                       7.431990
# Exterior1st_BrkFace              7.431990
# LandContour_HLS                  7.431990
# Neighborhood_BrkSide             7.431990
# Neighborhood_Crawfor             7.354812
# Neighborhood_Crawfor             7.279832
# BldgType_Duplex                  7.279832
# BldgType_Twnhs                   7.206946
# LandContour_Bnk                  7.136056
# Neighborhood_IDOTRR              6.999911
# BldgType_Duplex                  6.934489
# Neighborhood_BrkSide             6.870733
# Neighborhood_NWAmes              6.870733
# Exterior2nd_CmentBd              6.870733
# Neighborhood_SawyerW             6.808573
# Exterior1st_CemntBd              6.808573
# LandContour_Bnk                  6.808573
# HouseStyle_SLvl                  6.574607
# MSZoning_FV                      6.465636
# HouseStyle_SLvl                  6.465636
# Exterior1st_CemntBd              6.465636
# Neighborhood_Mitchel             6.465636
# Exterior2nd_CmentBd              6.412975
# Neighborhood_SawyerW             6.412975
# Alley_Grvl                       6.213481
# LandContour_HLS                  6.213481
# Neighborhood_NWAmes              6.074490
# Neighborhood_Sawyer              6.030001
# MSZoning_FV                      6.030001
# GarageType_NA                    5.943604
# Neighborhood_NridgHt             5.943604
# Neighborhood_Sawyer              5.901640
# GarageType_NA                    5.860464
# Neighborhood_Gilbert             5.820051
# Condition1_Feedr                 5.820051
# LotConfig_CulDSac                5.703155
# Condition1_Feedr                 5.665566
# Neighborhood_Gilbert             5.556643
# Neighborhood_Somerst             5.556643
# GarageType_BuiltIn               5.521556
# Neighborhood_NridgHt             5.453109
# SaleCondition_Abnorml            5.453109
# Electrical_FuseA                 5.354525
# LotConfig_CulDSac                5.291357
# CentralAir_N                     5.291357
# Neighborhood_Edwards             5.291357
# Electrical_FuseA                 5.291357
# Neighborhood_Somerst             5.230107
# SaleCondition_Abnorml            5.170679
# GarageType_BuiltIn               5.170679
# Neighborhood_Edwards             5.170679
# CentralAir_N                     5.084755
# Exterior1st_Plywood              4.897881
# Neighborhood_OldTown             4.823057
# Exterior1st_Plywood              4.774773
# BldgType_TwnhsE                  4.774773
# BldgType_TwnhsE                  4.751090
# SaleType_New                     4.681798
# Neighborhood_CollgCr             4.681798
# SaleType_New                     4.637006
# SaleCondition_Partial            4.615013
# MasVnrType_Stone                 4.593282
# SaleCondition_Partial            4.571807
# MasVnrType_Stone                 4.508868
# Neighborhood_OldTown             4.488367
# Exterior2nd_Plywood              4.448056
# KitchenAbvGr                    -6.976987
# Exterior2nd_Plywood              4.206343
# Foundation_BrkTil                4.171970
# BsmtFinSF2                       2.387259
# Neighborhood_CollgCr             4.056850
# HouseStyle_1.5Fin                4.009820
# EnclosedPorch                    1.895360
# BsmtHalfBath                     3.713558
# ScreenPorch                      2.916997
# HouseStyle_1.5Fin                3.904991
# Foundation_BrkTil                3.834000
# area                            -0.009432
# Exterior2nd_Wd Sdng              3.474712
# Exterior2nd_Wd Sdng              3.463679
# Exterior2nd_HdBoard              3.420320
# Exterior1st_Wd Sdng              3.378156
# Exterior1st_Wd Sdng              3.357504
# Exterior2nd_HdBoard              3.337130
# Exterior2nd_MetalSd              3.277606
# MSZoning_RM                      3.248706
# Neighborhood_NAmes               3.229745
# Exterior1st_MetalSd              3.220354
# Exterior1st_HdBoard              3.211022
# Exterior1st_HdBoard              3.192532
# Neighborhood_NAmes               3.174271
# BsmtFinType2                    -1.190324
# Exterior1st_MetalSd              3.120803
# Exterior2nd_MetalSd              3.094781
# MSZoning_RM                      3.019388
# LotConfig_Corner                 2.971220
# LotConfig_Corner                 2.886896
# RoofStyle_Hip                    2.842919
# Lot_Occupation                  -0.064188
# RoofStyle_Hip                    2.725272
# MasVnrArea                       0.694702
# OpenPorchSF                      0.361169
# GarageType_Detchd                2.170415
# GarageType_Detchd                2.139835
# HouseStyle_2Story                1.996628
# MasVnrType_BrkFace               1.969743
# HouseStyle_2Story                1.939666
# MasVnrType_BrkFace               1.932251
# WoodDeckSF                       0.404836
# Fence                            1.542134
# Exterior2nd_VinylSd              1.736561
# Exterior2nd_VinylSd              1.708112
# Exterior1st_VinylSd              1.708112
# Exterior1st_VinylSd              1.701871
# Area_Quality_Indicator           0.022976
# Area_Quality_Cond_Indicator     -0.009313
# Foundation_CBlock                1.449580
# Outside_Live_Area                0.120856
# Foundation_CBlock                1.373908
# Foundation_PConc                 1.347140
# ExterCond                       -1.057121
# Foundation_PConc                 1.302042
# 1stFlrSF                         0.029098
# LotFrontage                      0.014381
# HouseStyle_1Story                1.163795
# HouseStyle_1Story                1.117619
# BsmtExposure                    -0.039042
# GrLivArea                        0.041124
# Total_Usable_Area                0.003421
# TotalSF                         -0.002372
# Total_Area                      -0.001116
# Total_Close_Live_Area           -0.001116
# BsmtFinSF1                       0.193485
# BsmtUnfSF                        0.096922
# GarageType_Attchd                0.908339
# MasVnrType_None                  0.901063
# Final_Area                      -0.007628
# GarageType_Attchd                0.884799
# 2ndFlrSF                         0.425756
# MasVnrType_NA                    0.835110
# ExterQual                       -0.151434
# dtype: float64

# %%
# Diviser les données en train et test
tra = data.iloc[:len(train), :]  # 1460 premières lignes pour l'entraînement
tes = data.iloc[len(train):, :]  # Le reste pour le test

# Extraire SalePrice pour l'entraînement (pour concaténer avec les features d'entraînement)
y_S = y_SalePrice.iloc[:len(train)]  # Pas besoin de `:` supplémentaire ici

# Ajouter y_SalePrice à `tra` (en tant que nouvelle colonne)
tra = pd.concat([tra, y_S], axis=1)

# Vérifier la forme des ensembles train et test
print(tra.shape, tes.shape)

# Sauvegarder les fichiers résultants
tra.to_csv('final_data_nv.csv', index=False)
tes.to_csv('final_test_data_nv.csv', index=False)
# Out:
# (1449, 411) (1459, 410)
